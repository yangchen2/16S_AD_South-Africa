# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import biom
from biom import load_table
import numpy as np
from scipy.stats import spearmanr
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
import itertools
import matplotlib.patches
from scipy import stats
from scipy.stats import pearsonr
import os
import statsmodels.formula.api as smf
from statsmodels.formula.api import ols

# %%
# Load the metadata
metadata_path = '../Data/Metadata/updated_clean_ant_skin_metadata.tab'
metadata = pd.read_csv(metadata_path, sep='\t')

metadata['#sample-id'] = metadata['#sample-id'].str.replace('_', '')
# Set Sample-ID as the index for the metadata dataframe 
metadata = metadata.set_index('#sample-id')


# Create group column based on case_type to simplify group names
metadata['group'] = metadata['case_type'].map({
    'case-lesional skin': 'skin-ADL',
    'case-nonlesional skin': 'skin-ADNL', 
    'control-nonlesional skin': 'skin-H',
    'case-anterior nares': 'nares-AD',
    'control-anterior nares': 'nares-H'
})

metadata
# Out:
#             PlateNumber PlateLocation     i5 i5Sequence     i7 i7Sequence  \
# #sample-id
# Ca009STL              1            A1  SA501   ATCGTACG  SA701   CGAGAGTT
# 900221                1            B1  SA502   ACTATCTG  SA701   CGAGAGTT
# Ca010EBL              1            C1  SA503   TAGCGAGT  SA701   CGAGAGTT
# 900460                1            D1  SA504   CTGCGTGT  SA701   CGAGAGTT
# 900051                1            E1  SA505   TCATCGAG  SA701   CGAGAGTT
# ...                 ...           ...    ...        ...    ...        ...
# Ca006ONL2             6            H1  SA508   GACACCGT  SB701   CTCGACTT
# Ca006ONNL             6            F2  SA506   CGTGAGTG  SB702   CGAAGTAT
# Ca006ONNL2            6            H2  SA508   GACACCGT  SB702   CGAAGTAT
# Ca006ONPN             6            F3  SA506   CGTGAGTG  SB703   TAGCAGCT
# Ca006ONPN2            6            H3  SA508   GACACCGT  SB703   TAGCAGCT
#
#             identifier           Sequence      Plate ID Well location  ...  \
# #sample-id                                                             ...
# Ca009STL    SA701SA501  CGAGAGTT-ATCGTACG  1.010000e+21            A1  ...
# 900221      SA701SA502  CGAGAGTT-ACTATCTG  1.010000e+21            B1  ...
# Ca010EBL    SA701SA503  CGAGAGTT-TAGCGAGT  1.010000e+21            C1  ...
# 900460      SA701SA504  CGAGAGTT-CTGCGTGT  1.010000e+21            D1  ...
# 900051      SA701SA505  CGAGAGTT-TCATCGAG  1.010000e+21            E1  ...
# ...                ...                ...           ...           ...  ...
# Ca006ONL2   SB701SA508  CTCGACTT-GACACCGT  1.010000e+21            H1  ...
# Ca006ONNL   SB702SA506  CGAAGTAT-CGTGAGTG  1.010000e+21            F2  ...
# Ca006ONNL2  SB702SA508  CGAAGTAT-GACACCGT  1.010000e+21            H2  ...
# Ca006ONPN   SB703SA506  TAGCAGCT-CGTGAGTG  1.010000e+21            F3  ...
# Ca006ONPN2  SB703SA508  TAGCAGCT-GACACCGT  1.010000e+21            H3  ...
#
#                sex enrolment_date enrolment_season hiv_exposure hiv_status  \
# #sample-id
# Ca009STL      male      4/16/2015          Autumn     Unexposed   negative
# 900221      female      8/11/2015           Winter    Unexposed   negative
# Ca010EBL    female     11/20/2014           Spring    Unexposed   negative
# 900460      female      9/23/2015           Spring    Unexposed        NaN
# 900051        male      4/21/2015          Autumn     Unexposed   negative
# ...            ...            ...              ...          ...        ...
# Ca006ONL2   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONNL   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONNL2  female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONPN   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONPN2  female      3/25/2015           Autumn    Unexposed   negative
#
#            household_size o_scorad  \
# #sample-id
# Ca009STL              4.0       40
# 900221                7.0       34
# Ca010EBL              7.0       21
# 900460                4.0       40
# 900051                7.0       41
# ...                   ...      ...
# Ca006ONL2             3.0       34
# Ca006ONNL             3.0       34
# Ca006ONNL2            3.0       34
# Ca006ONPN             3.0       34
# Ca006ONPN2            3.0       34
#
#                                                  FWD_filepath  \
# #sample-id
# Ca009STL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900221      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca010EBL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900460      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900051      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# ...                                                       ...
# Ca006ONL2   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONNL   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONNL2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONPN   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONPN2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
#
#                                                  REV_filepath      group
# #sample-id
# Ca009STL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900221      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# Ca010EBL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900460      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900051      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# ...                                                       ...        ...
# Ca006ONL2   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# Ca006ONNL   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...  skin-ADNL
# Ca006ONNL2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...  skin-ADNL
# Ca006ONPN   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   nares-AD
# Ca006ONPN2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   nares-AD
#
# [502 rows x 32 columns]

# %%
# Read in table at ASV level
biom_path = '../Data/Tables/Absolute_Abundance_Tables/209766_filtered_by_prevalence_1pct_rare_Genus.biom'
# biom_path = '../Data/Tables/Absolute_Abundance_Tables/209766_filtered_by_prevalence_1pct_rare_Genus-ASV-non-collapse.biom'
biom_tbl = load_table(biom_path)
df = pd.DataFrame(biom_tbl.to_dataframe().T)

# delete the prefix from the index
df.index = df.index.str.replace('15564.', '')

df
# Out:
#          g__Streptococcus  g__Staphylococcus   g__  g__Haemophilus_D_734546  \
# 900344              303.0                  0   3.0                        0
# 900459               57.0                9.0   2.0                    131.0
# 900221                  0               27.0     0                        0
# 900570               39.0               86.0  53.0                      1.0
# 900092              337.0                  0   3.0                        0
# ...                   ...                ...   ...                      ...
# 9003972              78.0               52.0  16.0                      4.0
# 900097                3.0               52.0  86.0                        0
# 900498                9.0               22.0  43.0                        0
# 900276                  0                3.0  22.0                        0
# 900406                  0                  0     0                        0
#
#          g__Corynebacterium  g__Acinetobacter  g__Prevotella  g__Micrococcus  \
# 900344                 42.0                 0              0               0
# 900459                    0                 0            5.0             1.0
# 900221                  2.0               3.0              0               0
# 900570                  9.0              12.0           65.0               0
# 900092                  4.0                 0              0               0
# ...                     ...               ...            ...             ...
# 9003972                 7.0               4.0           12.0             3.0
# 900097                  3.0              38.0           38.0            18.0
# 900498                  6.0              19.0              0            15.0
# 900276                 13.0               6.0           22.0               0
# 900406                    0                 0              0               0
#
#          g__Dolosigranulum  g__Cutibacterium  ...  g__Eubacterium_M  \
# 900344                   0               2.0  ...                 0
# 900459               133.0                 0  ...                 0
# 900221                   0                 0  ...                 0
# 900570                   0                 0  ...                 0
# 900092                 1.0                 0  ...                 0
# ...                    ...               ...  ...               ...
# 9003972                  0              39.0  ...                 0
# 900097                   0               7.0  ...                 0
# 900498                   0              24.0  ...                 0
# 900276                   0             114.0  ...                 0
# 900406                   0                 0  ...                 0
#
#          g__Lachnospira  g__Helcococcus  g__Enterenecus  g__Evtepia  \
# 900344                0               0               0           0
# 900459                0               0               0           0
# 900221                0               0               0           0
# 900570                0               0               0           0
# 900092                0               0               0           0
# ...                 ...             ...             ...         ...
# 9003972               0               0               0           0
# 900097                0               0               0           0
# 900498                0               0               0           0
# 900276                0               0               0           0
# 900406                0               0               0           0
#
#          g__Fimenecus  g__CAG-41  g__Selenomonas_B_42762  \
# 900344              0          0                       0
# 900459              0          0                       0
# 900221              0          0                       0
# 900570              0          0                       0
# 900092              0          0                       0
# ...               ...        ...                     ...
# 9003972             0          0                       0
# 900097              0          0                       0
# 900498              0          0                       0
# 900276              0          0                       0
# 900406              0          0                       0
#
#          g__Facklamia_A_322620  g__Eubacterium_G
# 900344                       0                 0
# 900459                       0                 0
# 900221                       0                 0
# 900570                       0                 0
# 900092                       0                 0
# ...                        ...               ...
# 9003972                      0                 0
# 900097                       0                 0
# 900498                       0                 0
# 900276                       0                 0
# 900406                       0                 0
#
# [502 rows x 218 columns]

# %%
def rclr_transform(df, pseudocount=1e-6):
    """
    Applies Robust Centered Log-Ratio (RCLR) transformation to a DataFrame.
    Zeros are ignored in the geometric mean calculation per sample.
    """
    # Convert sparse to dense if needed
    df = df.sparse.to_dense()

    # Replace 0 with np.nan to ignore in log and mean
    df_masked = df.replace(0, np.nan)

    # Apply log (with pseudocount only where needed)
    log_df = np.log(df_masked + pseudocount)

    # Subtract mean of each row (feature)
    rclr_df = log_df.sub(log_df.mean(axis=1, skipna=True), axis=0)

    return rclr_df

# %%
rclr_df = rclr_transform(df)
rclr_df
# Out:
#          g__Streptococcus  g__Staphylococcus       g__  \
# 900344           2.902942                NaN -1.712178
# 900459           2.557814           0.711987 -0.792090
# 900221                NaN           1.126537       NaN
# 900570           2.535851           3.326637  2.842581
# 900092           4.204868                NaN -0.516602
# ...                   ...                ...       ...
# 9003972          3.143951           2.738485  1.559830
# 900097          -0.696746           2.155885  2.658989
# 900498           0.164330           1.058148  1.728305
# 900276                NaN          -0.574105  1.418325
# 900406                NaN                NaN       NaN
#
#          g__Haemophilus_D_734546  g__Corynebacterium  g__Acinetobacter  \
# 900344                       NaN            0.926879               NaN
# 900459                  3.389960                 NaN               NaN
# 900221                       NaN           -1.476152         -1.070687
# 900570                 -1.127710            1.069514          1.357196
# 900092                       NaN           -0.228920               NaN
# ...                          ...                 ...               ...
# 9003972                 0.173536            0.733152          0.173536
# 900097                       NaN           -0.696746          1.842228
# 900498                       NaN           -0.241135          0.911544
# 900276                       NaN            0.892232          0.119042
# 900406                       NaN                 NaN               NaN
#
#          g__Prevotella  g__Micrococcus  g__Dolosigranulum  g__Cutibacterium  \
# 900344             NaN             NaN                NaN         -2.117643
# 900459        0.124201       -1.485236           3.405112               NaN
# 900221             NaN             NaN                NaN               NaN
# 900570        3.046676             NaN                NaN               NaN
# 900092             NaN             NaN          -1.615213               NaN
# ...                ...             ...                ...               ...
# 9003972       1.272148       -0.114146                NaN          2.450803
# 900097        1.842228        1.095013                NaN          0.150552
# 900498             NaN        0.675155                NaN          1.145159
# 900276        1.418325             NaN                NaN          3.063481
# 900406             NaN             NaN                NaN               NaN
#
#          ...  g__Eubacterium_M  g__Lachnospira  g__Helcococcus  \
# 900344   ...               NaN             NaN             NaN
# 900459   ...               NaN             NaN             NaN
# 900221   ...               NaN             NaN             NaN
# 900570   ...               NaN             NaN             NaN
# 900092   ...               NaN             NaN             NaN
# ...      ...               ...             ...             ...
# 9003972  ...               NaN             NaN             NaN
# 900097   ...               NaN             NaN             NaN
# 900498   ...               NaN             NaN             NaN
# 900276   ...               NaN             NaN             NaN
# 900406   ...               NaN             NaN             NaN
#
#          g__Enterenecus  g__Evtepia  g__Fimenecus  g__CAG-41  \
# 900344              NaN         NaN           NaN        NaN
# 900459              NaN         NaN           NaN        NaN
# 900221              NaN         NaN           NaN        NaN
# 900570              NaN         NaN           NaN        NaN
# 900092              NaN         NaN           NaN        NaN
# ...                 ...         ...           ...        ...
# 9003972             NaN         NaN           NaN        NaN
# 900097              NaN         NaN           NaN        NaN
# 900498              NaN         NaN           NaN        NaN
# 900276              NaN         NaN           NaN        NaN
# 900406              NaN         NaN           NaN        NaN
#
#          g__Selenomonas_B_42762  g__Facklamia_A_322620  g__Eubacterium_G
# 900344                      NaN                    NaN               NaN
# 900459                      NaN                    NaN               NaN
# 900221                      NaN                    NaN               NaN
# 900570                      NaN                    NaN               NaN
# 900092                      NaN                    NaN               NaN
# ...                         ...                    ...               ...
# 9003972                     NaN                    NaN               NaN
# 900097                      NaN                    NaN               NaN
# 900498                      NaN                    NaN               NaN
# 900276                      NaN                    NaN               NaN
# 900406                      NaN                    NaN               NaN
#
# [502 rows x 218 columns]

# %%
# add o_scorad column
rclr_df = rclr_df.merge(metadata[['o_scorad']], left_index=True, right_index=True)

# add pid column
rclr_df = rclr_df.merge(metadata[['pid']], left_index=True, right_index=True)

# add area column
rclr_df = rclr_df.merge(metadata[['area']], left_index=True, right_index=True)

# Convert 'o_scorad' to numeric (coerce errors to NaN)
rclr_df['o_scorad'] = pd.to_numeric(metadata['o_scorad'], errors='coerce')

# Drop rows with missing SCORAD values
rclr_df = rclr_df.dropna(subset=['o_scorad'])

# Filter for only Umtata samples (those with 'UM' in pid)
rclr_df = rclr_df[rclr_df['area'].str.contains('Umtata', na=False)]

rclr_df
# Out:
#           g__Streptococcus   g__Staphylococcus       g__  \
# 900459            2.557814            0.711987 -0.792090
# 900221                 NaN            1.126537       NaN
# 900466            2.883453                 NaN       NaN
# 900301           -1.458702            3.682961 -1.458702
# 900423                 NaN            1.932297  1.599857
# ...                    ...                 ...       ...
# 900484            2.550841                 NaN       NaN
# 900294           -0.083496           -1.113116  2.352620
# 9003972           3.143951            2.738485  1.559830
# 900276                 NaN           -0.574105  1.418325
# 900406                 NaN                 NaN       NaN
#
#           g__Haemophilus_D_734546   g__Corynebacterium   g__Acinetobacter  \
# 900459                   3.389960                  NaN                NaN
# 900221                        NaN            -1.476152          -1.070687
# 900466                        NaN            -2.246445                NaN
# 900301                        NaN            -0.765556                NaN
# 900423                        NaN            -1.969675           0.863538
# ...                           ...                  ...                ...
# 900484                   0.547112            -0.551500                NaN
# 900294                        NaN            -1.336259          -1.623941
# 9003972                  0.173536             0.733152           0.173536
# 900276                        NaN             0.892232           0.119042
# 900406                        NaN                  NaN                NaN
#
#           g__Prevotella   g__Micrococcus   g__Dolosigranulum  \
# 900459         0.124201        -1.485236            3.405112
# 900221              NaN              NaN                 NaN
# 900466              NaN              NaN           -0.637008
# 900301              NaN              NaN                 NaN
# 900423              NaN        -0.097874                 NaN
# ...                 ...              ...                 ...
# 900484              NaN              NaN            0.489953
# 900294              NaN              NaN                 NaN
# 9003972        1.272148        -0.114146                 NaN
# 900276         1.418325              NaN                 NaN
# 900406              NaN              NaN                 NaN
#
#           g__Cutibacterium  ...   g__Enterenecus   g__Evtepia   g__Fimenecus  \
# 900459                 NaN  ...              NaN          NaN            NaN
# 900221                 NaN  ...              NaN          NaN            NaN
# 900466                 NaN  ...              NaN          NaN            NaN
# 900301                 NaN  ...              NaN          NaN            NaN
# 900423            1.050749  ...              NaN          NaN            NaN
# ...                    ...  ...              ...          ...            ...
# 900484                 NaN  ...              NaN          NaN            NaN
# 900294            1.852157  ...              NaN          NaN            NaN
# 9003972           2.450803  ...              NaN          NaN            NaN
# 900276            3.063481  ...              NaN          NaN            NaN
# 900406                 NaN  ...              NaN          NaN            NaN
#
#           g__CAG-41   g__Selenomonas_B_42762   g__Facklamia_A_322620  \
# 900459          NaN                      NaN                     NaN
# 900221          NaN                      NaN                     NaN
# 900466          NaN                      NaN                     NaN
# 900301          NaN                      NaN                     NaN
# 900423          NaN                      NaN                     NaN
# ...             ...                      ...                     ...
# 900484          NaN                      NaN                     NaN
# 900294          NaN                      NaN                     NaN
# 9003972         NaN                      NaN                     NaN
# 900276          NaN                      NaN                     NaN
# 900406          NaN                      NaN                     NaN
#
#           g__Eubacterium_G  o_scorad        pid    area
# 900459                 NaN      44.0  Ca-145-LM  Umtata
# 900221                 NaN      34.0  Ca-101-ID  Umtata
# 900466                 NaN      43.0  Ca-147-LJ  Umtata
# 900301                 NaN      42.0  Ca-112-AM  Umtata
# 900423                 NaN      32.0  Ca-133-LT  Umtata
# ...                    ...       ...        ...     ...
# 900484                 NaN      42.0  Ca-153-MN  Umtata
# 900294                 NaN      23.0  Ca-113-MN  Umtata
# 9003972                NaN      54.0  Ca-125-IM  Umtata
# 900276                 NaN      52.0  Ca-111-IN  Umtata
# 900406                 NaN      28.0  Ca-127-OM  Umtata
#
# [177 rows x 221 columns]

# %%
# Model: does Staph predict Strep after adjusting for severity?
# Subset and clean data
model_df = rclr_df[[' g__Streptococcus', ' g__Staphylococcus', 'o_scorad', 'pid']].dropna()
# Remove leading spaces in column names
model_df.columns = [col.strip() for col in model_df.columns]

model_df
# Out:
#          g__Streptococcus  g__Staphylococcus  o_scorad        pid
# 900459           2.557814           0.711987      44.0  Ca-145-LM
# 900301          -1.458702           3.682961      42.0  Ca-112-AM
# 900422           4.338956          -0.091860      43.0  Ca-132-LD
# 900329           0.917941           4.577833      39.0  Ca-119-AM
# 900456           3.122239           1.634162      53.0  Ca-144-HN
# ...                   ...                ...       ...        ...
# 900434           3.298513           1.610432      39.0  Ca-138-SM
# 900501           3.786917           1.453241      54.0  Ca-158-LC
# 900304           4.736879          -1.034561      33.0  Ca-115-OM
# 900294          -0.083496          -1.113116      23.0  Ca-113-MN
# 9003972          3.143951           2.738485      54.0  Ca-125-IM
#
# [118 rows x 4 columns]

# %%
model = smf.mixedlm("Q('g__Streptococcus') ~ Q('g__Staphylococcus') + o_scorad + pid",  # DependentVariable ~ Predictor1 + Predictor2
                    data=model_df, 
                    groups=model_df["pid"])
result = model.fit()
print(result.summary())
# Out:
#                Mixed Linear Model Regression Results
# ===================================================================
# Model:            MixedLM Dependent Variable: Q('g__Streptococcus')
# No. Observations: 118     Method:             REML
# No. Groups:       55      Scale:              2.3604
# Min. group size:  1       Log-Likelihood:     -120.3721
# Max. group size:  6       Converged:          No
# Mean group size:  2.1
# -------------------------------------------------------------------
#                          Coef.  Std.Err.   z    P>|z| [0.025 0.975]
# -------------------------------------------------------------------
# Intercept               -16.769
# pid[T.Ca-103-BT]          1.211    3.080  0.393 0.694 -4.825  7.248
# pid[T.Ca-104-SB]          9.410
# pid[T.Ca-105-LX]         10.298
# pid[T.Ca-106-NM]         -1.572
# pid[T.Ca-107-BM]          5.794
# pid[T.Ca-108-EJ]         -3.179
# pid[T.Ca-109-BJ]          0.274
# pid[T.Ca-110-LN]          1.304
# pid[T.Ca-112-AM]         -0.201
# pid[T.Ca-113-MN]          5.920
# pid[T.Ca-114-QT]         -1.967
# pid[T.Ca-115-OM]          5.364
# pid[T.Ca-116-AN]          5.971
# pid[T.Ca-117-SM]         -7.874
# pid[T.Ca-118-AS]         -1.372
# pid[T.Ca-119-AM]          1.793
# pid[T.Ca-120-ST]          3.864    2.875  1.344 0.179 -1.771  9.499
# pid[T.Ca-121-BT]          9.237
# pid[T.Ca-122-UK]          9.745
# pid[T.Ca-123-PG]          5.653
# pid[T.Ca-124-AB]          2.250
# pid[T.Ca-125-IM]         -5.495
# pid[T.Ca-126-KB]        -16.270
# pid[T.Ca-127-OM]          6.932
# pid[T.Ca-128-SN]          2.972
# pid[T.Ca-129-AJ]         -0.316
# pid[T.Ca-130-PM]         -4.365
# pid[T.Ca-131-PM]          2.458
# pid[T.Ca-132-LD]          0.610
# pid[T.Ca-133-LT]          1.922
# pid[T.Ca-134-IT]         -5.797
# pid[T.Ca-135-NS]        -14.466
# pid[T.Ca-136-OM]        -17.227
# pid[T.Ca-137-TM]        -10.656
# pid[T.Ca-138-SM]          2.195
# pid[T.Ca-139-OS]         -1.331
# pid[T.Ca-141-TC]        -16.335
# pid[T.Ca-144-HN]         -5.042
# pid[T.Ca-145-LM]          0.137
# pid[T.Ca-146-SM]          2.247
# pid[T.Ca-147-LJ]         -2.637
# pid[T.Ca-148-AL]          9.445
# pid[T.Ca-149-LM]         -7.361
# pid[T.Ca-150-ZS]          7.939
# pid[T.Ca-151-QR]          0.462
# pid[T.Ca-152-HN]         -4.986
# pid[T.Ca-153-MN]          0.771
# pid[T.Ca-154-OS]          0.896
# pid[T.Ca-155-LS]          2.425
# pid[T.Ca-158-LC]         -5.724
# pid[T.Ca-159-AS]          4.919
# pid[T.Ca-160-LB]         15.228
# pid[T.Ca-161-OM]         10.573
# pid[T.Co-109-AG]         -2.944
# Q('g__Staphylococcus')   -0.309    0.109 -2.841 0.004 -0.522 -0.096
# o_scorad                  0.453
# Group Var                 2.360
# ===================================================================
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with lbfgs
#   warnings.warn(
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2200: ConvergenceWarning: Retrying MixedLM optimization with cg
#   warnings.warn(
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/base/model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2206: ConvergenceWarning: MixedLM optimization failed, trying a different optimizer may help.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2218: ConvergenceWarning: Gradient optimization failed, |grad| = 0.142857
#   warnings.warn(msg, ConvergenceWarning)
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2261: ConvergenceWarning: The Hessian matrix at the estimated parameter values is not positive definite.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2704: RuntimeWarning: invalid value encountered in sqrt
#   sdf[0:self.k_fe, 1] = np.sqrt(np.diag(self.cov_params()[0:self.k_fe]))

# %%
# Fit mixed models to get residuals adjusted for SCORAD and pid
resid_model_strep = smf.mixedlm("Q('g__Streptococcus') ~ o_scorad", data=model_df, groups=model_df['pid']).fit()
resid_model_staph = smf.mixedlm("Q('g__Staphylococcus') ~ o_scorad", data=model_df, groups=model_df['pid']).fit()

# Store residuals
model_df['strep_resid'] = resid_model_strep.resid
model_df['staph_resid'] = resid_model_staph.resid

# Plot residuals
plt.figure(figsize=(6, 4.5))

sns.regplot(
    data=model_df,
    x='staph_resid',
    y='strep_resid',
    scatter_kws={"alpha": 0.6},
    line_kws={"color": "black"}
)

# Correlation for annotation
r, p = pearsonr(model_df['staph_resid'], model_df['strep_resid'])
plt.text(0.97, 0.97, f'Pearson r = {r:.2f}\np = {p:.3e}',
         transform=plt.gca().transAxes,
         verticalalignment='top',
         horizontalalignment='right',
         fontsize=13)

# Labeling
plt.xlabel('Staph (RCLR residuals, adj. SCORAD + subject)', fontsize=13)
plt.ylabel('Strep (RCLR residuals, adj. SCORAD + subject)', fontsize=13)
plt.suptitle('Linear Regression', fontsize=18, x=0.55, y=0.96)
plt.title('Strep ~ Staph | adjusted for SCORAD and subject', fontsize=15)
plt.tight_layout()
plt.xticks(fontsize=13)
plt.yticks(fontsize=13)
plt.xlabel('Staph (RCLR residuals)', fontsize=13)
plt.ylabel('Strep (RCLR residuals)', fontsize=13)

# Save figure
plt.savefig("../Plots/Analysis_figures/Severity_Correlations/Staph_Strep_effect_model_adjusted-Umtata.png", dpi=600)
# Out:
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:1634: UserWarning: Random effects covariance is singular
#   warnings.warn(msg)
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/statsmodels/regression/mixed_linear_model.py:2237: ConvergenceWarning: The MLE may be on the boundary of the parameter space.
#   warnings.warn(msg, ConvergenceWarning)
