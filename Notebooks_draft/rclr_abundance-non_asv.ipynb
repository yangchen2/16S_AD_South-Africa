# %% [markdown]
# # RCLR severity correlation boxplots (non-asv)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import biom
from biom import load_table
import numpy as np
from scipy.stats import spearmanr
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
import itertools
import matplotlib.patches
from scipy.stats import pearsonr

# %%
# Load the metadata
metadata_path = '../Data/Metadata/updated_clean_ant_skin_metadata.tab'
metadata = pd.read_csv(metadata_path, sep='\t')

metadata['#sample-id'] = metadata['#sample-id'].str.replace('_', '')
# Set Sample-ID as the index for the metadata dataframe 
metadata = metadata.set_index('#sample-id')


# Create group column based on case_type to simplify group names
metadata['group'] = metadata['case_type'].map({
    'case-lesional skin': 'skin-ADL',
    'case-nonlesional skin': 'skin-ADNL', 
    'control-nonlesional skin': 'skin-H',
    'case-anterior nares': 'nares-AD',
    'control-anterior nares': 'nares-H'
})



metadata
# Out:
#             PlateNumber PlateLocation     i5 i5Sequence     i7 i7Sequence  \
# #sample-id
# Ca009STL              1            A1  SA501   ATCGTACG  SA701   CGAGAGTT
# 900221                1            B1  SA502   ACTATCTG  SA701   CGAGAGTT
# Ca010EBL              1            C1  SA503   TAGCGAGT  SA701   CGAGAGTT
# 900460                1            D1  SA504   CTGCGTGT  SA701   CGAGAGTT
# 900051                1            E1  SA505   TCATCGAG  SA701   CGAGAGTT
# ...                 ...           ...    ...        ...    ...        ...
# Ca006ONL2             6            H1  SA508   GACACCGT  SB701   CTCGACTT
# Ca006ONNL             6            F2  SA506   CGTGAGTG  SB702   CGAAGTAT
# Ca006ONNL2            6            H2  SA508   GACACCGT  SB702   CGAAGTAT
# Ca006ONPN             6            F3  SA506   CGTGAGTG  SB703   TAGCAGCT
# Ca006ONPN2            6            H3  SA508   GACACCGT  SB703   TAGCAGCT
#
#             identifier           Sequence      Plate ID Well location  ...  \
# #sample-id                                                             ...
# Ca009STL    SA701SA501  CGAGAGTT-ATCGTACG  1.010000e+21            A1  ...
# 900221      SA701SA502  CGAGAGTT-ACTATCTG  1.010000e+21            B1  ...
# Ca010EBL    SA701SA503  CGAGAGTT-TAGCGAGT  1.010000e+21            C1  ...
# 900460      SA701SA504  CGAGAGTT-CTGCGTGT  1.010000e+21            D1  ...
# 900051      SA701SA505  CGAGAGTT-TCATCGAG  1.010000e+21            E1  ...
# ...                ...                ...           ...           ...  ...
# Ca006ONL2   SB701SA508  CTCGACTT-GACACCGT  1.010000e+21            H1  ...
# Ca006ONNL   SB702SA506  CGAAGTAT-CGTGAGTG  1.010000e+21            F2  ...
# Ca006ONNL2  SB702SA508  CGAAGTAT-GACACCGT  1.010000e+21            H2  ...
# Ca006ONPN   SB703SA506  TAGCAGCT-CGTGAGTG  1.010000e+21            F3  ...
# Ca006ONPN2  SB703SA508  TAGCAGCT-GACACCGT  1.010000e+21            H3  ...
#
#                sex enrolment_date enrolment_season hiv_exposure hiv_status  \
# #sample-id
# Ca009STL      male      4/16/2015          Autumn     Unexposed   negative
# 900221      female      8/11/2015           Winter    Unexposed   negative
# Ca010EBL    female     11/20/2014           Spring    Unexposed   negative
# 900460      female      9/23/2015           Spring    Unexposed        NaN
# 900051        male      4/21/2015          Autumn     Unexposed   negative
# ...            ...            ...              ...          ...        ...
# Ca006ONL2   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONNL   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONNL2  female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONPN   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONPN2  female      3/25/2015           Autumn    Unexposed   negative
#
#            household_size o_scorad  \
# #sample-id
# Ca009STL              4.0       40
# 900221                7.0       34
# Ca010EBL              7.0       21
# 900460                4.0       40
# 900051                7.0       41
# ...                   ...      ...
# Ca006ONL2             3.0       34
# Ca006ONNL             3.0       34
# Ca006ONNL2            3.0       34
# Ca006ONPN             3.0       34
# Ca006ONPN2            3.0       34
#
#                                                  FWD_filepath  \
# #sample-id
# Ca009STL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900221      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca010EBL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900460      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900051      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# ...                                                       ...
# Ca006ONL2   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONNL   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONNL2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONPN   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONPN2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
#
#                                                  REV_filepath      group
# #sample-id
# Ca009STL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900221      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# Ca010EBL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900460      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900051      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# ...                                                       ...        ...
# Ca006ONL2   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# Ca006ONNL   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...  skin-ADNL
# Ca006ONNL2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...  skin-ADNL
# Ca006ONPN   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   nares-AD
# Ca006ONPN2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   nares-AD
#
# [502 rows x 32 columns]

# %%
# Set microbiome type
microbiome_type = 'nares'

# %%
# Read in table at ASV level
biom_path = '../Data/Tables/Absolute_Abundance_Tables/209766_filtered_by_prevalence_1pct_rare_Genus.biom'
biom_tbl = load_table(biom_path)
df = pd.DataFrame(biom_tbl.to_dataframe().T)

# delete the prefix from the index
df.index = df.index.str.replace('15564.', '')

# Get samples that start with 'skin' in metadata
skin_samples = metadata[metadata['group'].str.startswith(microbiome_type)].index

# Filter df to keep only skin samples
df = df.loc[skin_samples]
df
# Out:
#             g__Streptococcus  g__Staphylococcus    g__  \
# #sample-id
# Ca009STPN               51.0                  0   32.0
# 900223                   3.0                  0      0
# Ca010EBPN               83.0                4.0  100.0
# 900462                 169.0                2.0   36.0
# 900053                 188.0                  0      0
# ...                      ...                ...    ...
# 9003992                 31.0                5.0   10.0
# 900402                  21.0               74.0   20.0
# 9004022                  9.0                  0   14.0
# Ca006ONPN                1.0                6.0    2.0
# Ca006ONPN2               2.0              151.0   36.0
#
#             g__Haemophilus_D_734546  g__Corynebacterium  g__Acinetobacter  \
# #sample-id
# Ca009STPN                         0               193.0                 0
# 900223                            0                23.0                 0
# Ca010EBPN                         0                55.0                 0
# 900462                         36.0                73.0                 0
# 900053                        144.0                   0                 0
# ...                             ...                 ...               ...
# 9003992                           0               148.0                 0
# 900402                            0               119.0              21.0
# 9004022                       301.0                11.0                 0
# Ca006ONPN                      69.0                45.0                 0
# Ca006ONPN2                     20.0                38.0                 0
#
#             g__Prevotella  g__Micrococcus  g__Dolosigranulum  \
# #sample-id
# Ca009STPN               0               0               48.0
# 900223                  0               0                2.0
# Ca010EBPN             8.0               0               23.0
# 900462                7.0             4.0                3.0
# 900053                  0               0                1.0
# ...                   ...             ...                ...
# 9003992               5.0               0               60.0
# 900402                  0            14.0                  0
# 9004022               4.0               0                6.0
# Ca006ONPN               0               0              227.0
# Ca006ONPN2              0               0               81.0
#
#             g__Cutibacterium  ...  g__Eubacterium_M  g__Lachnospira  \
# #sample-id                    ...
# Ca009STPN                  0  ...                 0               0
# 900223                     0  ...                 0               0
# Ca010EBPN               29.0  ...                 0               0
# 900462                   1.0  ...                 0               0
# 900053                   1.0  ...                 0               0
# ...                      ...  ...               ...             ...
# 9003992                  4.0  ...                 0               0
# 900402                   7.0  ...                 0               0
# 9004022                    0  ...                 0               0
# Ca006ONPN                  0  ...                 0               0
# Ca006ONPN2              22.0  ...                 0               0
#
#             g__Helcococcus  g__Enterenecus  g__Evtepia  g__Fimenecus  \
# #sample-id
# Ca009STPN                0               0           0             0
# 900223                   0               0           0             0
# Ca010EBPN                0               0           0             0
# 900462                   0               0           0             0
# 900053                   0               0           0             0
# ...                    ...             ...         ...           ...
# 9003992                  0               0           0             0
# 900402                   0               0           0             0
# 9004022                  0               0           0             0
# Ca006ONPN                0               0           0             0
# Ca006ONPN2               0               0           0             0
#
#             g__CAG-41  g__Selenomonas_B_42762  g__Facklamia_A_322620  \
# #sample-id
# Ca009STPN           0                       0                      0
# 900223              0                       0                      0
# Ca010EBPN           0                       0                      0
# 900462              0                       0                      0
# 900053              0                       0                      0
# ...               ...                     ...                    ...
# 9003992             0                       0                      0
# 900402              0                       0                      0
# 9004022             0                       0                      0
# Ca006ONPN           0                       0                      0
# Ca006ONPN2          0                       0                      0
#
#             g__Eubacterium_G
# #sample-id
# Ca009STPN                  0
# 900223                     0
# Ca010EBPN                  0
# 900462                     0
# 900053                     0
# ...                      ...
# 9003992                    0
# 900402                     0
# 9004022                    0
# Ca006ONPN                  0
# Ca006ONPN2                 0
#
# [197 rows x 218 columns]

# %%
def rclr_transform(df, pseudocount=1e-6):
    """
    Applies Robust Centered Log-Ratio (RCLR) transformation to a DataFrame.
    Zeros are ignored in the geometric mean calculation per sample.
    """
    # Convert sparse to dense if needed
    df = df.sparse.to_dense()

    # Replace 0 with np.nan to ignore in log and mean
    df_masked = df.replace(0, np.nan)

    # Apply log (with pseudocount only where needed)
    log_df = np.log(df_masked + pseudocount)

    # Subtract mean of each row (feature)
    rclr_df = log_df.sub(log_df.mean(axis=1, skipna=True), axis=0)

    return rclr_df



rclr_df = rclr_transform(df)

# %%
df_rclr = rclr_transform(df)
df_rclr
# Out:
#             g__Streptococcus  g__Staphylococcus       g__  \
# #sample-id
# Ca009STPN           1.302853                NaN  0.836764
# 900223             -1.194695                NaN       NaN
# Ca010EBPN           1.786005          -1.246541  1.972335
# 900462              3.839613          -0.597138  2.293233
# 900053              4.044725                NaN       NaN
# ...                      ...                ...       ...
# 9003992             2.011916           0.187367  0.880514
# 900402              1.352545           2.612087  1.303754
# 9004022             0.252154                NaN  0.693986
# Ca006ONPN          -2.658437          -0.866678 -1.965290
# Ca006ONPN2         -2.651532           1.672600  0.238839
#
#             g__Haemophilus_D_734546  g__Corynebacterium  g__Acinetobacter  \
# #sample-id
# Ca009STPN                       NaN            2.633718               NaN
# 900223                          NaN            0.842187               NaN
# Ca010EBPN                       NaN            1.374498               NaN
# 900462                     2.293233            3.000174               NaN
# 900053                     3.778096                 NaN               NaN
# ...                             ...                 ...               ...
# 9003992                         NaN            3.575142               NaN
# 900402                          NaN            3.087146          1.352545
# 9004022                    3.762039            0.452824               NaN
# Ca006ONPN                  1.575669            1.148225               NaN
# Ca006ONPN2                -0.348947            0.292907               NaN
#
#             g__Prevotella  g__Micrococcus  g__Dolosigranulum  \
# #sample-id
# Ca009STPN             NaN             NaN           1.242229
# 900223                NaN             NaN          -1.600160
# Ca010EBPN       -0.553394             NaN           0.502659
# 900462           0.655625        0.096009          -0.191673
# 900053                NaN             NaN          -1.191716
# ...                   ...             ...                ...
# 9003992          0.187367             NaN           2.672274
# 900402                NaN        0.947079                NaN
# 9004022         -0.558776             NaN          -0.153311
# Ca006ONPN             NaN             NaN           2.766512
# Ca006ONPN2            NaN             NaN           1.049770
#
#             g__Cutibacterium  ...  g__Eubacterium_M  g__Lachnospira  \
# #sample-id                    ...
# Ca009STPN                NaN  ...               NaN             NaN
# 900223                   NaN  ...               NaN             NaN
# Ca010EBPN           0.734460  ...               NaN             NaN
# 900462             -1.290285  ...               NaN             NaN
# 900053             -1.191716  ...               NaN             NaN
# ...                      ...  ...               ...             ...
# 9003992            -0.035776  ...               NaN             NaN
# 900402              0.253932  ...               NaN             NaN
# 9004022                  NaN  ...               NaN             NaN
# Ca006ONPN                NaN  ...               NaN             NaN
# Ca006ONPN2         -0.253637  ...               NaN             NaN
#
#             g__Helcococcus  g__Enterenecus  g__Evtepia  g__Fimenecus  \
# #sample-id
# Ca009STPN              NaN             NaN         NaN           NaN
# 900223                 NaN             NaN         NaN           NaN
# Ca010EBPN              NaN             NaN         NaN           NaN
# 900462                 NaN             NaN         NaN           NaN
# 900053                 NaN             NaN         NaN           NaN
# ...                    ...             ...         ...           ...
# 9003992                NaN             NaN         NaN           NaN
# 900402                 NaN             NaN         NaN           NaN
# 9004022                NaN             NaN         NaN           NaN
# Ca006ONPN              NaN             NaN         NaN           NaN
# Ca006ONPN2             NaN             NaN         NaN           NaN
#
#             g__CAG-41  g__Selenomonas_B_42762  g__Facklamia_A_322620  \
# #sample-id
# Ca009STPN         NaN                     NaN                    NaN
# 900223            NaN                     NaN                    NaN
# Ca010EBPN         NaN                     NaN                    NaN
# 900462            NaN                     NaN                    NaN
# 900053            NaN                     NaN                    NaN
# ...               ...                     ...                    ...
# 9003992           NaN                     NaN                    NaN
# 900402            NaN                     NaN                    NaN
# 9004022           NaN                     NaN                    NaN
# Ca006ONPN         NaN                     NaN                    NaN
# Ca006ONPN2        NaN                     NaN                    NaN
#
#             g__Eubacterium_G
# #sample-id
# Ca009STPN                NaN
# 900223                   NaN
# Ca010EBPN                NaN
# 900462                   NaN
# 900053                   NaN
# ...                      ...
# 9003992                  NaN
# 900402                   NaN
# 9004022                  NaN
# Ca006ONPN                NaN
# Ca006ONPN2               NaN
#
# [197 rows x 218 columns]

# %%
df_rclr = df_rclr.merge(metadata[['o_scorad']], left_index=True, right_index=True)
df_rclr = df_rclr.merge(metadata[['group']], left_index=True, right_index=True)
df_rclr = df_rclr.merge(metadata[['area']], left_index=True, right_index=True)

# Convert 'o_scorad' to numeric (coerce errors to NaN)
df_rclr['o_scorad'] = pd.to_numeric(metadata['o_scorad'], errors='coerce')

# Drop rows with missing SCORAD values
df_rclr = df_rclr.dropna(subset=['o_scorad'])
df_rclr
# Out:
#              g__Streptococcus   g__Staphylococcus       g__  \
# #sample-id
# Ca009STPN            1.302853                 NaN  0.836764
# 900223              -1.194695                 NaN       NaN
# Ca010EBPN            1.786005           -1.246541  1.972335
# 900462               3.839613           -0.597138  2.293233
# 900053               4.044725                 NaN       NaN
# ...                       ...                 ...       ...
# 900399              -1.158252            3.368956  1.582588
# 9003992              2.011916            0.187367  0.880514
# 9004022              0.252154                 NaN  0.693986
# Ca006ONPN           -2.658437           -0.866678 -1.965290
# Ca006ONPN2          -2.651532            1.672600  0.238839
#
#              g__Haemophilus_D_734546   g__Corynebacterium   g__Acinetobacter  \
# #sample-id
# Ca009STPN                        NaN             2.633718                NaN
# 900223                           NaN             0.842187                NaN
# Ca010EBPN                        NaN             1.374498                NaN
# 900462                      2.293233             3.000174                NaN
# 900053                      3.778096                  NaN                NaN
# ...                              ...                  ...                ...
# 900399                           NaN             0.546496           0.345825
# 9003992                          NaN             3.575142                NaN
# 9004022                     3.762039             0.452824                NaN
# Ca006ONPN                   1.575669             1.148225                NaN
# Ca006ONPN2                 -0.348947             0.292907                NaN
#
#              g__Prevotella   g__Micrococcus   g__Dolosigranulum  \
# #sample-id
# Ca009STPN              NaN              NaN            1.242229
# 900223                 NaN              NaN           -1.600160
# Ca010EBPN        -0.553394              NaN            0.502659
# 900462            0.655625         0.096009           -0.191673
# 900053                 NaN              NaN           -1.191716
# ...                    ...              ...                 ...
# 900399                 NaN        -1.158252                 NaN
# 9003992           0.187367              NaN            2.672274
# 9004022          -0.558776              NaN           -0.153311
# Ca006ONPN              NaN              NaN            2.766512
# Ca006ONPN2             NaN              NaN            1.049770
#
#              g__Cutibacterium  ...   g__Enterenecus   g__Evtepia  \
# #sample-id                     ...
# Ca009STPN                 NaN  ...              NaN          NaN
# 900223                    NaN  ...              NaN          NaN
# Ca010EBPN            0.734460  ...              NaN          NaN
# 900462              -1.290285  ...              NaN          NaN
# 900053              -1.191716  ...              NaN          NaN
# ...                       ...  ...              ...          ...
# 900399               2.425267  ...              NaN          NaN
# 9003992             -0.035776  ...              NaN          NaN
# 9004022                   NaN  ...              NaN          NaN
# Ca006ONPN                 NaN  ...              NaN          NaN
# Ca006ONPN2          -0.253637  ...              NaN          NaN
#
#              g__Fimenecus   g__CAG-41   g__Selenomonas_B_42762  \
# #sample-id
# Ca009STPN             NaN         NaN                      NaN
# 900223                NaN         NaN                      NaN
# Ca010EBPN             NaN         NaN                      NaN
# 900462                NaN         NaN                      NaN
# 900053                NaN         NaN                      NaN
# ...                   ...         ...                      ...
# 900399                NaN         NaN                      NaN
# 9003992               NaN         NaN                      NaN
# 9004022               NaN         NaN                      NaN
# Ca006ONPN             NaN         NaN                      NaN
# Ca006ONPN2            NaN         NaN                      NaN
#
#              g__Facklamia_A_322620   g__Eubacterium_G  o_scorad     group  \
# #sample-id
# Ca009STPN                      NaN                NaN      40.0  nares-AD
# 900223                         NaN                NaN      34.0  nares-AD
# Ca010EBPN                      NaN                NaN      21.0  nares-AD
# 900462                         NaN                NaN      40.0  nares-AD
# 900053                         NaN                NaN      41.0  nares-AD
# ...                            ...                ...       ...       ...
# 900399                         NaN                NaN      54.0  nares-AD
# 9003992                        NaN                NaN      54.0  nares-AD
# 9004022                        NaN                NaN      38.0  nares-AD
# Ca006ONPN                      NaN                NaN      34.0  nares-AD
# Ca006ONPN2                     NaN                NaN      34.0  nares-AD
#
#                  area
# #sample-id
# Ca009STPN   Cape Town
# 900223         Umtata
# Ca010EBPN   Cape Town
# 900462         Umtata
# 900053      Cape Town
# ...               ...
# 900399         Umtata
# 9003992        Umtata
# 9004022        Umtata
# Ca006ONPN   Cape Town
# Ca006ONPN2  Cape Town
#
# [102 rows x 221 columns]

# %%
# df_rclr = df_rclr[(df_rclr['group'] == 'skin-ADL')]
df_rclr = df_rclr[(df_rclr['group'] == 'nares-AD')]

df_rclr
# Out:
#              g__Streptococcus   g__Staphylococcus       g__  \
# #sample-id
# Ca009STPN            1.302853                 NaN  0.836764
# 900223              -1.194695                 NaN       NaN
# Ca010EBPN            1.786005           -1.246541  1.972335
# 900462               3.839613           -0.597138  2.293233
# 900053               4.044725                 NaN       NaN
# ...                       ...                 ...       ...
# 900399              -1.158252            3.368956  1.582588
# 9003992              2.011916            0.187367  0.880514
# 9004022              0.252154                 NaN  0.693986
# Ca006ONPN           -2.658437           -0.866678 -1.965290
# Ca006ONPN2          -2.651532            1.672600  0.238839
#
#              g__Haemophilus_D_734546   g__Corynebacterium   g__Acinetobacter  \
# #sample-id
# Ca009STPN                        NaN             2.633718                NaN
# 900223                           NaN             0.842187                NaN
# Ca010EBPN                        NaN             1.374498                NaN
# 900462                      2.293233             3.000174                NaN
# 900053                      3.778096                  NaN                NaN
# ...                              ...                  ...                ...
# 900399                           NaN             0.546496           0.345825
# 9003992                          NaN             3.575142                NaN
# 9004022                     3.762039             0.452824                NaN
# Ca006ONPN                   1.575669             1.148225                NaN
# Ca006ONPN2                 -0.348947             0.292907                NaN
#
#              g__Prevotella   g__Micrococcus   g__Dolosigranulum  \
# #sample-id
# Ca009STPN              NaN              NaN            1.242229
# 900223                 NaN              NaN           -1.600160
# Ca010EBPN        -0.553394              NaN            0.502659
# 900462            0.655625         0.096009           -0.191673
# 900053                 NaN              NaN           -1.191716
# ...                    ...              ...                 ...
# 900399                 NaN        -1.158252                 NaN
# 9003992           0.187367              NaN            2.672274
# 9004022          -0.558776              NaN           -0.153311
# Ca006ONPN              NaN              NaN            2.766512
# Ca006ONPN2             NaN              NaN            1.049770
#
#              g__Cutibacterium  ...   g__Enterenecus   g__Evtepia  \
# #sample-id                     ...
# Ca009STPN                 NaN  ...              NaN          NaN
# 900223                    NaN  ...              NaN          NaN
# Ca010EBPN            0.734460  ...              NaN          NaN
# 900462              -1.290285  ...              NaN          NaN
# 900053              -1.191716  ...              NaN          NaN
# ...                       ...  ...              ...          ...
# 900399               2.425267  ...              NaN          NaN
# 9003992             -0.035776  ...              NaN          NaN
# 9004022                   NaN  ...              NaN          NaN
# Ca006ONPN                 NaN  ...              NaN          NaN
# Ca006ONPN2          -0.253637  ...              NaN          NaN
#
#              g__Fimenecus   g__CAG-41   g__Selenomonas_B_42762  \
# #sample-id
# Ca009STPN             NaN         NaN                      NaN
# 900223                NaN         NaN                      NaN
# Ca010EBPN             NaN         NaN                      NaN
# 900462                NaN         NaN                      NaN
# 900053                NaN         NaN                      NaN
# ...                   ...         ...                      ...
# 900399                NaN         NaN                      NaN
# 9003992               NaN         NaN                      NaN
# 9004022               NaN         NaN                      NaN
# Ca006ONPN             NaN         NaN                      NaN
# Ca006ONPN2            NaN         NaN                      NaN
#
#              g__Facklamia_A_322620   g__Eubacterium_G  o_scorad     group  \
# #sample-id
# Ca009STPN                      NaN                NaN      40.0  nares-AD
# 900223                         NaN                NaN      34.0  nares-AD
# Ca010EBPN                      NaN                NaN      21.0  nares-AD
# 900462                         NaN                NaN      40.0  nares-AD
# 900053                         NaN                NaN      41.0  nares-AD
# ...                            ...                ...       ...       ...
# 900399                         NaN                NaN      54.0  nares-AD
# 9003992                        NaN                NaN      54.0  nares-AD
# 9004022                        NaN                NaN      38.0  nares-AD
# Ca006ONPN                      NaN                NaN      34.0  nares-AD
# Ca006ONPN2                     NaN                NaN      34.0  nares-AD
#
#                  area
# #sample-id
# Ca009STPN   Cape Town
# 900223         Umtata
# Ca010EBPN   Cape Town
# 900462         Umtata
# 900053      Cape Town
# ...               ...
# 900399         Umtata
# 9003992        Umtata
# 9004022        Umtata
# Ca006ONPN   Cape Town
# Ca006ONPN2  Cape Town
#
# [102 rows x 221 columns]

# %%
# Example input: list of bacterial taxa column names
taxa_list = [' g__Staphylococcus', ' g__Streptococcus', ' g__Micrococcus', ' g__Veillonella_A', ' g__Haemophilus_D_734546']

# Set up color map
area_colors = {'Cape Town': '#1f77b4', 'Umtata': '#ff7f0e'}  # Blue and orange

# Set up the figure with multiple subplots
fig, axes = plt.subplots(1, len(taxa_list), figsize=(len(taxa_list) * 2.5, 4), sharey=True)

for i, taxon in enumerate(taxa_list):
    ax = axes[i] if len(taxa_list) > 1 else axes  # handle single-subplot case

    # Drop missing values
    df_plot = df_rclr[['o_scorad', taxon, 'area']].dropna()

    # Plot each area with a different color
    for area, color in area_colors.items():
        subset = df_plot[df_plot['area'] == area]
        ax.scatter(subset['o_scorad'], subset[taxon], label=area, color=color, alpha=0.5, s=20)

    # Fit and plot regression line across all points
    sns.regplot(
        data=df_plot,
        x='o_scorad',
        y=taxon,
        scatter=False,
        line_kws={'color': 'black'},
        ax=ax
    )

    # Compute Pearson correlation
    r, pval = pearsonr(df_plot['o_scorad'], df_plot[taxon])
    ax.set_title(taxon.strip(), fontsize=14)
    ax.set_xlabel('SCORAD')
    if i == 0:
        ax.set_ylabel('RCLR Relative Abundance')
    else:
        ax.set_ylabel('')
    ax.text(0.05, 0.95, f"Pearson r = {r:.2f}\np = {pval:.1e}", transform=ax.transAxes,
            fontsize=12, va='top', ha='left', bbox=dict(facecolor='white', alpha=0.7, edgecolor='none'))

# Shared title and legend
fig.suptitle('Correlation Between Skin Bacteria and AD Severity', y=0.96, fontsize=18)
axes[0].legend(title='Area', loc='lower right')
plt.tight_layout()
plt.savefig('bacteria_vs_scorad_by_area.png', dpi=300)
