# %% [markdown]
# # Strep and severity score correlations

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import biom
from biom import load_table
import numpy as np
from scipy.stats import spearmanr
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
import itertools
import matplotlib.patches
from scipy.stats import pearsonr

# %%
# Load the metadata
metadata_path = '../Data/Metadata/updated_clean_ant_skin_metadata.tab'
metadata = pd.read_csv(metadata_path, sep='\t')

metadata['#sample-id'] = metadata['#sample-id'].str.replace('_', '')
# Set Sample-ID as the index for the metadata dataframe 
metadata = metadata.set_index('#sample-id')


# Create group column based on case_type to simplify group names
metadata['group'] = metadata['case_type'].map({
    'case-lesional skin': 'skin-ADL',
    'case-nonlesional skin': 'skin-ADNL', 
    'control-nonlesional skin': 'skin-H',
    'case-anterior nares': 'nares-AD',
    'control-anterior nares': 'nares-H'
})

metadata
# Out:
#             PlateNumber PlateLocation     i5 i5Sequence     i7 i7Sequence  \
# #sample-id
# Ca009STL              1            A1  SA501   ATCGTACG  SA701   CGAGAGTT
# 900221                1            B1  SA502   ACTATCTG  SA701   CGAGAGTT
# Ca010EBL              1            C1  SA503   TAGCGAGT  SA701   CGAGAGTT
# 900460                1            D1  SA504   CTGCGTGT  SA701   CGAGAGTT
# 900051                1            E1  SA505   TCATCGAG  SA701   CGAGAGTT
# ...                 ...           ...    ...        ...    ...        ...
# Ca006ONL2             6            H1  SA508   GACACCGT  SB701   CTCGACTT
# Ca006ONNL             6            F2  SA506   CGTGAGTG  SB702   CGAAGTAT
# Ca006ONNL2            6            H2  SA508   GACACCGT  SB702   CGAAGTAT
# Ca006ONPN             6            F3  SA506   CGTGAGTG  SB703   TAGCAGCT
# Ca006ONPN2            6            H3  SA508   GACACCGT  SB703   TAGCAGCT
#
#             identifier           Sequence      Plate ID Well location  ...  \
# #sample-id                                                             ...
# Ca009STL    SA701SA501  CGAGAGTT-ATCGTACG  1.010000e+21            A1  ...
# 900221      SA701SA502  CGAGAGTT-ACTATCTG  1.010000e+21            B1  ...
# Ca010EBL    SA701SA503  CGAGAGTT-TAGCGAGT  1.010000e+21            C1  ...
# 900460      SA701SA504  CGAGAGTT-CTGCGTGT  1.010000e+21            D1  ...
# 900051      SA701SA505  CGAGAGTT-TCATCGAG  1.010000e+21            E1  ...
# ...                ...                ...           ...           ...  ...
# Ca006ONL2   SB701SA508  CTCGACTT-GACACCGT  1.010000e+21            H1  ...
# Ca006ONNL   SB702SA506  CGAAGTAT-CGTGAGTG  1.010000e+21            F2  ...
# Ca006ONNL2  SB702SA508  CGAAGTAT-GACACCGT  1.010000e+21            H2  ...
# Ca006ONPN   SB703SA506  TAGCAGCT-CGTGAGTG  1.010000e+21            F3  ...
# Ca006ONPN2  SB703SA508  TAGCAGCT-GACACCGT  1.010000e+21            H3  ...
#
#                sex enrolment_date enrolment_season hiv_exposure hiv_status  \
# #sample-id
# Ca009STL      male      4/16/2015          Autumn     Unexposed   negative
# 900221      female      8/11/2015           Winter    Unexposed   negative
# Ca010EBL    female     11/20/2014           Spring    Unexposed   negative
# 900460      female      9/23/2015           Spring    Unexposed        NaN
# 900051        male      4/21/2015          Autumn     Unexposed   negative
# ...            ...            ...              ...          ...        ...
# Ca006ONL2   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONNL   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONNL2  female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONPN   female      3/25/2015           Autumn    Unexposed   negative
# Ca006ONPN2  female      3/25/2015           Autumn    Unexposed   negative
#
#            household_size o_scorad  \
# #sample-id
# Ca009STL              4.0       40
# 900221                7.0       34
# Ca010EBL              7.0       21
# 900460                4.0       40
# 900051                7.0       41
# ...                   ...      ...
# Ca006ONL2             3.0       34
# Ca006ONNL             3.0       34
# Ca006ONNL2            3.0       34
# Ca006ONPN             3.0       34
# Ca006ONPN2            3.0       34
#
#                                                  FWD_filepath  \
# #sample-id
# Ca009STL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900221      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca010EBL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900460      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900051      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# ...                                                       ...
# Ca006ONL2   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONNL   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONNL2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONPN   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONPN2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
#
#                                                  REV_filepath      group
# #sample-id
# Ca009STL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900221      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# Ca010EBL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900460      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900051      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# ...                                                       ...        ...
# Ca006ONL2   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# Ca006ONNL   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...  skin-ADNL
# Ca006ONNL2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...  skin-ADNL
# Ca006ONPN   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   nares-AD
# Ca006ONPN2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   nares-AD
#
# [502 rows x 32 columns]

# %%
# Read in table at ASV level
biom_path = '../Data/Tables/Absolute_Abundance_Tables/feature_table_with_tax_labels_Genus.biom'
# biom_path = '../Data/Tables/Absolute_Abundance_Tables/209766_filtered_by_prevalence_1pct_rare_Genus-ASV-non-collapse.biom'
biom_tbl = load_table(biom_path)
df = pd.DataFrame(biom_tbl.to_dataframe().T)

# delete the prefix from the index
df.index = df.index.str.replace('15564.', '')

# Get samples that don't start with 'skin' in metadata
skin_samples = metadata[metadata['group'].str.startswith('skin')].index

# Filter df to keep only skin samples
df = df.loc[skin_samples]
df
# Out:
#             g__Streptococcus_ASV-1  g__Streptococcus_ASV-2  \
# #sample-id
# Ca009STL                      15.0                       0
# 900221                           0                       0
# Ca010EBL                       8.0                       0
# 900460                        66.0                    44.0
# 900051                        30.0                       0
# ...                            ...                     ...
# 9004032                       66.0                       0
# Ca006ONL                      12.0                       0
# Ca006ONL2                        0                       0
# Ca006ONNL                      9.0                       0
# Ca006ONNL2                     5.0                     2.0
#
#             g__Corynebacterium_ASV-1  g__Corynebacterium_ASV-3  g___ASV-3  \
# #sample-id
# Ca009STL                           0                         0          0
# 900221                             0                         0          0
# Ca010EBL                           0                         0          0
# 900460                             0                         0       15.0
# 900051                             0                         0          0
# ...                              ...                       ...        ...
# 9004032                         99.0                         0          0
# Ca006ONL                           0                         0          0
# Ca006ONL2                          0                         0          0
# Ca006ONNL                          0                         0          0
# Ca006ONNL2                         0                         0          0
#
#             g__Bacillus_P_294101_ASV-2  g__Cutibacterium_ASV-1  g___ASV-18  \
# #sample-id
# Ca009STL                             0                    13.0           0
# 900221                               0                       0           0
# Ca010EBL                             0                     3.0           0
# 900460                               0                     4.0           0
# 900051                               0                    10.0         5.0
# ...                                ...                     ...         ...
# 9004032                              0                       0           0
# Ca006ONL                             0                    27.0           0
# Ca006ONL2                            0                       0           0
# Ca006ONNL                            0                     3.0           0
# Ca006ONNL2                           0                     1.0           0
#
#             g___ASV-28  g___ASV-25  ...  g__Blautia_A_141781_ASV-7  \
# #sample-id                          ...
# Ca009STL             0           0  ...                          0
# 900221               0           0  ...                          0
# Ca010EBL             0           0  ...                          0
# 900460               0         7.0  ...                          0
# 900051               0         2.0  ...                          0
# ...                ...         ...  ...                        ...
# 9004032              0           0  ...                          0
# Ca006ONL             0           0  ...                          0
# Ca006ONL2            0           0  ...                          0
# Ca006ONNL            0           0  ...                          0
# Ca006ONNL2           0           0  ...                          0
#
#             g___ASV-358  g__Peptoniphilus_A_ASV-7  g___ASV-154  g___ASV-169  \
# #sample-id
# Ca009STL              0                         0            0            0
# 900221                0                         0            0            0
# Ca010EBL              0                         0            0            0
# 900460                0                         0            0            0
# 900051                0                         0            0            0
# ...                 ...                       ...          ...          ...
# 9004032               0                         0            0            0
# Ca006ONL              0                         0            0            0
# Ca006ONL2             0                         0            0            0
# Ca006ONNL             0                         0            0            0
# Ca006ONNL2            0                         0            0            0
#
#             g__UBA952_ASV-1  g__Petroclostridium_ASV-1  \
# #sample-id
# Ca009STL                  0                          0
# 900221                    0                          0
# Ca010EBL                  0                          0
# 900460                    0                          0
# 900051                    0                          0
# ...                     ...                        ...
# 9004032                   0                          0
# Ca006ONL                  0                          0
# Ca006ONL2                 0                          0
# Ca006ONNL                 0                          0
# Ca006ONNL2                0                          0
#
#             g__Capnocytophaga_820690_ASV-4  g___ASV-202  \
# #sample-id
# Ca009STL                                 0            0
# 900221                                   0            0
# Ca010EBL                                 0            0
# 900460                                   0            0
# 900051                                   0            0
# ...                                    ...          ...
# 9004032                                  0            0
# Ca006ONL                                 0            0
# Ca006ONL2                                0            0
# Ca006ONNL                                0            0
# Ca006ONNL2                               0            0
#
#             g__Streptococcus_ASV-37
# #sample-id
# Ca009STL                          0
# 900221                            0
# Ca010EBL                          0
# 900460                            0
# 900051                            0
# ...                             ...
# 9004032                           0
# Ca006ONL                          0
# Ca006ONL2                         0
# Ca006ONNL                         0
# Ca006ONNL2                        0
#
# [305 rows x 2261 columns]

# %%
df.columns.tolist()
# Out:
# ['g__Streptococcus_ASV-1',
#  'g__Streptococcus_ASV-2',
#  'g__Corynebacterium_ASV-1',
#  'g__Corynebacterium_ASV-3',
#  'g___ASV-3',
#  'g__Bacillus_P_294101_ASV-2',
#  'g__Cutibacterium_ASV-1',
#  'g___ASV-18',
#  'g___ASV-28',
#  'g___ASV-25',
#  'g__Cutibacterium_ASV-2',
#  'g__Bifidobacterium_388775_ASV-4',
#  'g__Streptococcus_ASV-36',
#  'g__Haemophilus_D_734546_ASV-1',
#  'g__Dolosigranulum_ASV-1',
#  'g__Dolosigranulum_ASV-2',
#  'g__Haemophilus_D_734546_ASV-2',
#  'g__Staphylococcus_ASV-2',
#  'g__Staphylococcus_ASV-1',
#  'g__Micrococcus_ASV-2',
#  'g__Lactococcus_A_346120_ASV-1',
#  'g__Limosilactobacillus_ASV-1',
#  'g__Prevotella_ASV-1',
#  'g__Corynebacterium_ASV-11',
#  'g__Prevotella_ASV-2',
#  'g__Fusobacterium_C_ASV-3',
#  'g__Neisseria_563205_ASV-4',
#  'g__Arthrobacter_D_ASV-1',
#  'g__Gemella_ASV-2',
#  'g___ASV-51',
#  'g__Leptotrichia_A_993758_ASV-1',
#  'g__Porphyromonas_A_859423_ASV-2',
#  'g__Fusobacterium_C_ASV-2',
#  'g___ASV-6',
#  'g___ASV-65',
#  'g__Brachybacterium_ASV-2',
#  'g__Neisseria_563205_ASV-3',
#  'g__Veillonella_A_ASV-4',
#  'g__Sphingobacterium_ASV-5',
#  'g__Jeotgalicoccus_A_310962_ASV-2',
#  'g__Rothia_ASV-6',
#  'g__Bacillus_A_ASV-1',
#  'g__Psychrobacter_ASV-1',
#  'g__Psychrobacter_ASV-3',
#  'g__Staphylococcus_ASV-3',
#  'g__Acinetobacter_ASV-2',
#  'g__Corynebacterium_ASV-2',
#  'g__Acinetobacter_ASV-6',
#  'g__Micrococcus_ASV-1',
#  'g___ASV-16',
#  'g__Ruminococcus_E_ASV-1',
#  'g__Collinsella_ASV-1',
#  'g___ASV-7',
#  'g__Porphyromonas_A_859426_ASV-5',
#  'g__Alloprevotella_ASV-1',
#  'g__Deinococcus_B_ASV-3',
#  'g__Finegoldia_ASV-1',
#  'g__Prevotella_ASV-6',
#  'g__Prevotella_ASV-15',
#  'g__Faecalibacterium_ASV-2',
#  'g___ASV-81',
#  'g__Dictyoglomus_ASV-1',
#  'g__Dorea_A_ASV-1',
#  'g__Haemophilus_D_735815_ASV-1',
#  'g__Streptococcus_ASV-5',
#  'g__Anaerococcus_ASV-11',
#  'g__Roseburia_ASV-1',
#  'g__Oligella_ASV-1',
#  'g__Brachybacterium_ASV-1',
#  'g__Helcococcus_ASV-1',
#  'g__Microbacterium_A_383184_ASV-1',
#  'g___ASV-196',
#  'g__Intestinibacter_ASV-1',
#  'g__Agathobacter_164117_ASV-1',
#  'g__Peptostreptococcus_ASV-2',
#  'g__Roseburia_ASV-5',
#  'g__Aeromicrobium_ASV-1',
#  'g__Prevotella_ASV-3',
#  'g__Bifidobacterium_388775_ASV-6',
#  'g___ASV-62',
#  'g__Prevotella_ASV-38',
#  'g__Brevibacterium_ASV-2',
#  'g__Nocardioides_A_392796_ASV-1',
#  'g__Streptococcus_ASV-3',
#  'g__F0422_ASV-1',
#  'g__Paracoccus_ASV-1',
#  'g___ASV-2',
#  'g__Veillonella_A_ASV-8',
#  'g__Veillonella_A_ASV-1',
#  'g___ASV-4',
#  'g__Escherichia_710834_ASV-1',
#  'g__Corynebacterium_ASV-7',
#  'g__Acinetobacter_ASV-1',
#  'g__Citricoccus_384863_ASV-1',
#  'g__Neisseria_563205_ASV-2',
#  'g__Luteimonas_C_615545_ASV-1',
#  'g__Nocardioides_A_392796_ASV-3',
#  'g__Chryseomicrobium_303841_ASV-1',
#  'g___ASV-11',
#  'g__Paracoccus_ASV-3',
#  'g___ASV-123',
#  'g__Prevotella_ASV-11',
#  'g__Acinetobacter_ASV-13',
#  'g__Psychrobacter_ASV-2',
#  'g___ASV-179',
#  'g__Neisseria_563205_ASV-1',
#  'g__Massilia_ASV-1',
#  'g__Gemella_ASV-1',
#  'g__Paracoccus_ASV-9',
#  'g___ASV-101',
#  'g__Pontibacter_909804_ASV-1',
#  'g__Anaeroglobus_ASV-1',
#  'g__Peptoniphilus_A_ASV-2',
#  'g__Corynebacterium_ASV-6',
#  'g__Oliverpabstia_ASV-1',
#  'g__Chryseobacterium_796614_ASV-1',
#  'g__Sphingobium_A_485959_ASV-5',
#  'g__Lancefieldella_ASV-1',
#  'g___ASV-17',
#  'g__Pseudoxanthomonas_A_615282_ASV-1',
#  'g___ASV-48',
#  'g__Acinetobacter_ASV-5',
#  'g__Peptostreptococcus_ASV-4',
#  'g__Blautia_A_141781_ASV-2',
#  'g___ASV-126',
#  'g__Pleomorphomonas_ASV-1',
#  'g__Brevilactibacter_ASV-1',
#  'g__Leptotrichia_A_993758_ASV-7',
#  'g___ASV-22',
#  'g__Arenimonas_613591_ASV-1',
#  'g__Anaerococcus_ASV-1',
#  'g__Alicyclobacillus_I_ASV-1',
#  'g___ASV-54',
#  'g__Pauljensenia_ASV-1',
#  'g__Bacteroides_H_ASV-5',
#  'g__Acinetobacter_ASV-3',
#  'g__Brevundimonas_ASV-1',
#  'g__Sphingomicrobium_483265_ASV-2',
#  'g__Faecalibacillus_ASV-1',
#  'g___ASV-114',
#  'g___ASV-53',
#  'g__Granulicatella_ASV-1',
#  'g__SIO2C1_ASV-4',
#  'g__Roseomonas_A_507160_ASV-1',
#  'g__Urinicoccus_ASV-2',
#  'g__Anaerococcus_ASV-7',
#  'g__Paenibacillus_A_ASV-1',
#  'g__Aeromonas_ASV-1',
#  'g__Fusobacterium_C_ASV-6',
#  'g___ASV-66',
#  'g__Leptotrichia_A_993758_ASV-2',
#  'g__Chryseotalea_ASV-1',
#  'g___ASV-129',
#  'g__Actinotalea_ASV-1',
#  'g__Kingella_B_563201_ASV-2',
#  'g__Mesorhizobium_F_498388_ASV-1',
#  'g___ASV-186',
#  'g___ASV-19',
#  'g__Dialister_ASV-9',
#  'g__Prevotella_ASV-24',
#  'g__Anaerococcus_ASV-19',
#  'g___ASV-21',
#  'g__Blautia_A_141781_ASV-1',
#  'g__Novosphingobium_485350_ASV-2',
#  'g__Haemophilus_A_ASV-1',
#  'g___ASV-59',
#  'g___ASV-80',
#  'g__Novosphingobium_485351_ASV-3',
#  'g__Actinomyces_ASV-1',
#  'g__Exiguobacterium_A_ASV-1',
#  'g__Kingella_B_563201_ASV-1',
#  'g__Lachnospira_ASV-4',
#  'g__Mediterraneibacter_A_155507_ASV-4',
#  'g__Pseudorhodoferax_ASV-1',
#  'g__Brevibacterium_ASV-5',
#  'g__Brevundimonas_ASV-2',
#  'g__Peptoniphilus_A_ASV-1',
#  'g__Prevotella_ASV-4',
#  'g__Mucilaginibacter_A_ASV-1',
#  'g___ASV-1',
#  'g__Mucilaginibacter_A_ASV-5',
#  'g__Acinetobacter_ASV-14',
#  'g___ASV-27',
#  'g__Actinomyces_ASV-3',
#  'g__Fenollaria_ASV-1',
#  'g__Prevotella_ASV-19',
#  'g___ASV-143',
#  'g__Dermabacter_ASV-1',
#  'g___ASV-58',
#  'g__Pseudomonas_E_647464_ASV-4',
#  'g__Prevotella_ASV-29',
#  'g__F0422_ASV-2',
#  'g___ASV-60',
#  'g__Flavobacterium_ASV-13',
#  'g__Jeotgalicoccus_A_310962_ASV-3',
#  'g__Fusobacterium_C_ASV-1',
#  'g__Massilia_ASV-7',
#  'g__Veillonella_A_ASV-3',
#  'g__Prevotella_ASV-18',
#  'g__Prevotella_ASV-12',
#  'g___ASV-139',
#  'g__Prevotella_ASV-9',
#  'g__Prevotella_ASV-40',
#  'g__Prevotella_ASV-45',
#  'g__Prevotella_ASV-53',
#  'g__Rothia_ASV-2',
#  'g__Prevotella_ASV-16',
#  'g__Rothia_ASV-5',
#  'g__Centipeda_ASV-3',
#  'g__Porphyromonas_A_859423_ASV-1',
#  'g__Tannerella_ASV-1',
#  'g__Leptotrichia_A_993758_ASV-9',
#  'g__Campylobacter_A_ASV-1',
#  'g__Pauljensenia_ASV-4',
#  'g__Leptotrichia_A_993758_ASV-13',
#  'g__Corynebacterium_ASV-21',
#  'g__Anaeroglobus_ASV-2',
#  'g__Prevotella_ASV-43',
#  'g___ASV-42',
#  'g__Prevotella_ASV-34',
#  'g___ASV-98',
#  'g__SIO2C1_ASV-1',
#  'g__SIO2C1_ASV-2',
#  'g___ASV-5',
#  'g___ASV-9',
#  'g___ASV-32',
#  'g__Leuconostoc_B_ASV-1',
#  'g___ASV-23',
#  'g___ASV-94',
#  'g__Rubellimicrobium_ASV-2',
#  'g___ASV-26',
#  'g___ASV-31',
#  'g__Urinicoccus_ASV-1',
#  'g___ASV-109',
#  'g___ASV-57',
#  'g___ASV-334',
#  'g__Pleomorphomonas_ASV-3',
#  'g__Fen-455_ASV-1',
#  'g___ASV-49',
#  'g__Sphingobium_A_485959_ASV-1',
#  'g___ASV-91',
#  'g__Luteimonas_C_615545_ASV-2',
#  'g___ASV-192',
#  'g___ASV-33',
#  'g__Massilia_ASV-10',
#  'g___ASV-168',
#  'g___ASV-55',
#  'g__Weissella_A_338544_ASV-2',
#  'g__Peptoniphilus_B_226777_ASV-1',
#  'g___ASV-95',
#  'g__Dietzia_ASV-3',
#  'g__Empedobacter_790298_ASV-1',
#  'g__Massilia_ASV-5',
#  'g__Pseudomonas_E_647464_ASV-3',
#  'g__Caulobacter_487784_ASV-1',
#  'g__Jeotgalicoccus_A_310962_ASV-1',
#  'g__Massilia_ASV-2',
#  'g__Rhodoferax_A_585629_ASV-2',
#  'g__Rhodoferax_A_585629_ASV-3',
#  'g__Pararheinheimera_ASV-1',
#  'g__SIO2C1_ASV-3',
#  'g__Bifidobacterium_388775_ASV-1',
#  'g__Cloacibacterium_ASV-3',
#  'g__Peptoniphilus_A_ASV-3',
#  'g__Veillonella_A_ASV-6',
#  'g__Veillonella_A_ASV-2',
#  'g___ASV-472',
#  'g__Veillonella_A_ASV-5',
#  'g__Prevotella_ASV-5',
#  'g__Bacillus_P_294101_ASV-3',
#  'g__Ligilactobacillus_ASV-2',
#  'g__Streptococcus_ASV-17',
#  'g__Roseburia_ASV-2',
#  'g__Streptococcus_ASV-18',
#  'g__Streptococcus_ASV-35',
#  'g___ASV-14',
#  'g___ASV-10',
#  'g___ASV-30',
#  'g__Corynebacterium_ASV-4',
#  'g__Corynebacterium_ASV-5',
#  'g___ASV-40',
#  'g__Massilia_ASV-3',
#  'g__Leuconostoc_B_ASV-4',
#  'g__Sphingobacterium_ASV-1',
#  'g___ASV-52',
#  'g__Acinetobacter_ASV-7',
#  'g__Paracoccus_ASV-4',
#  'g__Brevibacterium_ASV-1',
#  'g__Actinomyces_ASV-2',
#  'g__Prevotella_ASV-8',
#  'g__Selenomonas_B_42762_ASV-1',
#  'g__Leptotrichia_A_993758_ASV-4',
#  'g__Scardovia_ASV-1',
#  'g__Lactobacillus_ASV-5',
#  'g__Capnocytophaga_820688_ASV-1',
#  'g__Dialister_ASV-1',
#  'g__Corynebacterium_ASV-10',
#  'g__Staphylococcus_ASV-7',
#  'g___ASV-15',
#  'g___ASV-76',
#  'g__Staphylococcus_ASV-35',
#  'g__Mesorhizobium_F_498388_ASV-3',
#  'g__Staphylococcus_ASV-34',
#  'g__Pseudomonas_B_650451_ASV-1',
#  'g__Staphylococcus_ASV-33',
#  'g__Escherichia_710834_ASV-2',
#  'g__Acinetobacter_ASV-8',
#  'g__Chroococcidiopsis_29153_ASV-1',
#  'g__Exiguobacterium_A_ASV-2',
#  'g__Modestobacter_ASV-1',
#  'g___ASV-84',
#  'g__SIO2C1_ASV-10',
#  'g__Chryseolinea_ASV-1',
#  'g___ASV-68',
#  'g__Sphingomonas_L_486704_ASV-1',
#  'g__Nostoc_B_27156_ASV-1',
#  'g___ASV-189',
#  'g__Calothrix_ASV-1',
#  'g__Hymenobacter_910554_ASV-1',
#  'g__Brevundimonas_ASV-3',
#  'g___ASV-177',
#  'g__Aequorivita_ASV-1',
#  'g__Methylobacterium_ASV-1',
#  'g___ASV-262',
#  'g___ASV-83',
#  'g__Anaerococcus_ASV-3',
#  'g___ASV-343',
#  'g__Sphingomonas_L_486704_ASV-3',
#  'g__Aliterella_ASV-1',
#  'g__Edaphobacter_415416_ASV-1',
#  'g___ASV-64',
#  'g__KBS-83_ASV-1',
#  'g__Enterocloster_ASV-5',
#  'g___ASV-75',
#  'g___ASV-35',
#  'g__Brevundimonas_ASV-4',
#  'g__Frisingicoccus_ASV-1',
#  'g__Sphingobacterium_ASV-2',
#  'g___ASV-166',
#  'g__Mucilaginibacter_A_ASV-6',
#  'g__Clostridioides_A_ASV-1',
#  'g__Comamonas_F_589250_ASV-1',
#  'g__Modestobacter_ASV-2',
#  'g__Cellvibrio_ASV-1',
#  'g__Adhaeribacter_ASV-1',
#  'g__Hyphomicrobium_A_ASV-3',
#  'g___ASV-67',
#  'g__Ruminococcus_B_ASV-1',
#  'g__Teichococcus_ASV-2',
#  'g___ASV-344',
#  'g___ASV-47',
#  'g___ASV-206',
#  'g__Solirubrobacter_ASV-4',
#  'g__Mycobacterium_ASV-2',
#  'g__Solirubrobacter_ASV-8',
#  'g__Solirubrobacter_ASV-9',
#  'g__Mucilaginibacter_A_ASV-11',
#  'g__Yimella_ASV-1',
#  'g__Sphingobium_A_485959_ASV-3',
#  'g___ASV-141',
#  'g__Alistipes_A_871404_ASV-1',
#  'g___ASV-70',
#  'g__Methanobrevibacter_A_ASV-1',
#  'g___ASV-134',
#  'g___ASV-550',
#  'g__Terriglobus_A_ASV-1',
#  'g__Corynebacterium_ASV-13',
#  'g___ASV-561',
#  'g___ASV-302',
#  'g__Hydrogenophaga_590395_ASV-1',
#  'g__REDI01_ASV-1',
#  'g__Adhaeribacter_ASV-3',
#  'g__Friedmanniella_ASV-2',
#  'g__Streptococcus_ASV-8',
#  'g___ASV-294',
#  'g__Brevundimonas_ASV-7',
#  'g__Streptococcus_ASV-6',
#  'g__Acinetobacter_ASV-4',
#  'g___ASV-510',
#  'g___ASV-515',
#  'g__Eubacterium_G_ASV-1',
#  'g__Chryseobacterium_796614_ASV-5',
#  'g__Chryseobacterium_796614_ASV-2',
#  'g___ASV-92',
#  'g___ASV-13',
#  'g___ASV-45',
#  'g__Staphylococcus_ASV-4',
#  'g__Dictyoglomus_ASV-2',
#  'g___ASV-24',
#  'g__Faecalibacterium_ASV-1',
#  'g__Bosea_ASV-1',
#  'g__Faecalibacterium_ASV-4',
#  'g__Prevotella_ASV-27',
#  'g__Catenibacterium_ASV-1',
#  'g__Alloprevotella_ASV-2',
#  'g__Aeromonas_ASV-2',
#  'g__Phocaeicola_A_858004_ASV-1',
#  'g__Abiotrophia_ASV-2',
#  'g__Leptotrichia_A_993758_ASV-15',
#  'g__Pseudomonas_E_647464_ASV-1',
#  'g__Capnocytophaga_820688_ASV-5',
#  'g__Mobilitalea_ASV-1',
#  'g___ASV-96',
#  'g__Acinetobacter_ASV-10',
#  'g__Corynebacterium_ASV-12',
#  'g__Capnocytophaga_820688_ASV-2',
#  'g__Bifidobacterium_388775_ASV-2',
#  'g__Copromonas_ASV-1',
#  'g__Clostridium_P_ASV-1',
#  'g__Granulicatella_ASV-2',
#  'g___ASV-38',
#  'g__Fenollaria_ASV-2',
#  'g__Lactobacillus_ASV-8',
#  'g__Staphylococcus_ASV-6',
#  'g___ASV-233',
#  'g___ASV-205',
#  'g__Leptotrichia_A_993758_ASV-5',
#  'g__CAG-83_ASV-1',
#  'g__Prevotella_ASV-22',
#  'g__Lactobacillus_ASV-2',
#  'g__Flavobacterium_ASV-24',
#  'g__Cloacibacterium_ASV-4',
#  'g___ASV-528',
#  'g__Lactococcus_A_346120_ASV-2',
#  'g__Prevotella_ASV-41',
#  'g__Peptostreptococcus_ASV-3',
#  'g___ASV-72',
#  'g__Hydrogenophaga_590395_ASV-2',
#  'g__Cloacibacterium_ASV-2',
#  'g__Prevotella_ASV-52',
#  'g__Lancefieldella_ASV-2',
#  'g__Mesorhizobium_F_498388_ASV-2',
#  'g__Brevibacterium_ASV-6',
#  'g__Prevotella_ASV-7',
#  'g___ASV-258',
#  'g___ASV-351',
#  'g__Chryseobacterium_796614_ASV-3',
#  'g__Pauljensenia_ASV-3',
#  'g__Acinetobacter_ASV-15',
#  'g__Stenotrophomonas_A_615274_ASV-2',
#  'g__Acinetobacter_ASV-17',
#  'g__Acinetobacter_ASV-18',
#  'g__Acinetobacter_ASV-24',
#  'g__Prevotella_ASV-37',
#  'g__Agathobacter_164117_ASV-2',
#  'g__Blautia_A_141781_ASV-5',
#  'g__Faecalibacterium_ASV-5',
#  'g__Ruminococcus_E_ASV-2',
#  'g__CAG-127_ASV-1',
#  'g__CAG-95_ASV-1',
#  'g__CAG-127_ASV-2',
#  'g__Mediterraneibacter_A_155507_ASV-5',
#  'g__Coprococcus_A_121497_ASV-2',
#  'g__Akkermansia_ASV-2',
#  'g__Akkermansia_ASV-1',
#  'g__Coprococcus_A_121497_ASV-1',
#  'g__Streptococcus_ASV-4',
#  'g__Gemmiger_A_73129_ASV-1',
#  'g__Faecalibacillus_ASV-2',
#  'g__Collinsella_ASV-2',
#  'g__Dialister_ASV-6',
#  'g__Pseudoruminococcus_A_ASV-1',
#  'g__Gemmiger_A_73129_ASV-5',
#  'g__Pseudoruminococcus_A_ASV-2',
#  'g___ASV-149',
#  'g__Anaerobutyricum_ASV-1',
#  'g__ER4_ASV-2',
#  'g__Haemophilus_D_735815_ASV-2',
#  'g___ASV-78',
#  'g__Anaerobutyricum_ASV-2',
#  'g__Acetatifactor_ASV-1',
#  'g__CAG-269_ASV-4',
#  'g__Blautia_A_141781_ASV-8',
#  'g__Lactobacillus_ASV-3',
#  'g__Blautia_A_141781_ASV-3',
#  'g__CAG-41_ASV-2',
#  'g___ASV-157',
#  'g___ASV-242',
#  'g__Lactobacillus_ASV-1',
#  'g___ASV-304',
#  'g__Corynebacterium_ASV-8',
#  'g__CAG-83_ASV-2',
#  'g__Dorea_A_ASV-2',
#  'g__Parabacteroides_B_862066_ASV-2',
#  'g__Clostridium_T_ASV-4',
#  'g__Dysosmobacter_ASV-1',
#  'g__Bacteroides_H_ASV-3',
#  'g___ASV-172',
#  'g__Alistipes_A_871400_ASV-1',
#  'g__Paratractidigestivibacter_ASV-1',
#  'g__Copromorpha_ASV-1',
#  'g__CAG-41_ASV-1',
#  'g__Agathobaculum_ASV-1',
#  'g___ASV-151',
#  'g__Bacteroides_H_ASV-17',
#  'g__Enterenecus_ASV-1',
#  'g___ASV-204',
#  'g__Gemmiger_A_73129_ASV-3',
#  'g___ASV-345',
#  'g__Paratractidigestivibacter_ASV-2',
#  'g__Coprococcus_A_187866_ASV-1',
#  'g___ASV-43',
#  'g__ER4_ASV-3',
#  'g__Evtepia_ASV-2',
#  'g__S5-A14a_ASV-2',
#  'g__Senegalimassilia_ASV-1',
#  'g__Bacteroides_H_ASV-2',
#  'g__Hylemonella_582308_ASV-1',
#  'g__Parabacteroides_B_862066_ASV-6',
#  'g__Cupidesulfovibrio_ASV-1',
#  'g__Cupidesulfovibrio_ASV-2',
#  'g__Sutterella_ASV-2',
#  'g__Senegalimassilia_ASV-2',
#  'g__Agathobaculum_ASV-3',
#  'g__Haemophilus_D_735815_ASV-3',
#  'g__Clostridium_P_ASV-2',
#  'g__Corynebacterium_ASV-20',
#  'g__Sutterella_ASV-3',
#  'g___ASV-399',
#  'g__Sphingomonas_L_486704_ASV-6',
#  'g__Cryptobacteroides_ASV-1',
#  'g__Terrisporobacter_ASV-1',
#  'g__Streptococcus_ASV-14',
#  'g__Corynebacterium_ASV-41',
#  'g__Faecousia_ASV-3',
#  'g__Terrisporobacter_ASV-2',
#  'g__Ruminiclostridium_E_ASV-1',
#  'g__Mediterraneibacter_A_155507_ASV-2',
#  'g__Ruminiclostridium_E_ASV-2',
#  'g__Veillonella_A_ASV-7',
#  'g__Veillonella_A_ASV-9',
#  'g__Kerstersia_ASV-2',
#  'g__Bacteroides_H_ASV-1',
#  'g__Paracoccus_ASV-2',
#  'g__SIO2C1_ASV-6',
#  'g__Ruminococcus_B_ASV-2',
#  'g__Actinomyces_ASV-4',
#  'g__Nocardioides_A_392796_ASV-2',
#  'g___ASV-220',
#  'g___ASV-282',
#  'g__Brevundimonas_ASV-5',
#  'g__Clostridium_T_ASV-9',
#  'g__Clostridioides_A_ASV-2',
#  'g__Paracoccus_ASV-5',
#  'g__Leptotrichia_A_993758_ASV-6',
#  'g__Catenibacterium_ASV-2',
#  'g___ASV-266',
#  'g__Rothia_ASV-1',
#  'g__Massilia_ASV-12',
#  'g__Corynebacterium_ASV-23',
#  'g__Kerstersia_ASV-1',
#  'g__Corynebacterium_ASV-35',
#  'g__Corynebacterium_ASV-17',
#  'g__Corynebacterium_ASV-47',
#  'g__Micrococcus_ASV-3',
#  'g__SIO2C1_ASV-5',
#  'g__Phocaeicola_A_858004_ASV-4',
#  'g___ASV-121',
#  'g__Pseudomonas_A_ASV-1',
#  'g__Bifidobacterium_388775_ASV-3',
#  'g__Cloacibacterium_ASV-1',
#  'g___ASV-20',
#  'g__Clostridium_T_ASV-1',
#  'g__Pusillimonas_A_ASV-1',
#  'g__Metamycoplasma_ASV-2',
#  'g__Metamycoplasma_ASV-1',
#  'g___ASV-413',
#  'g___ASV-73',
#  'g__Friedmanniella_ASV-1',
#  'g__Granulicatella_ASV-4',
#  'g__Sphingomicrobium_483265_ASV-1',
#  'g__Bradyrhizobium_ASV-2',
#  'g__Staphylococcus_ASV-8',
#  'g___ASV-12',
#  'g__Blautia_A_141781_ASV-4',
#  'g__Capnocytophaga_820690_ASV-1',
#  'g___ASV-164',
#  'g__Ruminococcus_D_ASV-1',
#  'g__Bariatricus_ASV-1',
#  'g__Sphingomonas_L_486704_ASV-7',
#  'g__Anaerococcus_ASV-12',
#  'g__Capnocytophaga_820688_ASV-8',
#  'g__Sphingomonas_L_486704_ASV-23',
#  'g__Prevotella_ASV-25',
#  'g__Parvimonas_ASV-3',
#  'g__Sphingomonas_L_486704_ASV-4',
#  'g__CAG-217_ASV-1',
#  'g__ER4_ASV-1',
#  'g__Parvimonas_ASV-5',
#  'g__Prevotella_ASV-21',
#  'g___ASV-117',
#  'g___ASV-373',
#  'g__Leptotrichia_A_993641_ASV-3',
#  'g__Aggregatibacter_736122_ASV-1',
#  'g___ASV-36',
#  'g__Enterocloster_ASV-1',
#  'g__Anaerostipes_ASV-1',
#  'g__Leptotrichia_A_993641_ASV-4',
#  'g__Centipeda_ASV-6',
#  'g__Roseburia_ASV-6',
#  'g__Prevotella_ASV-30',
#  'g___ASV-369',
#  'g__Acidipropionibacterium_ASV-1',
#  'g__Anaerostipes_ASV-2',
#  'g__SIO2C1_ASV-23',
#  'g__Capnocytophaga_820688_ASV-3',
#  'g__Barnesiella_ASV-1',
#  'g__Tannerella_ASV-4',
#  'g__Streptococcus_ASV-7',
#  'g__Loigolactobacillus_ASV-1',
#  'g___ASV-37',
#  'g___ASV-88',
#  'g__Loigolactobacillus_ASV-2',
#  'g___ASV-184',
#  'g__Lactobacillus_ASV-6',
#  'g__Lactobacillus_ASV-9',
#  'g__Gaiella_ASV-1',
#  'g__Pseudomonas_E_647464_ASV-2',
#  'g__Blautia_A_141781_ASV-6',
#  'g__Veillonella_A_ASV-10',
#  'g__UMGS1994_ASV-1',
#  'g__Gaiella_ASV-2',
#  'g__Rothia_ASV-4',
#  'g__Corynebacterium_ASV-34',
#  'g__Croceibacterium_484881_ASV-1',
#  'g__Cutibacterium_ASV-5',
#  'g__Clostridium_Q_135822_ASV-1',
#  'g__Mediterraneibacter_A_155507_ASV-3',
#  'g__Marinococcus_ASV-1',
#  'g__Rhodococcus_C_375578_ASV-1',
#  'g__Marinomonas_ASV-1',
#  'g__Micrococcoides_ASV-1',
#  'g__Abiotrophia_ASV-1',
#  'g___ASV-317',
#  'g__Acinetobacter_ASV-29',
#  'g__Eubacterium_B_ASV-1',
#  'g__Erysipelatoclostridium_ASV-1',
#  'g__Acinetobacter_ASV-22',
#  'g__Devosia_A_502124_ASV-2',
#  'g__Klebsiella_724518_ASV-1',
#  'g___ASV-86',
#  'g__Lautropia_ASV-1',
#  'g__Clostridium_Q_135822_ASV-2',
#  'g___ASV-536',
#  'g__Exiguobacterium_A_ASV-4',
#  'g__Acinetobacter_ASV-9',
#  'g__Atopostipes_ASV-1',
#  'g__Rubellimicrobium_ASV-1',
#  'g__Leuconostoc_B_ASV-2',
#  'g__Acinetobacter_ASV-16',
#  'g__Nocardioides_A_392796_ASV-5',
#  'g__Pseudomonas_E_647464_ASV-5',
#  'g__Bifidobacterium_388775_ASV-5',
#  'g__UMGS872_ASV-1',
#  'g__UMGS872_ASV-2',
#  'g__Psychrobacter_ASV-4',
#  'g__Staphylococcus_ASV-12',
#  'g__Facklamia_A_322620_ASV-1',
#  'g__Prevotella_ASV-28',
#  'g__Capnocytophaga_820688_ASV-6',
#  'g___ASV-41',
#  'g__Prevotella_ASV-39',
#  'g__Acinetobacter_ASV-11',
#  'g___ASV-89',
#  'g___ASV-93',
#  'g__Sphingomonas_L_486704_ASV-5',
#  'g__F1-60-MAGs163_ASV-1',
#  'g___ASV-107',
#  'g___ASV-303',
#  'g__Pseudomonas_A_ASV-2',
#  'g__Actinoplanes_ASV-1',
#  'g__Olegusella_ASV-2',
#  'g___ASV-286',
#  'g__Cutibacterium_ASV-4',
#  'g__Olegusella_ASV-1',
#  'g__Mycobacterium_ASV-5',
#  'g__Cutibacterium_ASV-3',
#  'g__Acidipropionibacterium_ASV-2',
#  'g__Prevotella_ASV-50',
#  'g__Sphingobacterium_ASV-3',
#  'g__Comamonas_F_589250_ASV-5',
#  'g__Comamonas_F_589250_ASV-6',
#  'g__Corynebacterium_ASV-22',
#  'g__Peptoniphilus_A_ASV-5',
#  'g__Empedobacter_790298_ASV-2',
#  'g__Porphyromonas_A_859426_ASV-2',
#  'g__Varibaculum_ASV-2',
#  'g__Varibaculum_ASV-1',
#  'g___ASV-34',
#  'g__Mediterraneibacter_A_155507_ASV-1',
#  'g__Helcococcus_ASV-4',
#  'g___ASV-132',
#  'g__Anaerococcus_ASV-4',
#  'g__Anaerococcus_ASV-10',
#  'g__Veillonella_A_ASV-11',
#  'g__Pseudonocardia_ASV-2',
#  'g__Faecalibacterium_ASV-3',
#  'g__Negativicoccus_ASV-1',
#  'g__Veillonella_A_ASV-12',
#  'g___ASV-100',
#  'g__Schaedlerella_ASV-1',
#  'g__Anaerococcus_ASV-6',
#  'g__Fusobacterium_A_ASV-1',
#  'g__Faecalibacterium_ASV-8',
#  'g___ASV-104',
#  'g__Gleimia_ASV-1',
#  'g___ASV-208',
#  'g__Campylobacter_A_ASV-6',
#  'g__Prevotella_ASV-26',
#  'g__Dialister_ASV-13',
#  'g__Paracoccus_ASV-7',
#  'g__Anaerococcus_ASV-18',
#  'g__Fusobacterium_C_ASV-4',
#  'g__UBA3402_ASV-1',
#  'g__Howardella_ASV-2',
#  'g__Dialister_ASV-14',
#  'g___ASV-181',
#  'g__Dialister_ASV-4',
#  'g___ASV-546',
#  'g___ASV-547',
#  'g___ASV-548',
#  'g__Pedobacter_887417_ASV-1',
#  'g__Fusobacterium_C_ASV-10',
#  'g__Eremococcus_ASV-1',
#  'g__Leptotrichia_A_993758_ASV-3',
#  'g__Howardella_ASV-1',
#  'g__Pedobacter_887417_ASV-3',
#  'g___ASV-549',
#  'g__Bosea_ASV-5',
#  'g___ASV-543',
#  'g___ASV-61',
#  'g___ASV-555',
#  'g__Microbacterium_A_383184_ASV-2',
#  'g__Corynebacterium_ASV-18',
#  'g__RUG115_ASV-1',
#  'g__Lachnoclostridium_A_130679_ASV-1',
#  'g__Cereibacter_A_494292_ASV-1',
#  'g__Halomonas_E_640244_ASV-1',
#  'g__Bacillus_P_294101_ASV-1',
#  'g__Gemmiger_A_73129_ASV-2',
#  'g___ASV-211',
#  'g__Parabacteroides_B_862066_ASV-5',
#  'g__Rhodoferax_A_585629_ASV-5',
#  'g___ASV-212',
#  'g__Ruminococcus_C_58660_ASV-1',
#  'g___ASV-213',
#  'g__Rhodoferax_A_585629_ASV-1',
#  'g__Nocardioides_A_392796_ASV-4',
#  'g__Pseudoxanthomonas_A_615337_ASV-1',
#  'g__Ruminococcus_C_58660_ASV-2',
#  'g__Burkholderia_ASV-2',
#  'g__Streptomyces_G_395345_ASV-2',
#  'g__Alistipes_A_871400_ASV-3',
#  'g__Brevundimonas_ASV-6',
#  'g__Copromorpha_ASV-2',
#  'g__Ligilactobacillus_ASV-3',
#  'g__Rhodococcus_B_ASV-1',
#  'g__Skermanella_ASV-3',
#  'g__Blautia_A_141781_ASV-10',
#  'g__Sphingobacterium_ASV-7',
#  'g__Brevundimonas_ASV-8',
#  'g__Limivivens_ASV-1',
#  'g__Blautia_A_141781_ASV-9',
#  'g___ASV-309',
#  'g__Mycobacterium_ASV-4',
#  'g___ASV-215',
#  'g__Pseudomonas_E_647464_ASV-11',
#  'g__Sphingobium_A_485959_ASV-4',
#  'g__Streptococcus_ASV-9',
#  'g__Flavobacterium_ASV-5',
#  'g___ASV-113',
#  'g__Bacillus_P_294101_ASV-5',
#  'g__Corynebacterium_ASV-27',
#  'g__Lactobacillus_ASV-10',
#  'g__Agathobaculum_ASV-2',
#  'g___ASV-131',
#  'g__Corynebacterium_ASV-9',
#  'g__SIO2C1_ASV-7',
#  'g__Weissella_A_338544_ASV-4',
#  'g__Weissella_A_338544_ASV-3',
#  'g__Brevibacterium_ASV-3',
#  'g__Sphingomonas_L_486704_ASV-8',
#  'g__Alkalibacterium_ASV-1',
#  'g__Lactobacillus_ASV-7',
#  'g___ASV-115',
#  'g__Copromonas_ASV-3',
#  'g__Fimenecus_ASV-2',
#  'g___ASV-133',
#  'g__Fimenecus_ASV-1',
#  'g__Finegoldia_ASV-2',
#  'g__Gluconobacter_C_ASV-2',
#  'g__Clostridium_T_ASV-7',
#  'g___ASV-175',
#  'g__Prosthecobacter_ASV-1',
#  'g__Bariatricus_ASV-2',
#  'g___ASV-102',
#  'g__Flavobacterium_ASV-2',
#  'g__Helcococcus_ASV-2',
#  'g__Rhodopila_506777_ASV-1',
#  'g___ASV-461',
#  'g___ASV-209',
#  'g__Rhodopila_506777_ASV-4',
#  'g__Lactococcus_A_343306_ASV-1',
#  'g__Solirubrobacter_ASV-2',
#  'g__Bacteroides_H_ASV-4',
#  'g__Vescimonas_ASV-2',
#  'g__ER4_ASV-4',
#  'g__Parabacteroides_B_862066_ASV-3',
#  'g__Gluconobacter_B_ASV-1',
#  'g___ASV-452',
#  'g__Clostridium_T_ASV-10',
#  'g__Prevotella_ASV-62',
#  'g__Sphingobium_A_485959_ASV-2',
#  'g__Spirosoma_ASV-2',
#  'g__Mesorhizobium_F_498388_ASV-4',
#  'g__Centipeda_ASV-4',
#  'g___ASV-444',
#  'g__Vescimonas_ASV-1',
#  'g___ASV-336',
#  'g__Phascolarctobacterium_A_ASV-1',
#  'g__Rhodovarius_ASV-2',
#  'g___ASV-439',
#  'g__Porphyromonas_A_859426_ASV-6',
#  'g__Micrococcus_ASV-5',
#  'g__Acetobacter_ASV-1',
#  'g___ASV-442',
#  'g__Oligoflexus_ASV-2',
#  'g__Centipeda_ASV-1',
#  'g__Clostridium_T_ASV-2',
#  'g__Skermanella_ASV-1',
#  'g__Porphyromonas_A_859424_ASV-1',
#  'g__Levyella_ASV-1',
#  'g__Novosphingobium_485351_ASV-4',
#  'g__Deinococcus_B_ASV-1',
#  'g__Teichococcus_ASV-3',
#  'g__Shewanella_ASV-2',
#  'g__Skermanella_ASV-2',
#  'g___ASV-144',
#  'g__Evtepia_ASV-3',
#  'g__Levyella_ASV-2',
#  'g__Teichococcus_ASV-1',
#  'g__Leptotrichia_A_993758_ASV-10',
#  'g__Novosphingobium_485351_ASV-5',
#  'g___ASV-118',
#  'g___ASV-443',
#  'g___ASV-446',
#  'g__Turicibacter_ASV-1',
#  'g__Sphingomonas_L_486704_ASV-2',
#  'g___ASV-105',
#  'g__Clostridium_T_ASV-11',
#  'g__Cutibacterium_ASV-6',
#  'g__Comamonas_F_589250_ASV-3',
#  'g__Variovorax_ASV-1',
#  'g__Devosia_A_502124_ASV-1',
#  'g__SIO2C1_ASV-16',
#  'g___ASV-449',
#  'g__Bradyrhizobium_ASV-4',
#  'g___ASV-110',
#  'g__Oribacterium_ASV-1',
#  'g__Niastella_ASV-2',
#  'g__Friedmanniella_ASV-4',
#  'g__Pseudomonas_E_650326_ASV-1',
#  'g___ASV-469',
#  'g__Arthrobacter_D_ASV-2',
#  'g__Prevotella_ASV-31',
#  'g__Sphingomonas_L_486704_ASV-20',
#  'g___ASV-331',
#  'g__Sphingomonas_L_486704_ASV-18',
#  'g__Dyadobacter_906144_ASV-1',
#  'g___ASV-112',
#  'g___ASV-207',
#  'g___ASV-470',
#  'g__Micromonospora_H_372070_ASV-1',
#  'g__2011-GWC2-44-17_ASV-1',
#  'g___ASV-85',
#  'g__Corynebacterium_ASV-14',
#  'g__Corynebacterium_ASV-19',
#  'g__Streptococcus_ASV-12',
#  'g___ASV-159',
#  'g__Gluconobacter_B_ASV-2',
#  'g__Citricoccus_384863_ASV-2',
#  'g__Brevibacterium_ASV-4',
#  'g__Leptotrichia_A_993758_ASV-14',
#  'g___ASV-46',
#  'g__Capnocytophaga_820690_ASV-2',
#  'g__Anaerococcus_ASV-28',
#  'g___ASV-120',
#  'g__Anaerococcus_ASV-20',
#  'g__Phocaeicola_A_858004_ASV-2',
#  'g__Chryseolinea_ASV-2',
#  'g__Acetobacter_ASV-2',
#  'g__Leptotrichia_A_993641_ASV-1',
#  'g__GWC2-73-18_ASV-2',
#  'g___ASV-203',
#  'g__CAG-177_ASV-1',
#  'g__Flavobacterium_ASV-27',
#  'g___ASV-500',
#  'g__Solirubrobacter_ASV-3',
#  'g__Enterocloster_ASV-2',
#  'g___ASV-332',
#  'g___ASV-155',
#  'g__Capnocytophaga_820688_ASV-10',
#  'g___ASV-491',
#  'g__Gp6-AA45_ASV-4',
#  'g___ASV-162',
#  'g__CADDYX01_ASV-1',
#  'g__Capnocytophaga_820688_ASV-7',
#  'g___ASV-349',
#  'g___ASV-490',
#  'g__Campylobacter_A_ASV-3',
#  'g__Paracoccus_ASV-12',
#  'g__Devosia_A_502124_ASV-4',
#  'g___ASV-90',
#  'g___ASV-474',
#  'g__SIO2C1_ASV-29',
#  'g__UMGS1994_ASV-2',
#  'g___ASV-475',
#  'g__Aggregatibacter_736122_ASV-2',
#  'g___ASV-261',
#  'g__CADDYX01_ASV-2',
#  'g__F0058_ASV-1',
#  'g__Pontibacter_909804_ASV-2',
#  'g__Hyphomicrobium_A_ASV-5',
#  'g__Eubacterium_I_ASV-2',
#  'g__GWC2-73-18_ASV-3',
#  'g__Campylobacter_A_ASV-2',
#  'g___ASV-483',
#  'g__Arachnia_ASV-1',
#  'g__Olegusella_ASV-3',
#  'g__Campylobacter_A_ASV-4',
#  'g___ASV-484',
#  'g__Faecousia_ASV-2',
#  'g__Deinococcus_B_ASV-2',
#  'g__Hyphomicrobium_A_ASV-6',
#  'g__Nitrosocosmicus_ASV-1',
#  'g__Solirubrobacter_ASV-10',
#  'g__QHVH01_ASV-1',
#  'g__Staphylococcus_ASV-32',
#  'g__QHVH01_ASV-2',
#  'g__SCGC-AG-212-J23_ASV-1',
#  'g__Leptotrichia_A_993758_ASV-8',
#  'g__Nocardioides_A_392796_ASV-6',
#  'g___ASV-485',
#  'g__Methanobrevibacter_A_ASV-2',
#  'g___ASV-63',
#  'g__Kribbella_ASV-1',
#  'g__Gaiella_ASV-4',
#  'g__Gemella_ASV-3',
#  'g__Paracoccus_ASV-13',
#  'g__Filifactor_ASV-2',
#  'g___ASV-148',
#  'g__SIO2C1_ASV-28',
#  'g__Fusobacterium_C_ASV-5',
#  'g__Leptotrichia_A_993758_ASV-17',
#  'g__Flaviaesturariibacter_ASV-1',
#  'g___ASV-249',
#  'g___ASV-226',
#  'g___ASV-44',
#  'g__Jatrophihabitans_372606_ASV-1',
#  'g__Pauljensenia_ASV-2',
#  'g__Phenylobacterium_ASV-1',
#  'g__Catonella_ASV-1',
#  'g__Photobacterium_ASV-1',
#  'g__Megasphaera_A_38692_ASV-1',
#  'g__Solirubrobacter_ASV-1',
#  'g__Pseudomonas_E_647464_ASV-6',
#  'g__Chryseomonas_650364_ASV-1',
#  'g___ASV-56',
#  'g___ASV-486',
#  'g__Staphylococcus_ASV-31',
#  'g__Chryseomonas_650364_ASV-2',
#  'g__Rhodococcus_C_375578_ASV-2',
#  'g__Paracoccus_ASV-8',
#  'g__Atopostipes_ASV-3',
#  'g__Dialister_ASV-7',
#  'g__Anaerococcus_ASV-27',
#  'g__Flavobacterium_ASV-26',
#  'g___ASV-250',
#  'g__Granulicatella_ASV-3',
#  'g__Rothia_ASV-3',
#  'g__Veillonella_A_ASV-13',
#  'g___ASV-251',
#  'g__Streptococcus_ASV-10',
#  'g__Clostridium_H_ASV-1',
#  'g__Thermus_A_ASV-1',
#  'g__Clostridium_H_ASV-2',
#  'g__Leptotrichia_A_993641_ASV-2',
#  'g__Prevotella_ASV-42',
#  'g__Prevotella_ASV-10',
#  'g__Corynebacterium_ASV-16',
#  'g__Paraprevotella_ASV-1',
#  'g__Enterocloster_ASV-6',
#  'g__Stenotrophomonas_A_615274_ASV-3',
#  'g__Capnocytophaga_820688_ASV-4',
#  'g___ASV-190',
#  'g__Peptoanaerobacter_ASV-2',
#  'g__Flavisolibacter_B_ASV-1',
#  'g___ASV-87',
#  'g___ASV-252',
#  'g___ASV-170',
#  ...]

# %%
# Calculate column sums and sort columns by sum in descending order
col_sums = df.sum()
df = df[col_sums.sort_values(ascending=False).index]
df.columns.tolist()
# Out:
# ['g__Staphylococcus_ASV-1',
#  'g__Staphylococcus_ASV-2',
#  'g__Streptococcus_ASV-1',
#  'g__Micrococcus_ASV-1',
#  'g__Corynebacterium_ASV-2',
#  'g__Streptococcus_ASV-2',
#  'g___ASV-1',
#  'g__Prevotella_ASV-1',
#  'g___ASV-2',
#  'g__Streptococcus_ASV-3',
#  'g__Acinetobacter_ASV-1',
#  'g__Cutibacterium_ASV-1',
#  'g__Prevotella_ASV-2',
#  'g__Haemophilus_D_734546_ASV-1',
#  'g__Chryseobacterium_796614_ASV-1',
#  'g__Acinetobacter_ASV-2',
#  'g__Micrococcus_ASV-2',
#  'g___ASV-4',
#  'g__Acinetobacter_ASV-3',
#  'g__Corynebacterium_ASV-4',
#  'g___ASV-5',
#  'g__Veillonella_A_ASV-1',
#  'g__Escherichia_710834_ASV-1',
#  'g__Corynebacterium_ASV-5',
#  'g__Cutibacterium_ASV-2',
#  'g__Neisseria_563205_ASV-1',
#  'g__Staphylococcus_ASV-3',
#  'g__SIO2C1_ASV-1',
#  'g__Psychrobacter_ASV-1',
#  'g___ASV-7',
#  'g___ASV-8',
#  'g__Massilia_ASV-1',
#  'g__Acinetobacter_ASV-4',
#  'g__Chryseobacterium_796614_ASV-2',
#  'g__Corynebacterium_ASV-6',
#  'g___ASV-10',
#  'g__Neisseria_563205_ASV-2',
#  'g___ASV-9',
#  'g__Streptococcus_ASV-5',
#  'g__Aeromonas_ASV-1',
#  'g__Paracoccus_ASV-1',
#  'g__Prevotella_ASV-3',
#  'g___ASV-6',
#  'g__Corynebacterium_ASV-7',
#  'g__Gemella_ASV-1',
#  'g__Streptococcus_ASV-4',
#  'g__Corynebacterium_ASV-1',
#  'g__Pseudomonas_E_647464_ASV-1',
#  'g__Acinetobacter_ASV-5',
#  'g___ASV-12',
#  'g__Acinetobacter_ASV-6',
#  'g__Brachybacterium_ASV-1',
#  'g___ASV-13',
#  'g__Empedobacter_790298_ASV-1',
#  'g__Bifidobacterium_388775_ASV-1',
#  'g___ASV-14',
#  'g__Haemophilus_D_735815_ASV-1',
#  'g__Acinetobacter_ASV-7',
#  'g___ASV-11',
#  'g__F0422_ASV-1',
#  'g__Prevotella_ASV-4',
#  'g__Granulicatella_ASV-1',
#  'g___ASV-17',
#  'g__Corynebacterium_ASV-8',
#  'g___ASV-16',
#  'g__Actinomyces_ASV-1',
#  'g___ASV-18',
#  'g__Microbacterium_A_383184_ASV-1',
#  'g__Brevibacterium_ASV-1',
#  'g__Haemophilus_D_734546_ASV-2',
#  'g__Lactococcus_A_346120_ASV-1',
#  'g__SIO2C1_ASV-2',
#  'g__Acinetobacter_ASV-8',
#  'g__Porphyromonas_A_859423_ASV-1',
#  'g__Acinetobacter_ASV-9',
#  'g__Escherichia_710834_ASV-2',
#  'g___ASV-19',
#  'g__Paracoccus_ASV-2',
#  'g___ASV-3',
#  'g__Faecalibacterium_ASV-1',
#  'g__Aeromonas_ASV-2',
#  'g__Veillonella_A_ASV-2',
#  'g__Granulicatella_ASV-2',
#  'g__Finegoldia_ASV-1',
#  'g__SIO2C1_ASV-3',
#  'g__Enterococcus_C_ASV-1',
#  'g___ASV-23',
#  'g__Neisseria_563205_ASV-3',
#  'g__Paracoccus_ASV-3',
#  'g__Pseudomonas_E_647464_ASV-2',
#  'g__Dolosigranulum_ASV-1',
#  'g__Catenibacterium_ASV-1',
#  'g__Agathobacter_164117_ASV-1',
#  'g__Veillonella_A_ASV-4',
#  'g__Acinetobacter_ASV-10',
#  'g__Veillonella_A_ASV-3',
#  'g__Psychrobacter_ASV-2',
#  'g___ASV-27',
#  'g___ASV-22',
#  'g___ASV-26',
#  'g__Psychrobacter_ASV-3',
#  'g__Luteimonas_C_615545_ASV-1',
#  'g__Gemella_ASV-2',
#  'g__Corynebacterium_ASV-9',
#  'g__Staphylococcus_ASV-4',
#  'g___ASV-29',
#  'g__Lactobacillus_ASV-1',
#  'g___ASV-28',
#  'g__Corynebacterium_ASV-10',
#  'g__Microbacterium_A_383184_ASV-2',
#  'g__Neisseria_563205_ASV-4',
#  'g__Corynebacterium_ASV-12',
#  'g__Faecalibacterium_ASV-2',
#  'g__Corynebacterium_ASV-13',
#  'g__Massilia_ASV-2',
#  'g__Streptococcus_ASV-6',
#  'g__Veillonella_A_ASV-5',
#  'g__Skermanella_ASV-1',
#  'g___ASV-30',
#  'g__Massilia_ASV-3',
#  'g___ASV-25',
#  'g___ASV-31',
#  'g___ASV-24',
#  'g__Bifidobacterium_388775_ASV-2',
#  'g__Acinetobacter_ASV-11',
#  'g__Mediterraneibacter_A_155507_ASV-1',
#  'g__Brevundimonas_ASV-1',
#  'g__Brachybacterium_ASV-2',
#  'g___ASV-21',
#  'g___ASV-32',
#  'g__Blautia_A_141781_ASV-1',
#  'g___ASV-33',
#  'g__Rhodococcus_C_375578_ASV-1',
#  'g__Fusobacterium_C_ASV-1',
#  'g__Ruminococcus_B_ASV-1',
#  'g___ASV-20',
#  'g__Sphingobium_A_485959_ASV-1',
#  'g___ASV-34',
#  'g__Collinsella_ASV-1',
#  'g__Haemophilus_D_735815_ASV-2',
#  'g__Corynebacterium_ASV-11',
#  'g__Brevibacterium_ASV-2',
#  'g__Jeotgalicoccus_A_310962_ASV-1',
#  'g__Streptococcus_ASV-7',
#  'g__Anaerostipes_ASV-1',
#  'g__Nocardioides_A_392796_ASV-1',
#  'g___ASV-35',
#  'g__Rothia_ASV-1',
#  'g__Acinetobacter_ASV-12',
#  'g__Acinetobacter_ASV-13',
#  'g__Cloacibacterium_ASV-1',
#  'g__Exiguobacterium_A_ASV-1',
#  'g__Phocaeicola_A_858004_ASV-1',
#  'g__Comamonas_F_589250_ASV-1',
#  'g__Prevotella_ASV-5',
#  'g__Mycobacterium_ASV-1',
#  'g__Lactococcus_A_346120_ASV-2',
#  'g__Bifidobacterium_388775_ASV-3',
#  'g__Dorea_A_ASV-1',
#  'g__Hymenobacter_910554_ASV-1',
#  'g__Faecalibacterium_ASV-3',
#  'g__Blautia_A_141781_ASV-2',
#  'g__SIO2C1_ASV-4',
#  'g__Alloprevotella_ASV-1',
#  'g__Pseudomonas_E_647464_ASV-3',
#  'g__Acinetobacter_ASV-14',
#  'g___ASV-38',
#  'g__Mesorhizobium_F_498388_ASV-1',
#  'g__Empedobacter_790298_ASV-2',
#  'g__Actinomyces_ASV-2',
#  'g__Ruminococcus_E_ASV-1',
#  'g__Abiotrophia_ASV-1',
#  'g__Fenollaria_ASV-1',
#  'g__F0422_ASV-2',
#  'g__Vibrio_678715_ASV-1',
#  'g__Mesorhizobium_F_498388_ASV-2',
#  'g___ASV-37',
#  'g__Sphingomonas_L_486704_ASV-1',
#  'g__Pauljensenia_ASV-1',
#  'g__SIO2C1_ASV-5',
#  'g__Leuconostoc_B_ASV-1',
#  'g___ASV-40',
#  'g__Porphyromonas_A_859423_ASV-2',
#  'g___ASV-39',
#  'g__Anaerococcus_ASV-1',
#  'g__Agathobacter_164117_ASV-2',
#  'g__Granulicatella_ASV-3',
#  'g__Peptostreptococcus_ASV-1',
#  'g__Capnocytophaga_820688_ASV-1',
#  'g__Corynebacterium_ASV-14',
#  'g___ASV-43',
#  'g__Corynebacterium_ASV-15',
#  'g___ASV-45',
#  'g___ASV-44',
#  'g__Exiguobacterium_A_ASV-2',
#  'g__Catenibacterium_ASV-2',
#  'g__Acinetobacter_ASV-15',
#  'g__Shewanella_ASV-1',
#  'g__Bacillus_A_ASV-1',
#  'g__Granulicatella_ASV-4',
#  'g__Prevotella_ASV-6',
#  'g__SIO2C1_ASV-6',
#  'g__Peptoniphilus_A_ASV-1',
#  'g__Prevotella_ASV-8',
#  'g__Dialister_ASV-1',
#  'g__Bifidobacterium_388775_ASV-4',
#  'g__Clostridioides_A_ASV-1',
#  'g__Acinetobacter_ASV-16',
#  'g__Lactobacillus_ASV-3',
#  'g___ASV-41',
#  'g__Acinetobacter_ASV-17',
#  'g__Capnocytophaga_820688_ASV-2',
#  'g__Rhodococcus_C_375578_ASV-2',
#  'g___ASV-48',
#  'g__Bosea_ASV-1',
#  'g__Leptotrichia_A_993758_ASV-2',
#  'g__Sphingobacterium_ASV-1',
#  'g__Roseburia_ASV-1',
#  'g__Bacteroides_H_ASV-1',
#  'g__Peptoniphilus_A_ASV-2',
#  'g___ASV-49',
#  'g__Corynebacterium_ASV-3',
#  'g___ASV-47',
#  'g___ASV-51',
#  'g__Leptotrichia_A_993758_ASV-1',
#  'g__Limosilactobacillus_ASV-1',
#  'g__Brevibacterium_ASV-3',
#  'g__Prevotella_ASV-10',
#  'g__Comamonas_F_589250_ASV-2',
#  'g___ASV-50',
#  'g__Prevotella_ASV-13',
#  'g___ASV-56',
#  'g__Lactobacillus_ASV-4',
#  'g___ASV-52',
#  'g__Blautia_A_141781_ASV-3',
#  'g__Aggregatibacter_736122_ASV-1',
#  'g__Citricoccus_384863_ASV-1',
#  'g__Veillonella_A_ASV-7',
#  'g__Micrococcus_ASV-3',
#  'g__Edaphocola_ASV-1',
#  'g__Capnocytophaga_820688_ASV-3',
#  'g___ASV-60',
#  'g__Lactobacillus_ASV-2',
#  'g___ASV-15',
#  'g___ASV-61',
#  'g___ASV-54',
#  'g__Roseomonas_A_507160_ASV-1',
#  'g__Thermicanus_ASV-1',
#  'g___ASV-63',
#  'g__Faecalibacillus_ASV-1',
#  'g__Anaerococcus_ASV-2',
#  'g___ASV-53',
#  'g__Jeotgalicoccus_A_310962_ASV-2',
#  'g__Luteimonas_C_615545_ASV-2',
#  'g___ASV-55',
#  'g___ASV-42',
#  'g__Pseudomonas_E_647464_ASV-4',
#  'g__Exiguobacterium_A_ASV-3',
#  'g__Sphingomicrobium_483265_ASV-1',
#  'g__Copromonas_ASV-1',
#  'g___ASV-62',
#  'g__Prevotella_ASV-9',
#  'g__Corynebacterium_ASV-16',
#  'g__Veillonella_A_ASV-6',
#  'g__Prevotella_ASV-12',
#  'g__Limosilactobacillus_ASV-2',
#  'g___ASV-64',
#  'g__Leptotrichia_A_993758_ASV-3',
#  'g___ASV-36',
#  'g___ASV-66',
#  'g__Fusobacterium_C_ASV-2',
#  'g__Sphingobacterium_ASV-2',
#  'g__Finegoldia_ASV-2',
#  'g__Yimella_ASV-1',
#  'g__Pseudomonas_B_650451_ASV-1',
#  'g__Sphingobium_A_485959_ASV-2',
#  'g__Brevibacterium_ASV-4',
#  'g__Prevotella_ASV-15',
#  'g__Faecalibacterium_ASV-4',
#  'g___ASV-69',
#  'g___ASV-58',
#  'g__Arthrobacter_D_ASV-1',
#  'g__Prevotella_ASV-7',
#  'g__Pseudoxanthomonas_A_615337_ASV-1',
#  'g__Bacillus_A_ASV-2',
#  'g__Peptostreptococcus_ASV-3',
#  'g__Fusobacterium_C_ASV-3',
#  'g__Alloprevotella_ASV-2',
#  'g__Bifidobacterium_388775_ASV-5',
#  'g__Capnocytophaga_820690_ASV-1',
#  'g__Gemmiger_A_73129_ASV-1',
#  'g___ASV-71',
#  'g__Flavobacterium_ASV-1',
#  'g__Psychrobacter_ASV-4',
#  'g__Hylemonella_582308_ASV-1',
#  'g__Comamonas_F_589250_ASV-3',
#  'g___ASV-70',
#  'g__Shewanella_ASV-2',
#  'g__Kerstersia_ASV-1',
#  'g__Sphingomonas_L_486704_ASV-2',
#  'g___ASV-68',
#  'g__Mediterraneibacter_A_155507_ASV-2',
#  'g___ASV-67',
#  'g__Abiotrophia_ASV-2',
#  'g___ASV-72',
#  'g___ASV-57',
#  'g__Leuconostoc_B_ASV-2',
#  'g__Lactobacillus_ASV-5',
#  'g__Prevotella_ASV-16',
#  'g__Prevotella_ASV-11',
#  'g__Peptostreptococcus_ASV-2',
#  'g__Veillonella_A_ASV-8',
#  'g___ASV-75',
#  'g__Methylobacterium_ASV-1',
#  'g___ASV-73',
#  'g__Treponema_B_986142_ASV-1',
#  'g___ASV-77',
#  'g__Clostridium_T_ASV-1',
#  'g__Nocardioides_A_392796_ASV-2',
#  'g__Sphingomonas_L_486704_ASV-3',
#  'g__Nocardioides_A_392796_ASV-3',
#  'g__Capnocytophaga_820688_ASV-4',
#  'g__Skermanella_ASV-2',
#  'g__Exiguobacterium_A_ASV-5',
#  'g__Streptococcus_ASV-9',
#  'g__Clostridium_P_ASV-1',
#  'g__Blautia_A_141781_ASV-4',
#  'g__Leptotrichia_A_993758_ASV-4',
#  'g___ASV-76',
#  'g__Bacillus_J_ASV-1',
#  'g__Coprococcus_A_187866_ASV-1',
#  'g__Ligilactobacillus_ASV-1',
#  'g__Cutibacterium_ASV-3',
#  'g___ASV-81',
#  'g__Prevotella_ASV-14',
#  'g__Prevotella_ASV-18',
#  'g__Staphylococcus_ASV-6',
#  'g___ASV-79',
#  'g__Massilia_ASV-4',
#  'g__Clostridium_H_ASV-1',
#  'g__Oliverpabstia_ASV-1',
#  'g__Nocardioides_A_392796_ASV-4',
#  'g__Bacteroides_H_ASV-2',
#  'g__Rothia_ASV-3',
#  'g___ASV-78',
#  'g__Pseudomonas_E_647464_ASV-5',
#  'g__Citricoccus_384863_ASV-2',
#  'g__Peptoniphilus_A_ASV-3',
#  'g__Massilia_ASV-6',
#  'g__Loigolactobacillus_ASV-1',
#  'g__Corynebacterium_ASV-18',
#  'g__Lactobacillus_ASV-6',
#  'g__Phocaeicola_A_858004_ASV-2',
#  'g__Corynebacterium_ASV-17',
#  'g__Anaerobutyricum_ASV-1',
#  'g___ASV-82',
#  'g__Lancefieldella_ASV-1',
#  'g__Prevotella_ASV-21',
#  'g__Exiguobacterium_A_ASV-4',
#  'g___ASV-80',
#  'g__Paracoccus_ASV-4',
#  'g__Gordonia_B_376796_ASV-1',
#  'g___ASV-83',
#  'g__Prevotella_ASV-20',
#  'g__Roseburia_ASV-2',
#  'g__Intestinibacter_ASV-1',
#  'g__Prevotella_ASV-23',
#  'g__Prevotella_ASV-17',
#  'g__Alloprevotella_ASV-3',
#  'g__Rothia_ASV-4',
#  'g___ASV-84',
#  'g__Micrococcoides_ASV-1',
#  'g__Veillonella_A_ASV-9',
#  'g__Sutterella_ASV-1',
#  'g__Mycobacterium_ASV-2',
#  'g__Staphylococcus_ASV-7',
#  'g__Marinococcus_ASV-1',
#  'g__Blautia_A_141780_ASV-1',
#  'g__Enterocloster_ASV-1',
#  'g__Pleomorphomonas_ASV-1',
#  'g__Haemophilus_A_ASV-1',
#  'g__Anaerococcus_ASV-3',
#  'g__Friedmanniella_ASV-1',
#  'g__Oligella_ASV-1',
#  'g__Prevotella_ASV-19',
#  'g__Pseudomonas_A_ASV-1',
#  'g__Dietzia_ASV-1',
#  'g__Parvimonas_ASV-2',
#  'g__Pleomorphomonas_ASV-2',
#  'g__Lautropia_ASV-1',
#  'g__Prevotella_ASV-22',
#  'g__Comamonas_F_589250_ASV-4',
#  'g__Pseudomonas_K_ASV-1',
#  'g__Peptostreptococcus_ASV-4',
#  'g__Sphingomonas_L_486704_ASV-4',
#  'g__Jeotgalicoccus_A_310962_ASV-3',
#  'g___ASV-74',
#  'g__Prevotella_ASV-25',
#  'g__Parvimonas_ASV-1',
#  'g__Prevotella_ASV-26',
#  'g___ASV-85',
#  'g__Thermicanus_ASV-2',
#  'g__Aliicoccus_ASV-1',
#  'g__Anaerococcus_ASV-4',
#  'g___ASV-86',
#  'g__Cloacibacterium_ASV-2',
#  'g__Streptococcus_ASV-10',
#  'g__Sphingomicrobium_483265_ASV-2',
#  'g__Mesorhizobium_F_498388_ASV-3',
#  'g__Rubellimicrobium_ASV-1',
#  'g__Halomonas_E_640244_ASV-1',
#  'g__Thermus_A_ASV-1',
#  'g__Phenylobacterium_ASV-1',
#  'g__Sphingobium_A_485959_ASV-3',
#  'g__Pseudonocardia_ASV-1',
#  'g__Sphingomonas_L_486704_ASV-5',
#  'g__Fusobacterium_C_ASV-5',
#  'g___ASV-92',
#  'g__Carnobacterium_A_320743_ASV-1',
#  'g__Rothia_ASV-2',
#  'g__Paracoccus_ASV-5',
#  'g__Prevotella_ASV-27',
#  'g__Dorea_A_ASV-2',
#  'g__Streptococcus_ASV-11',
#  'g__Pseudomonas_E_650326_ASV-1',
#  'g__Mucilaginibacter_A_ASV-1',
#  'g__Paracoccus_ASV-6',
#  'g__Fenollaria_ASV-2',
#  'g__Dermacoccus_ASV-1',
#  'g__Mycobacterium_ASV-3',
#  'g___ASV-46',
#  'g__Stenotrophomonas_A_615274_ASV-1',
#  'g__Brevundimonas_ASV-2',
#  'g__Faecalibacterium_ASV-5',
#  'g__Ruminococcus_D_ASV-1',
#  'g__Collinsella_ASV-2',
#  'g__Fannyhessea_ASV-1',
#  'g__Novosphingobium_485351_ASV-1',
#  'g__Comamonas_F_589250_ASV-5',
#  'g___ASV-93',
#  'g__Fusobacterium_A_ASV-1',
#  'g__Leuconostoc_B_ASV-3',
#  'g__Actinomyces_ASV-3',
#  'g__Pleomorphomonas_ASV-3',
#  'g__Dialister_ASV-2',
#  'g__Staphylococcus_ASV-5',
#  'g___ASV-59',
#  'g___ASV-91',
#  'g__Corynebacterium_ASV-20',
#  'g___ASV-97',
#  'g__Cereibacter_A_494292_ASV-1',
#  'g__Parabacteroides_B_862066_ASV-1',
#  'g__Hylemonella_582308_ASV-2',
#  'g___ASV-87',
#  'g__Dietzia_ASV-2',
#  'g__Lactobacillus_ASV-7',
#  'g__Leptotrichia_A_993758_ASV-7',
#  'g__Tannerella_ASV-1',
#  'g__Brevundimonas_ASV-3',
#  'g__Sphingomonas_L_486704_ASV-6',
#  'g__Streptococcus_ASV-13',
#  'g__Moraxella_A_651148_ASV-1',
#  'g__Centipeda_ASV-1',
#  'g__Sphingomonas_L_486704_ASV-7',
#  'g__Clostridium_H_ASV-2',
#  'g__Atopostipes_ASV-1',
#  'g__Nemorincola_ASV-1',
#  'g__Parabacteroides_B_862066_ASV-2',
#  'g__Agathobaculum_ASV-1',
#  'g__S5-A14a_ASV-1',
#  'g__Sphingobacterium_ASV-3',
#  'g__Blautia_A_141781_ASV-5',
#  'g__Caulobacter_487784_ASV-1',
#  'g__Massilia_ASV-5',
#  'g___ASV-90',
#  'g___ASV-95',
#  'g__Corynebacterium_ASV-19',
#  'g__Brevundimonas_ASV-4',
#  'g___ASV-99',
#  'g__Leptotrichia_A_993758_ASV-5',
#  'g__Vescimonas_ASV-1',
#  'g__Porphyromonas_A_859426_ASV-1',
#  'g__Gemmiger_A_73129_ASV-2',
#  'g___ASV-102',
#  'g__Rothia_ASV-6',
#  'g__Corynebacterium_ASV-22',
#  'g__Mesorhizobium_F_498388_ASV-4',
#  'g___ASV-100',
#  'g__Microbacterium_A_383312_ASV-1',
#  'g___ASV-96',
#  'g__UBA6175_ASV-1',
#  'g__Massilia_ASV-7',
#  'g___ASV-94',
#  'g__Anaerococcus_ASV-5',
#  'g__Rhodoferax_A_585629_ASV-1',
#  'g__Pararheinheimera_ASV-1',
#  'g__Pauljensenia_ASV-3',
#  'g__Acidipropionibacterium_ASV-2',
#  'g__Dolosigranulum_ASV-2',
#  'g__Paratractidigestivibacter_ASV-1',
#  'g__Weissella_A_338544_ASV-1',
#  'g__Rhodoferax_A_585629_ASV-2',
#  'g__Acetobacter_ASV-1',
#  'g__Terrisporobacter_ASV-1',
#  'g__Prevotella_ASV-24',
#  'g___ASV-104',
#  'g__Mediterraneibacter_A_155507_ASV-3',
#  'g__Pseudorhodoferax_ASV-1',
#  'g__Parabacteroides_B_862066_ASV-3',
#  'g__Chroococcidiopsis_29153_ASV-1',
#  'g__Campylobacter_A_ASV-2',
#  'g__Acidipropionibacterium_ASV-1',
#  'g__Enterocloster_ASV-2',
#  'g__Clostridioides_A_ASV-2',
#  'g__Prevotella_ASV-30',
#  'g__Enterovirga_ASV-1',
#  'g__Planococcus_ASV-1',
#  'g___ASV-107',
#  'g__Croceibacterium_484881_ASV-1',
#  'g__Tepidiphilus_ASV-1',
#  'g__Leptotrichia_A_993641_ASV-2',
#  'g__Acinetobacter_ASV-18',
#  'g__Treponema_C_ASV-1',
#  'g__Clostridium_Q_135822_ASV-1',
#  'g__Lactobacillus_ASV-9',
#  'g__Prevotella_ASV-33',
#  'g___ASV-88',
#  'g__Fusobacterium_C_ASV-7',
#  'g__Dialister_ASV-3',
#  'g___ASV-101',
#  'g__SIO2C1_ASV-7',
#  'g__Lactobacillus_ASV-8',
#  'g__Anaerococcus_ASV-6',
#  'g__Brevibacterium_ASV-5',
#  'g__Weissella_A_338544_ASV-2',
#  'g__Anaerococcus_ASV-7',
#  'g__Dictyoglomus_ASV-1',
#  'g__Gluconobacter_B_ASV-1',
#  'g__Flavobacterium_ASV-3',
#  'g__UMGS1994_ASV-1',
#  'g__Dietzia_ASV-3',
#  'g__Parabacteroides_B_862066_ASV-4',
#  'g__Aeromicrobium_ASV-1',
#  'g__Anaeroglobus_ASV-1',
#  'g___ASV-117',
#  'g___ASV-115',
#  'g___ASV-113',
#  'g___ASV-109',
#  'g__Rubellimicrobium_ASV-2',
#  'g__Kingella_B_563201_ASV-1',
#  'g___ASV-114',
#  'g___ASV-110',
#  'g___ASV-118',
#  'g__Massilia_ASV-8',
#  'g__Phascolarctobacterium_A_ASV-1',
#  'g__F0058_ASV-1',
#  'g___ASV-111',
#  'g__Alloprevotella_ASV-4',
#  'g__Streptococcus_ASV-8',
#  'g__Eubacterium_I_ASV-1',
#  'g__Faecalibacterium_ASV-7',
#  'g__Paracoccus_ASV-8',
#  'g__Pauljensenia_ASV-2',
#  'g__Devosia_A_501803_ASV-1',
#  'g__CAG-83_ASV-1',
#  'g__Filifactor_ASV-2',
#  'g__Varibaculum_ASV-1',
#  'g__Kineococcus_ASV-1',
#  'g__Cutibacterium_ASV-4',
#  'g__Dysosmobacter_ASV-1',
#  'g__Hydrogenophaga_590395_ASV-1',
#  'g__Brevundimonas_ASV-5',
#  'g___ASV-116',
#  'g__Dysosmobacter_ASV-2',
#  'g__Faecalibacterium_ASV-6',
#  'g__Acetobacter_ASV-2',
#  'g__Blautia_A_141780_ASV-2',
#  'g__Leptotrichia_A_993758_ASV-6',
#  'g___ASV-106',
#  'g__Eubacterium_B_ASV-1',
#  'g__Gemmiger_A_73129_ASV-3',
#  'g___ASV-122',
#  'g__Mucilaginibacter_A_ASV-2',
#  'g___ASV-108',
#  'g__Limnohabitans_A_ASV-1',
#  'g__Bacteroides_H_ASV-3',
#  'g___ASV-126',
#  'g__Prevotella_ASV-36',
#  'g__Stenotrophomonas_A_615274_ASV-2',
#  'g__Sphingobacterium_ASV-4',
#  'g__Capnocytophaga_820688_ASV-5',
#  'g__Pontibacter_909804_ASV-1',
#  'g__Prevotella_ASV-32',
#  'g__CAG-273_ASV-1',
#  'g__Ezakiella_ASV-1',
#  'g__UBA1417_ASV-1',
#  'g__Cloacibacterium_ASV-3',
#  'g__RUG115_ASV-1',
#  'g__Fusobacterium_C_ASV-6',
#  'g___ASV-105',
#  'g__Massilia_ASV-9',
#  'g__Rhodoferax_A_585629_ASV-3',
#  'g__Corynebacterium_ASV-23',
#  'g___ASV-119',
#  'g__Staphylococcus_ASV-8',
#  'g__Mucilaginibacter_A_ASV-3',
#  'g__Novosphingobium_485350_ASV-1',
#  'g___ASV-112',
#  'g__Prevotella_ASV-31',
#  'g___ASV-89',
#  'g__Campylobacter_A_ASV-1',
#  'g__UBA6175_ASV-2',
#  'g__Megasphaera_A_38692_ASV-1',
#  'g__Nosocomiicoccus_ASV-1',
#  'g__Fusobacterium_C_ASV-4',
#  'g__Paracoccus_ASV-7',
#  'g__Rhodovarius_ASV-1',
#  'g__Clostridium_T_ASV-2',
#  'g__Solirubrobacter_ASV-1',
#  'g___ASV-124',
#  'g__Nocardioides_A_392796_ASV-5',
#  'g__Lactococcus_A_343306_ASV-1',
#  'g___ASV-131',
#  'g__Solirubrobacter_ASV-2',
#  'g__Leptotrichia_A_993641_ASV-1',
#  'g__Sphingomonas_L_486704_ASV-8',
#  'g__Streptococcus_ASV-12',
#  'g__Rhodococcus_B_ASV-1',
#  'g__Prevotella_ASV-28',
#  'g__Sphingomicrobium_483265_ASV-3',
#  'g__Catonella_ASV-1',
#  'g__Klebsiella_724518_ASV-1',
#  'g__Levyella_ASV-1',
#  'g___ASV-132',
#  'g__Faecalibacterium_ASV-8',
#  'g__Flavobacterium_ASV-2',
#  'g___ASV-136',
#  'g___ASV-142',
#  'g__Microvirga_ASV-1',
#  'g__Helcococcus_ASV-1',
#  'g___ASV-127',
#  'g__Anaerococcus_ASV-9',
#  'g__Brevibacterium_ASV-6',
#  'g__Copromonas_ASV-2',
#  'g__Chryseomicrobium_303841_ASV-1',
#  'g__Gemmiger_A_73129_ASV-4',
#  'g___ASV-138',
#  'g__CAG-269_ASV-1',
#  'g__Alloprevotella_ASV-5',
#  'g__Treponema_C_ASV-2',
#  'g__Dermabacter_ASV-1',
#  'g__Haemophilus_A_ASV-2',
#  'g__Akkermansia_ASV-1',
#  'g__Brevilactibacter_ASV-1',
#  'g__Rothia_ASV-5',
#  'g__Prevotella_ASV-29',
#  'g__CAG-217_ASV-1',
#  'g__Filifactor_ASV-1',
#  'g__Micrococcus_ASV-4',
#  'g__Paenibacillus_J_366884_ASV-1',
#  'g__Blautia_A_141781_ASV-6',
#  'g__Lentilactobacillus_ASV-1',
#  'g__Streptomyces_G_399870_ASV-1',
#  'g__Mediterraneibacter_A_155507_ASV-4',
#  'g__Bariatricus_ASV-1',
#  'g__Dermacoccus_ASV-2',
#  'g__F0058_ASV-2',
#  'g__Berryella_ASV-1',
#  'g__Sphingomonas_L_486704_ASV-9',
#  'g___ASV-134',
#  'g___ASV-141',
#  'g___ASV-152',
#  'g__Chryseomonas_650364_ASV-1',
#  'g___ASV-143',
#  'g__Bosea_ASV-2',
#  'g__Limnohabitans_A_ASV-2',
#  'g__Camelimonas_ASV-1',
#  'g__SIO2C1_ASV-8',
#  'g__Agathobaculum_ASV-2',
#  'g__Oliverpabstia_ASV-2',
#  'g___ASV-148',
#  'g__Leptotrichia_A_993758_ASV-9',
#  'g__Prevotella_ASV-34',
#  'g__Leptotrichia_A_993758_ASV-12',
#  'g__Massilia_ASV-10',
#  'g___ASV-150',
#  'g__Peptoniphilus_B_226777_ASV-1',
#  'g__Methylobacterium_ASV-2',
#  'g__Herbaspirillum_ASV-1',
#  'g__Devosia_A_502124_ASV-1',
#  'g___ASV-144',
#  'g__Skermanella_ASV-3',
#  'g__Modestobacter_ASV-1',
#  'g__Fusobacterium_C_ASV-8',
#  'g___ASV-153',
#  'g__Deinococcus_B_ASV-2',
#  'g___ASV-139',
#  'g__Nocardioides_A_392796_ASV-6',
#  'g___ASV-140',
#  'g__Abditibacterium_ASV-1',
#  'g__Paracoccus_ASV-10',
#  'g__Senegalimassilia_ASV-1',
#  'g__Kineococcus_ASV-2',
#  'g__Clostridium_T_ASV-3',
#  'g___ASV-123',
#  'g__UBA994_ASV-1',
#  'g___ASV-154',
#  'g__Anaerococcus_ASV-8',
#  'g__Vescimonas_ASV-2',
#  'g__Peptoanaerobacter_ASV-1',
#  'g__Prevotella_ASV-38',
#  'g__Bifidobacterium_388775_ASV-6',
#  'g__Streptococcus_ASV-14',
#  'g__Gp6-AA45_ASV-1',
#  'g___ASV-133',
#  'g__Ruminococcus_B_ASV-2',
#  'g__Weissella_A_338544_ASV-3',
#  'g__Pseudoxanthomonas_A_615282_ASV-1',
#  'g__Megasphaera_A_38692_ASV-2',
#  'g__KBS-96_ASV-1',
#  'g__Petroclostridium_ASV-1',
#  'g__Dictyoglomus_ASV-2',
#  'g__Helcococcus_ASV-2',
#  'g__Advenella_ASV-1',
#  'g__Pseudonocardia_ASV-2',
#  'g___ASV-145',
#  'g__Anaerococcus_ASV-10',
#  'g__Blautia_A_141781_ASV-7',
#  'g__Gallicola_ASV-1',
#  'g___ASV-146',
#  'g__Rhodopila_506777_ASV-1',
#  'g__Porphyromonas_A_859426_ASV-2',
#  'g__Ruminococcus_E_ASV-2',
#  'g__Comamonas_F_589250_ASV-6',
#  'g__Acetatifactor_ASV-1',
#  'g__Paucibacter_A_ASV-1',
#  'g__Faecousia_ASV-1',
#  'g___ASV-169',
#  'g__Turicibacter_ASV-1',
#  'g___ASV-160',
#  'g__Enterocloster_ASV-3',
#  'g__Prevotella_ASV-44',
#  'g__Mesorhizobium_F_498388_ASV-5',
#  'g__Tannerella_ASV-3',
#  'g__Teichococcus_ASV-1',
#  'g___ASV-158',
#  'g__Dialister_ASV-5',
#  'g__Lachnospira_ASV-1',
#  'g__Pseudomonas_B_650451_ASV-2',
#  'g__Corynebacterium_ASV-24',
#  'g__Eubacterium_B_ASV-2',
#  'g___ASV-174',
#  'g__Catonella_ASV-2',
#  'g__Phocaeicola_A_858004_ASV-3',
#  'g__Fannyhessea_ASV-2',
#  'g__Acinetobacter_ASV-21',
#  'g___ASV-182',
#  'g__Stomatobaculum_ASV-1',
#  'g___ASV-185',
#  'g__Limosilactobacillus_ASV-3',
#  'g__Staphylococcus_ASV-9',
#  'g___ASV-156',
#  'g___ASV-137',
#  'g__Rickettsia_ASV-1',
#  'g___ASV-161',
#  'g__Ventrimonas_ASV-1',
#  'g___ASV-163',
#  'g___ASV-165',
#  'g__Acinetobacter_ASV-20',
#  'g__Brevibacterium_ASV-7',
#  'g___ASV-167',
#  'g__Enterococcus_E_ASV-1',
#  'g__Aeromicrobium_ASV-2',
#  'g__Rhodococcus_B_ASV-2',
#  'g___ASV-171',
#  'g__Peptoniphilus_A_ASV-4',
#  'g___ASV-159',
#  'g__Sphingomonas_L_486704_ASV-10',
#  'g___ASV-120',
#  'g__Devosia_A_502124_ASV-3',
#  'g__Desulfovibrio_R_446353_ASV-1',
#  'g___ASV-180',
#  'g__Enterovirga_ASV-2',
#  'g__Tannerella_ASV-2',
#  'g___ASV-162',
#  'g__Roseomonas_A_507160_ASV-2',
#  'g__Acinetobacter_ASV-19',
#  'g__Nitrosocosmicus_ASV-1',
#  'g__SIO2C1_ASV-11',
#  'g__Streptococcus_ASV-16',
#  'g__Corynebacterium_ASV-25',
#  'g__Flaviaesturariibacter_ASV-1',
#  'g__Paenalcaligenes_ASV-1',
#  'g__Alcaligenes_ASV-1',
#  'g__Sphingomicrobium_483265_ASV-4',
#  'g__Treponema_B_986142_ASV-2',
#  'g__Cohnella_ASV-1',
#  'g__Sphingomonas_L_486704_ASV-12',
#  'g__Devosia_A_502124_ASV-2',
#  'g___ASV-177',
#  'g__Coprococcus_A_121497_ASV-1',
#  'g__SIO2C1_ASV-10',
#  'g___ASV-157',
#  'g___ASV-166',
#  'g__Prevotella_ASV-41',
#  'g__Sphingobium_A_485959_ASV-4',
#  'g__ER4_ASV-1',
#  'g___ASV-179',
#  'g__Pauljensenia_ASV-4',
#  'g__Anaerococcus_ASV-12',
#  'g___ASV-172',
#  'g__Alistipes_A_871400_ASV-1',
#  'g__Prevotella_ASV-37',
#  'g___ASV-164',
#  'g__Kerstersia_ASV-2',
#  'g__Actinomyces_ASV-4',
#  'g__Pseudomonas_A_ASV-2',
#  'g__Dialister_ASV-4',
#  'g__Gemmiger_A_73129_ASV-5',
#  'g__Cutibacterium_ASV-5',
#  'g___ASV-98',
#  'g__Gaiella_ASV-1',
#  'g___ASV-175',
#  'g__Capnocytophaga_820688_ASV-6',
#  'g__Bacillus_P_294101_ASV-1',
#  'g___ASV-168',
#  'g___ASV-65',
#  'g__Prevotella_ASV-39',
#  'g__Copromonas_ASV-3',
#  'g__Methanobrevibacter_A_ASV-1',
#  'g__Corynebacterium_ASV-21',
#  'g__Leptotrichia_A_993758_ASV-8',
#  'g__Solirubrobacter_ASV-3',
#  'g___ASV-191',
#  'g__Faecousia_ASV-2',
#  'g__Sphingomonas_L_486704_ASV-11',
#  'g___ASV-121',
#  'g___ASV-186',
#  'g__Kingella_B_563201_ASV-2',
#  'g___ASV-199',
#  'g__Campylobacter_A_ASV-3',
#  'g___ASV-206',
#  'g__Arachnia_ASV-1',
#  'g___ASV-155',
#  'g__Eremococcus_ASV-1',
#  'g___ASV-188',
#  'g__Peptostreptococcus_ASV-5',
#  'g__Palsa-739_ASV-2',
#  'g__Lautropia_ASV-2',
#  'g___ASV-198',
#  'g__Sphingomonas_L_486704_ASV-13',
#  'g__W5053_ASV-1',
#  'g__VAYN01_ASV-1',
#  'g__Alistipes_A_871400_ASV-2',
#  'g__Devosia_A_502124_ASV-4',
#  'g__Capnocytophaga_820688_ASV-7',
#  'g___ASV-129',
#  'g__Schaedlerella_ASV-1',
#  'g___ASV-181',
#  'g__Dialister_ASV-8',
#  'g___ASV-192',
#  'g__Gaiella_ASV-2',
#  'g__Loigolactobacillus_ASV-2',
#  'g___ASV-200',
#  'g__Geodermatophilus_A_ASV-1',
#  'g__Bradyrhizobium_ASV-1',
#  'g___ASV-194',
#  'g__UphvI-Ar2_ASV-1',
#  'g__Yimella_ASV-2',
#  'g__Flavisolibacter_B_ASV-1',
#  'g__Actinoplanes_ASV-1',
#  'g__Prevotella_ASV-40',
#  'g___ASV-176',
#  'g__Schaedlerella_ASV-2',
#  'g___ASV-189',
#  'g__Flaviaesturariibacter_ASV-2',
#  'g__Parvimonas_ASV-3',
#  'g__Lentilactobacillus_ASV-2',
#  'g__Dialister_ASV-7',
#  'g__Mucilaginibacter_A_ASV-5',
#  'g__Limosilactobacillus_ASV-4',
#  'g___ASV-203',
#  'g__Gleimia_ASV-1',
#  'g__Pseudomonas_E_647464_ASV-6',
#  'g___ASV-208',
#  'g__QHXM01_ASV-2',
#  'g__Bosea_ASV-3',
#  'g__Flavobacterium_ASV-4',
#  'g__Frisingicoccus_ASV-1',
#  'g__Eggerthella_ASV-1',
#  'g__Demequina_ASV-1',
#  'g__Alteraurantiacibacter_ASV-1',
#  'g__Bryocella_ASV-1',
#  'g___ASV-183',
#  'g__Bacteroides_H_ASV-6',
#  'g___ASV-207',
#  'g__Lancefieldella_ASV-2',
#  'g__Devosia_A_502124_ASV-5',
#  'g__Arthrobacter_D_ASV-2',
#  'g__Anaerococcus_ASV-13',
#  'g__Aliicoccus_ASV-2',
#  'g__Chryseobacterium_796614_ASV-3',
#  'g__Oribacterium_ASV-1',
#  'g__Treponema_B_986141_ASV-1',
#  'g__Pseudonocardia_ASV-3',
#  'g__Friedmanniella_ASV-3',
#  'g__Corynebacterium_ASV-27',
#  'g__Mediterraneibacter_A_155507_ASV-5',
#  'g__Enterocloster_ASV-4',
#  'g__Acinetobacter_ASV-24',
#  'g__CAG-41_ASV-1',
#  'g__Acinetobacter_ASV-23',
#  'g__Anaerococcus_ASV-11',
#  'g__CAG-127_ASV-1',
#  'g__Clostridium_T_ASV-4',
#  'g__Paucilactobacillus_ASV-1',
#  'g__Mycobacterium_ASV-4',
#  'g__Peptoniphilus_C_ASV-1',
#  'g___ASV-202',
#  'g__Hymenobacter_910554_ASV-2',
#  'g__Leptotrichia_A_993758_ASV-14',
#  'g__Bacteroides_H_ASV-4',
#  'g___ASV-125',
#  'g__Butyribacter_ASV-1',
#  'g__Lachnoclostridium_A_130679_ASV-1',
#  'g___ASV-201',
#  'g__Bacillus_P_294101_ASV-2',
#  'g__Allosphingosinicella_ASV-1',
#  'g__Microbacterium_A_383184_ASV-3',
#  'g__Parvimonas_ASV-5',
#  'g__Niveispirillum_ASV-1',
#  'g__Aequorivita_ASV-1',
#  'g___ASV-217',
#  'g___ASV-238',
#  'g__Rhodopila_506777_ASV-2',
#  'g__Actinomyces_ASV-5',
#  'g___ASV-228',
#  'g___ASV-187',
#  'g__Eubacterium_R_ASV-1',
#  'g__Calothrix_ASV-1',
#  'g__Prevotella_ASV-35',
#  'g__Centipeda_ASV-2',
#  'g__Phenylobacterium_ASV-2',
#  'g__Lachnospira_ASV-2',
#  'g__Acinetobacter_ASV-22',
#  'g___ASV-242',
#  'g__Parvimonas_ASV-4',
#  'g__Lichenihabitans_ASV-1',
#  'g__Leptotrichia_A_993641_ASV-4',
#  'g__Ligilactobacillus_ASV-2',
#  'g___ASV-135',
#  'g___ASV-232',
#  'g__Leuconostoc_B_ASV-4',
#  'g__Selenomonas_B_42762_ASV-1',
#  'g___ASV-184',
#  'g__Dialister_ASV-6',
#  'g__Paraburkholderia_580243_ASV-1',
#  'g__Gp6-AA45_ASV-2',
#  'g__Helcococcus_ASV-3',
#  'g__Streptomyces_G_399870_ASV-2',
#  'g___ASV-234',
#  'g__Anaerobutyricum_ASV-2',
#  'g__Alterileibacterium_ASV-1',
#  'g__Porphyromonas_A_859426_ASV-3',
#  'g__Capnocytophaga_820688_ASV-8',
#  'g__Flavobacterium_ASV-6',
#  'g__Hyphomicrobium_A_ASV-1',
#  'g__Flavobacterium_ASV-7',
#  'g__Flavobacterium_ASV-9',
#  'g__Shinella_ASV-1',
#  'g__Mucilaginibacter_A_ASV-7',
#  'g___ASV-216',
#  'g__Blautia_A_141781_ASV-8',
#  'g__Sphingomonas_L_486704_ASV-14',
#  'g__Eubacterium_G_ASV-1',
#  'g__Prevotella_ASV-47',
#  'g__Salinicoccus_ASV-1',
#  'g__Niastella_ASV-1',
#  'g__Gulosibacter_ASV-1',
#  'g__Pseudomonas_E_647464_ASV-7',
#  'g___ASV-204',
#  'g__Paracoccus_ASV-11',
#  'g__Cryptobacteroides_ASV-2',
#  'g__Intestinibacter_ASV-2',
#  'g___ASV-225',
#  'g__Terrisporobacter_ASV-2',
#  'g__Anaerococcus_ASV-15',
#  'g__Fen-455_ASV-1',
#  'g__Bosea_ASV-4',
#  'g__Mucilaginibacter_A_ASV-8',
#  'g__Cloacibacterium_ASV-4',
#  'g__Anaerococcus_ASV-14',
#  'g__Cryptobacteroides_ASV-1',
#  'g___ASV-233',
#  'g__Pseudomonas_E_647464_ASV-8',
#  'g__S5-A14a_ASV-2',
#  'g__Prevotella_ASV-48',
#  'g__Corynebacterium_ASV-29',
#  'g__Rothia_ASV-7',
#  'g__Lagierella_ASV-2',
#  ...]

# %%
def rclr_transform(df, pseudocount=1e-6):
    """
    Applies Robust Centered Log-Ratio (RCLR) transformation to a DataFrame.
    Zeros are ignored in the geometric mean calculation per sample.
    """
    # Convert sparse to dense if needed
    df = df.sparse.to_dense()

    # Replace 0 with np.nan to ignore in log and mean
    df_masked = df.replace(0, np.nan)

    # Apply log (with pseudocount only where needed)
    log_df = np.log(df_masked + pseudocount)

    # Subtract mean of each row (feature)
    rclr_df = log_df.sub(log_df.mean(axis=1, skipna=True), axis=0)

    return rclr_df



rclr_df = rclr_transform(df)

# %%
# Map the 'group' column from metadata to df based on matching index
rclr_df['group'] = metadata.loc[rclr_df.index, 'group']
rclr_df
# Out:
#             g__Staphylococcus_ASV-1  g__Staphylococcus_ASV-2  \
# #sample-id
# Ca009STL                  -0.203199                -1.301811
# 900221                          NaN                      NaN
# Ca010EBL                   3.054638                 2.731238
# 900460                     1.657654                 1.657654
# 900051                     3.756053                 2.448896
# ...                             ...                      ...
# 9004032                         NaN                      NaN
# Ca006ONL                   3.315374                 1.783898
# Ca006ONL2                       NaN                      NaN
# Ca006ONNL                  3.708304                 1.790251
# Ca006ONNL2                 3.858727                 3.197737
#
#             g__Streptococcus_ASV-1  g__Micrococcus_ASV-1  \
# #sample-id
# Ca009STL                  0.713092              0.713092
# 900221                         NaN                   NaN
# Ca010EBL                  0.803347                   NaN
# 900460                    3.139258             -0.357249
# 900051                    2.021452                   NaN
# ...                            ...                   ...
# 9004032                   2.749671                   NaN
# Ca006ONL                  1.090750                   NaN
# Ca006ONL2                      NaN                   NaN
# Ca006ONNL                 0.729379             -0.774698
# Ca006ONNL2                0.437727              2.047165
#
#             g__Corynebacterium_ASV-2  g__Streptococcus_ASV-2  g___ASV-1  \
# #sample-id
# Ca009STL                         NaN                     NaN   2.639770
# 900221                     -2.027367                     NaN        NaN
# Ca010EBL                         NaN                     NaN   2.019742
# 900460                           NaN                2.733793        NaN
# 900051                           NaN                     NaN        NaN
# ...                              ...                     ...        ...
# 9004032                          NaN                     NaN        NaN
# Ca006ONL                   -1.394155                     NaN   2.243430
# Ca006ONL2                        NaN                     NaN        NaN
# Ca006ONNL                   0.611596                     NaN   1.751030
# Ca006ONNL2                 -0.478563               -0.478563  -0.478563
#
#             g__Prevotella_ASV-1  g___ASV-2  g__Streptococcus_ASV-3  ...  \
# #sample-id                                                          ...
# Ca009STL                    NaN  -0.385521                1.140536  ...
# 900221                      NaN        NaN                     NaN  ...
# Ca010EBL                1.02649  -1.276094                0.515665  ...
# 900460                      NaN        NaN                1.945336  ...
# 900051                      NaN        NaN               -1.379744  ...
# ...                         ...        ...                     ...  ...
# 9004032                     NaN        NaN               -0.746836  ...
# Ca006ONL                    NaN  -1.394155                0.551754  ...
# Ca006ONL2                   NaN        NaN                     NaN  ...
# Ca006ONNL                   NaN  -0.369233               -1.467845  ...
# Ca006ONNL2                  NaN   1.226184                0.620049  ...
#
#             g__Fluviicola_ASV-2  g___ASV-369  g__Flavobacterium_ASV-25  \
# #sample-id
# Ca009STL                    NaN          NaN                       NaN
# 900221                      NaN          NaN                       NaN
# Ca010EBL                    NaN          NaN                       NaN
# 900460                      NaN          NaN                       NaN
# 900051                      NaN          NaN                       NaN
# ...                         ...          ...                       ...
# 9004032                     NaN          NaN                       NaN
# Ca006ONL                    NaN          NaN                       NaN
# Ca006ONL2                   NaN          NaN                       NaN
# Ca006ONNL                   NaN          NaN                       NaN
# Ca006ONNL2                  NaN          NaN                       NaN
#
#             g___ASV-434  g__Staphylococcus_ASV-33  g__Flavobacterium_ASV-8  \
# #sample-id
# Ca009STL            NaN                       NaN                      NaN
# 900221              NaN                       NaN                      NaN
# Ca010EBL            NaN                       NaN                      NaN
# 900460              NaN                       NaN                      NaN
# 900051              NaN                       NaN                      NaN
# ...                 ...                       ...                      ...
# 9004032             NaN                       NaN                      NaN
# Ca006ONL            NaN                       NaN                      NaN
# Ca006ONL2           NaN                       NaN                      NaN
# Ca006ONNL           NaN                       NaN                      NaN
# Ca006ONNL2          NaN                       NaN                      NaN
#
#             g___ASV-489  g__Staphylococcus_ASV-34  g__Streptococcus_ASV-37  \
# #sample-id
# Ca009STL            NaN                       NaN                      NaN
# 900221              NaN                       NaN                      NaN
# Ca010EBL            NaN                       NaN                      NaN
# 900460              NaN                       NaN                      NaN
# 900051              NaN                       NaN                      NaN
# ...                 ...                       ...                      ...
# 9004032             NaN                       NaN                      NaN
# Ca006ONL            NaN                       NaN                      NaN
# Ca006ONL2           NaN                       NaN                      NaN
# Ca006ONNL           NaN                       NaN                      NaN
# Ca006ONNL2          NaN                       NaN                      NaN
#
#                 group
# #sample-id
# Ca009STL     skin-ADL
# 900221       skin-ADL
# Ca010EBL     skin-ADL
# 900460       skin-ADL
# 900051       skin-ADL
# ...               ...
# 9004032      skin-ADL
# Ca006ONL     skin-ADL
# Ca006ONL2    skin-ADL
# Ca006ONNL   skin-ADNL
# Ca006ONNL2  skin-ADNL
#
# [305 rows x 2262 columns]

# %%
rclr_df['group'].value_counts()

# rclr_df = rclr_df.rename(columns={
#     col: col.replace("g__Haemophilus_D_734546", "g__Haemophilus")
#     for col in df.columns
#     if col.startswith("g__Haemophilus_D_734546")
# })


# rclr_df = rclr_df.rename(columns={
#     col: col.replace("g__Veillonella_A", "g__Veillonella")
#     for col in df.columns
#     if col.startswith("g__Veillonella_A")
# })
# Out:
# group
# skin-ADNL    111
# skin-ADL     107
# skin-H        87
# Name: count, dtype: int64

# %%
def pairwise_mannwhitney_bh(df, feature, group_col='group'):
    groups = df[group_col].unique()
    comparisons = list(itertools.combinations(groups, 2))

    raw_pvals = []
    labels = []
    pairs = []

    for g1, g2 in comparisons:
        x = df[df[group_col] == g1][feature].dropna()
        y = df[df[group_col] == g2][feature].dropna()
        _, p = mannwhitneyu(x, y, alternative='two-sided')
        raw_pvals.append(p)
        labels.append(f"{g1} vs {g2}")
        pairs.append((g1, g2))

    _, pvals_corrected, _, _ = multipletests(raw_pvals, method='fdr_bh')

    results_df = pd.DataFrame({
        'Comparison': labels,
        'Pair': pairs,
        'Raw p-value': raw_pvals,
        'BH-corrected p-value': pvals_corrected
    })

    return results_df

# %%
# Filter for skin samples
skin_samples = rclr_df[rclr_df['group'].isin(['skin-ADL', 'skin-ADNL', 'skin-H'])]
skin_samples
# Out:
#             g__Staphylococcus_ASV-1  g__Staphylococcus_ASV-2  \
# #sample-id
# Ca009STL                  -0.203199                -1.301811
# 900221                          NaN                      NaN
# Ca010EBL                   3.054638                 2.731238
# 900460                     1.657654                 1.657654
# 900051                     3.756053                 2.448896
# ...                             ...                      ...
# 9004032                         NaN                      NaN
# Ca006ONL                   3.315374                 1.783898
# Ca006ONL2                       NaN                      NaN
# Ca006ONNL                  3.708304                 1.790251
# Ca006ONNL2                 3.858727                 3.197737
#
#             g__Streptococcus_ASV-1  g__Micrococcus_ASV-1  \
# #sample-id
# Ca009STL                  0.713092              0.713092
# 900221                         NaN                   NaN
# Ca010EBL                  0.803347                   NaN
# 900460                    3.139258             -0.357249
# 900051                    2.021452                   NaN
# ...                            ...                   ...
# 9004032                   2.749671                   NaN
# Ca006ONL                  1.090750                   NaN
# Ca006ONL2                      NaN                   NaN
# Ca006ONNL                 0.729379             -0.774698
# Ca006ONNL2                0.437727              2.047165
#
#             g__Corynebacterium_ASV-2  g__Streptococcus_ASV-2  g___ASV-1  \
# #sample-id
# Ca009STL                         NaN                     NaN   2.639770
# 900221                     -2.027367                     NaN        NaN
# Ca010EBL                         NaN                     NaN   2.019742
# 900460                           NaN                2.733793        NaN
# 900051                           NaN                     NaN        NaN
# ...                              ...                     ...        ...
# 9004032                          NaN                     NaN        NaN
# Ca006ONL                   -1.394155                     NaN   2.243430
# Ca006ONL2                        NaN                     NaN        NaN
# Ca006ONNL                   0.611596                     NaN   1.751030
# Ca006ONNL2                 -0.478563               -0.478563  -0.478563
#
#             g__Prevotella_ASV-1  g___ASV-2  g__Streptococcus_ASV-3  ...  \
# #sample-id                                                          ...
# Ca009STL                    NaN  -0.385521                1.140536  ...
# 900221                      NaN        NaN                     NaN  ...
# Ca010EBL                1.02649  -1.276094                0.515665  ...
# 900460                      NaN        NaN                1.945336  ...
# 900051                      NaN        NaN               -1.379744  ...
# ...                         ...        ...                     ...  ...
# 9004032                     NaN        NaN               -0.746836  ...
# Ca006ONL                    NaN  -1.394155                0.551754  ...
# Ca006ONL2                   NaN        NaN                     NaN  ...
# Ca006ONNL                   NaN  -0.369233               -1.467845  ...
# Ca006ONNL2                  NaN   1.226184                0.620049  ...
#
#             g__Fluviicola_ASV-2  g___ASV-369  g__Flavobacterium_ASV-25  \
# #sample-id
# Ca009STL                    NaN          NaN                       NaN
# 900221                      NaN          NaN                       NaN
# Ca010EBL                    NaN          NaN                       NaN
# 900460                      NaN          NaN                       NaN
# 900051                      NaN          NaN                       NaN
# ...                         ...          ...                       ...
# 9004032                     NaN          NaN                       NaN
# Ca006ONL                    NaN          NaN                       NaN
# Ca006ONL2                   NaN          NaN                       NaN
# Ca006ONNL                   NaN          NaN                       NaN
# Ca006ONNL2                  NaN          NaN                       NaN
#
#             g___ASV-434  g__Staphylococcus_ASV-33  g__Flavobacterium_ASV-8  \
# #sample-id
# Ca009STL            NaN                       NaN                      NaN
# 900221              NaN                       NaN                      NaN
# Ca010EBL            NaN                       NaN                      NaN
# 900460              NaN                       NaN                      NaN
# 900051              NaN                       NaN                      NaN
# ...                 ...                       ...                      ...
# 9004032             NaN                       NaN                      NaN
# Ca006ONL            NaN                       NaN                      NaN
# Ca006ONL2           NaN                       NaN                      NaN
# Ca006ONNL           NaN                       NaN                      NaN
# Ca006ONNL2          NaN                       NaN                      NaN
#
#             g___ASV-489  g__Staphylococcus_ASV-34  g__Streptococcus_ASV-37  \
# #sample-id
# Ca009STL            NaN                       NaN                      NaN
# 900221              NaN                       NaN                      NaN
# Ca010EBL            NaN                       NaN                      NaN
# 900460              NaN                       NaN                      NaN
# 900051              NaN                       NaN                      NaN
# ...                 ...                       ...                      ...
# 9004032             NaN                       NaN                      NaN
# Ca006ONL            NaN                       NaN                      NaN
# Ca006ONL2           NaN                       NaN                      NaN
# Ca006ONNL           NaN                       NaN                      NaN
# Ca006ONNL2          NaN                       NaN                      NaN
#
#                 group
# #sample-id
# Ca009STL     skin-ADL
# 900221       skin-ADL
# Ca010EBL     skin-ADL
# 900460       skin-ADL
# 900051       skin-ADL
# ...               ...
# 9004032      skin-ADL
# Ca006ONL     skin-ADL
# Ca006ONL2    skin-ADL
# Ca006ONNL   skin-ADNL
# Ca006ONNL2  skin-ADNL
#
# [305 rows x 2262 columns]

# %%
def pairwise_mannwhitney_bh(df, feature, group_col='group'):
    groups = df[group_col].unique()
    comparisons = list(itertools.combinations(groups, 2))

    raw_pvals = []
    labels = []
    pairs = []

    for g1, g2 in comparisons:
        x = df[df[group_col] == g1][feature].dropna()
        y = df[df[group_col] == g2][feature].dropna()

        # Skip comparison if either group has no data
        if len(x) == 0 or len(y) == 0:
            continue

        _, p = mannwhitneyu(x, y, alternative='two-sided')
        raw_pvals.append(p)
        labels.append(f"{g1} vs {g2}")
        pairs.append((g1, g2))

    if len(raw_pvals) == 0:
        return pd.DataFrame(columns=['Comparison', 'Pair', 'Raw p-value', 'BH-corrected p-value'])

    _, pvals_corrected, _, _ = multipletests(raw_pvals, method='fdr_bh')

    results_df = pd.DataFrame({
        'Comparison': labels,
        'Pair': pairs,
        'Raw p-value': raw_pvals,
        'BH-corrected p-value': pvals_corrected
    })

    return results_df

# %%
# Define custom color palette
group_palette = {
    'skin-H': '#ADD8E6',     # baby blue
    'skin-ADNL': '#FFDAB9',  # peach
    'skin-ADL': '#E31A1C'    # red
}

strip_palette = {
    'skin-H': '#6CA6CD',     # darker baby blue
    'skin-ADNL': '#E6AC8F',  # darker peach
    'skin-ADL': '#A50000'    # darker red
}

# %%
def plot_multi_taxa_boxplots(data, taxa_list, group_palette, strip_palette, title_name, order=['skin-H', 'skin-ADNL', 'skin-ADL']):
    n_taxa = len(taxa_list)
    group_count = len(order)

    # Prepare long format dataframe
    plot_data = []
    for i, taxon in enumerate(taxa_list):
        for j, group in enumerate(order):
            xpos = i * group_count + j
            values = data.loc[data['group'] == group, taxon]
            for v in values:
                plot_data.append({
                    'x': xpos,
                    'taxon': taxon.replace(' g__', '').split('_')[0],
                    'value': v,
                    'group': group
                })

    plot_df = pd.DataFrame(plot_data)

    # Plot
    fig, ax = plt.subplots(figsize=(n_taxa * 2.5, 5))

    sns.boxplot(
        data=plot_df,
        x='x',
        y='value',
        hue='group',
        palette=group_palette,
        width=0.5,
        fliersize=0,
        dodge=False,
        ax=ax
    )

    sns.stripplot(
        data=plot_df,
        x='x',
        y='value',
        hue='group',
        palette=strip_palette,
        dodge=False,
        jitter=True,
        size=4,
        alpha=0.75,
        ax=ax
    )

    # Remove duplicated legends
    handles, labels = ax.get_legend_handles_labels()

    # Count samples per group
    group_counts = {g: data[data['group'] == g].shape[0] for g in order}

    # Create updated legend labels
    legend_labels = [f"{g.replace('skin-', '')} (n={group_counts[g]})" for g in order]

    # Add updated legend — horizontally at bottom-left
    ax.legend(
        handles[:3],
        legend_labels,
        # title='Sample',
        loc='lower left',
        bbox_to_anchor=(0.35, -0.35),  # adjust y for spacing below plot
        ncol=len(order),            # show horizontally
        fontsize=12,
        title_fontsize=10,
        frameon=True,
        borderaxespad=0
    )


    # X-tick labels per taxon group
    xtick_positions = [i * group_count + 1 for i in range(n_taxa)]
    # xtick_labels = [taxon.replace('g__', '').split('_')[0] for taxon in taxa_list]
    xtick_labels = [taxon.replace('g__', '').replace('_ASV-', '\nASV-') for taxon in taxa_list]
    ax.set_xticks(xtick_positions)
    ax.set_xticklabels(xtick_labels, fontsize=14)

    ax.set_xlim(-0.5, n_taxa * group_count - 0.5)
    ax.set_ylabel("RCLR-transformed abundance", fontsize=14)
    ax.tick_params(axis='y', labelsize=14)
    ax.set_xlabel(" ")

    ax.set_title(title_name, fontsize=18, pad=14)

    # ------------------------
    # Annotate p-values
    # ------------------------
    for i, taxon in enumerate(taxa_list):
        stats = pairwise_mannwhitney_bh(data, taxon)
        y_max = data[taxon].max()
        offset = y_max * 0.15

        for k, row in stats.iterrows():
            g1, g2 = row['Pair']
            pval = row['BH-corrected p-value']
            xpos1 = i * group_count + order.index(g1)
            xpos2 = i * group_count + order.index(g2)
            x = (xpos1 + xpos2) / 2
            y = y_max + offset * k

            stars = '***' if pval < 0.001 else '**' if pval < 0.01 else '*' if pval < 0.05 else ''
            label = f"{pval:.1e} {stars}"

            ax.plot([xpos1, xpos1, xpos2, xpos2], [y - 0.01, y, y, y - 0.01], lw=1, color='black')
            ax.text(x, y + 0.01, label, ha='center', va='bottom', fontsize=12)

    sns.despine()
    fig.tight_layout()
    return fig

# %%
taxa_list = ['g__Streptococcus_ASV-1', 'g__Streptococcus_ASV-2', 'g__Staphylococcus_ASV-1',
            'g__Micrococcus_ASV-1', 'g__Veillonella_A_ASV-1', 'g__Haemophilus_D_734546_ASV-1']
fig = plot_multi_taxa_boxplots(skin_samples, taxa_list, group_palette, strip_palette, 'Differential Taxa on Skin by Atopic Dermatitis Status')
fig.savefig('../Plots/Analysis_figures/RCLR_Abundance/rclr_multi_taxa_boxplot_all_taxa_ASV.png', dpi=600)
# Out:
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/seaborn/_oldcore.py:1075: FutureWarning: When grouping with a length-1 list-like, you will need to pass a length-1 tuple to get_group in a future version of pandas. Pass `(name,)` instead of `name` to silence this warning.
#   data_subset = grouped_data.get_group(pd_key)

# %% [markdown]
# ## Show correlation with lesion severity

# %%
# Map o_scorad and pid from metadata to skin_samples based on matching indexes
skin_samples = skin_samples.merge(metadata[['o_scorad']], left_index=True, right_index=True)
skin_samples = skin_samples.merge(metadata[['pid']], left_index=True, right_index=True)

skin_samples
# Out:
#             g__Staphylococcus_ASV-1  g__Staphylococcus_ASV-2  \
# #sample-id
# Ca009STL                  -0.203199                -1.301811
# 900221                          NaN                      NaN
# Ca010EBL                   3.054638                 2.731238
# 900460                     1.657654                 1.657654
# 900051                     3.756053                 2.448896
# ...                             ...                      ...
# 9004032                         NaN                      NaN
# Ca006ONL                   3.315374                 1.783898
# Ca006ONL2                       NaN                      NaN
# Ca006ONNL                  3.708304                 1.790251
# Ca006ONNL2                 3.858727                 3.197737
#
#             g__Streptococcus_ASV-1  g__Micrococcus_ASV-1  \
# #sample-id
# Ca009STL                  0.713092              0.713092
# 900221                         NaN                   NaN
# Ca010EBL                  0.803347                   NaN
# 900460                    3.139258             -0.357249
# 900051                    2.021452                   NaN
# ...                            ...                   ...
# 9004032                   2.749671                   NaN
# Ca006ONL                  1.090750                   NaN
# Ca006ONL2                      NaN                   NaN
# Ca006ONNL                 0.729379             -0.774698
# Ca006ONNL2                0.437727              2.047165
#
#             g__Corynebacterium_ASV-2  g__Streptococcus_ASV-2  g___ASV-1  \
# #sample-id
# Ca009STL                         NaN                     NaN   2.639770
# 900221                     -2.027367                     NaN        NaN
# Ca010EBL                         NaN                     NaN   2.019742
# 900460                           NaN                2.733793        NaN
# 900051                           NaN                     NaN        NaN
# ...                              ...                     ...        ...
# 9004032                          NaN                     NaN        NaN
# Ca006ONL                   -1.394155                     NaN   2.243430
# Ca006ONL2                        NaN                     NaN        NaN
# Ca006ONNL                   0.611596                     NaN   1.751030
# Ca006ONNL2                 -0.478563               -0.478563  -0.478563
#
#             g__Prevotella_ASV-1  g___ASV-2  g__Streptococcus_ASV-3  ...  \
# #sample-id                                                          ...
# Ca009STL                    NaN  -0.385521                1.140536  ...
# 900221                      NaN        NaN                     NaN  ...
# Ca010EBL                1.02649  -1.276094                0.515665  ...
# 900460                      NaN        NaN                1.945336  ...
# 900051                      NaN        NaN               -1.379744  ...
# ...                         ...        ...                     ...  ...
# 9004032                     NaN        NaN               -0.746836  ...
# Ca006ONL                    NaN  -1.394155                0.551754  ...
# Ca006ONL2                   NaN        NaN                     NaN  ...
# Ca006ONNL                   NaN  -0.369233               -1.467845  ...
# Ca006ONNL2                  NaN   1.226184                0.620049  ...
#
#             g__Flavobacterium_ASV-25  g___ASV-434  g__Staphylococcus_ASV-33  \
# #sample-id
# Ca009STL                         NaN          NaN                       NaN
# 900221                           NaN          NaN                       NaN
# Ca010EBL                         NaN          NaN                       NaN
# 900460                           NaN          NaN                       NaN
# 900051                           NaN          NaN                       NaN
# ...                              ...          ...                       ...
# 9004032                          NaN          NaN                       NaN
# Ca006ONL                         NaN          NaN                       NaN
# Ca006ONL2                        NaN          NaN                       NaN
# Ca006ONNL                        NaN          NaN                       NaN
# Ca006ONNL2                       NaN          NaN                       NaN
#
#             g__Flavobacterium_ASV-8  g___ASV-489  g__Staphylococcus_ASV-34  \
# #sample-id
# Ca009STL                        NaN          NaN                       NaN
# 900221                          NaN          NaN                       NaN
# Ca010EBL                        NaN          NaN                       NaN
# 900460                          NaN          NaN                       NaN
# 900051                          NaN          NaN                       NaN
# ...                             ...          ...                       ...
# 9004032                         NaN          NaN                       NaN
# Ca006ONL                        NaN          NaN                       NaN
# Ca006ONL2                       NaN          NaN                       NaN
# Ca006ONNL                       NaN          NaN                       NaN
# Ca006ONNL2                      NaN          NaN                       NaN
#
#             g__Streptococcus_ASV-37      group  o_scorad        pid
# #sample-id
# Ca009STL                        NaN   skin-ADL        40  Ca-009-ST
# 900221                          NaN   skin-ADL        34  Ca-101-ID
# Ca010EBL                        NaN   skin-ADL        21  Ca-010-EB
# 900460                          NaN   skin-ADL        40  Ca-146-SM
# 900051                          NaN   skin-ADL        41  Ca-011-LQ
# ...                             ...        ...       ...        ...
# 9004032                         NaN   skin-ADL        78  Ca-126-KB
# Ca006ONL                        NaN   skin-ADL        34  Ca-006-ON
# Ca006ONL2                       NaN   skin-ADL        34  Ca-006-ON
# Ca006ONNL                       NaN  skin-ADNL        34  Ca-006-ON
# Ca006ONNL2                      NaN  skin-ADNL        34  Ca-006-ON
#
# [305 rows x 2264 columns]

# %%
# Convert 'o_scorad' to numeric (coerce errors to NaN)
skin_samples['o_scorad'] = pd.to_numeric(metadata['o_scorad'], errors='coerce')

# Drop rows with missing SCORAD values
skin_samples = skin_samples.dropna(subset=['o_scorad'])
skin_samples
# Out:
#             g__Staphylococcus_ASV-1  g__Staphylococcus_ASV-2  \
# #sample-id
# Ca009STL                  -0.203199                -1.301811
# 900221                          NaN                      NaN
# Ca010EBL                   3.054638                 2.731238
# 900460                     1.657654                 1.657654
# 900051                     3.756053                 2.448896
# ...                             ...                      ...
# 9004032                         NaN                      NaN
# Ca006ONL                   3.315374                 1.783898
# Ca006ONL2                       NaN                      NaN
# Ca006ONNL                  3.708304                 1.790251
# Ca006ONNL2                 3.858727                 3.197737
#
#             g__Streptococcus_ASV-1  g__Micrococcus_ASV-1  \
# #sample-id
# Ca009STL                  0.713092              0.713092
# 900221                         NaN                   NaN
# Ca010EBL                  0.803347                   NaN
# 900460                    3.139258             -0.357249
# 900051                    2.021452                   NaN
# ...                            ...                   ...
# 9004032                   2.749671                   NaN
# Ca006ONL                  1.090750                   NaN
# Ca006ONL2                      NaN                   NaN
# Ca006ONNL                 0.729379             -0.774698
# Ca006ONNL2                0.437727              2.047165
#
#             g__Corynebacterium_ASV-2  g__Streptococcus_ASV-2  g___ASV-1  \
# #sample-id
# Ca009STL                         NaN                     NaN   2.639770
# 900221                     -2.027367                     NaN        NaN
# Ca010EBL                         NaN                     NaN   2.019742
# 900460                           NaN                2.733793        NaN
# 900051                           NaN                     NaN        NaN
# ...                              ...                     ...        ...
# 9004032                          NaN                     NaN        NaN
# Ca006ONL                   -1.394155                     NaN   2.243430
# Ca006ONL2                        NaN                     NaN        NaN
# Ca006ONNL                   0.611596                     NaN   1.751030
# Ca006ONNL2                 -0.478563               -0.478563  -0.478563
#
#             g__Prevotella_ASV-1  g___ASV-2  g__Streptococcus_ASV-3  ...  \
# #sample-id                                                          ...
# Ca009STL                    NaN  -0.385521                1.140536  ...
# 900221                      NaN        NaN                     NaN  ...
# Ca010EBL                1.02649  -1.276094                0.515665  ...
# 900460                      NaN        NaN                1.945336  ...
# 900051                      NaN        NaN               -1.379744  ...
# ...                         ...        ...                     ...  ...
# 9004032                     NaN        NaN               -0.746836  ...
# Ca006ONL                    NaN  -1.394155                0.551754  ...
# Ca006ONL2                   NaN        NaN                     NaN  ...
# Ca006ONNL                   NaN  -0.369233               -1.467845  ...
# Ca006ONNL2                  NaN   1.226184                0.620049  ...
#
#             g__Flavobacterium_ASV-25  g___ASV-434  g__Staphylococcus_ASV-33  \
# #sample-id
# Ca009STL                         NaN          NaN                       NaN
# 900221                           NaN          NaN                       NaN
# Ca010EBL                         NaN          NaN                       NaN
# 900460                           NaN          NaN                       NaN
# 900051                           NaN          NaN                       NaN
# ...                              ...          ...                       ...
# 9004032                          NaN          NaN                       NaN
# Ca006ONL                         NaN          NaN                       NaN
# Ca006ONL2                        NaN          NaN                       NaN
# Ca006ONNL                        NaN          NaN                       NaN
# Ca006ONNL2                       NaN          NaN                       NaN
#
#             g__Flavobacterium_ASV-8  g___ASV-489  g__Staphylococcus_ASV-34  \
# #sample-id
# Ca009STL                        NaN          NaN                       NaN
# 900221                          NaN          NaN                       NaN
# Ca010EBL                        NaN          NaN                       NaN
# 900460                          NaN          NaN                       NaN
# 900051                          NaN          NaN                       NaN
# ...                             ...          ...                       ...
# 9004032                         NaN          NaN                       NaN
# Ca006ONL                        NaN          NaN                       NaN
# Ca006ONL2                       NaN          NaN                       NaN
# Ca006ONNL                       NaN          NaN                       NaN
# Ca006ONNL2                      NaN          NaN                       NaN
#
#             g__Streptococcus_ASV-37      group  o_scorad        pid
# #sample-id
# Ca009STL                        NaN   skin-ADL      40.0  Ca-009-ST
# 900221                          NaN   skin-ADL      34.0  Ca-101-ID
# Ca010EBL                        NaN   skin-ADL      21.0  Ca-010-EB
# 900460                          NaN   skin-ADL      40.0  Ca-146-SM
# 900051                          NaN   skin-ADL      41.0  Ca-011-LQ
# ...                             ...        ...       ...        ...
# 9004032                         NaN   skin-ADL      78.0  Ca-126-KB
# Ca006ONL                        NaN   skin-ADL      34.0  Ca-006-ON
# Ca006ONL2                       NaN   skin-ADL      34.0  Ca-006-ON
# Ca006ONNL                       NaN  skin-ADNL      34.0  Ca-006-ON
# Ca006ONNL2                      NaN  skin-ADNL      34.0  Ca-006-ON
#
# [209 rows x 2264 columns]

# %%
# Filter to only include skin-ADL samples for severity correlation analysis
# rclr_df = rclr_df[(rclr_df['group'] == 'skin-ADL') | (rclr_df['group'] == 'skin-ADNL')]
skin_samples
# Out:
#             g__Staphylococcus_ASV-1  g__Staphylococcus_ASV-2  \
# #sample-id
# Ca009STL                  -0.203199                -1.301811
# 900221                          NaN                      NaN
# Ca010EBL                   3.054638                 2.731238
# 900460                     1.657654                 1.657654
# 900051                     3.756053                 2.448896
# ...                             ...                      ...
# 9004032                         NaN                      NaN
# Ca006ONL                   3.315374                 1.783898
# Ca006ONL2                       NaN                      NaN
# Ca006ONNL                  3.708304                 1.790251
# Ca006ONNL2                 3.858727                 3.197737
#
#             g__Streptococcus_ASV-1  g__Micrococcus_ASV-1  \
# #sample-id
# Ca009STL                  0.713092              0.713092
# 900221                         NaN                   NaN
# Ca010EBL                  0.803347                   NaN
# 900460                    3.139258             -0.357249
# 900051                    2.021452                   NaN
# ...                            ...                   ...
# 9004032                   2.749671                   NaN
# Ca006ONL                  1.090750                   NaN
# Ca006ONL2                      NaN                   NaN
# Ca006ONNL                 0.729379             -0.774698
# Ca006ONNL2                0.437727              2.047165
#
#             g__Corynebacterium_ASV-2  g__Streptococcus_ASV-2  g___ASV-1  \
# #sample-id
# Ca009STL                         NaN                     NaN   2.639770
# 900221                     -2.027367                     NaN        NaN
# Ca010EBL                         NaN                     NaN   2.019742
# 900460                           NaN                2.733793        NaN
# 900051                           NaN                     NaN        NaN
# ...                              ...                     ...        ...
# 9004032                          NaN                     NaN        NaN
# Ca006ONL                   -1.394155                     NaN   2.243430
# Ca006ONL2                        NaN                     NaN        NaN
# Ca006ONNL                   0.611596                     NaN   1.751030
# Ca006ONNL2                 -0.478563               -0.478563  -0.478563
#
#             g__Prevotella_ASV-1  g___ASV-2  g__Streptococcus_ASV-3  ...  \
# #sample-id                                                          ...
# Ca009STL                    NaN  -0.385521                1.140536  ...
# 900221                      NaN        NaN                     NaN  ...
# Ca010EBL                1.02649  -1.276094                0.515665  ...
# 900460                      NaN        NaN                1.945336  ...
# 900051                      NaN        NaN               -1.379744  ...
# ...                         ...        ...                     ...  ...
# 9004032                     NaN        NaN               -0.746836  ...
# Ca006ONL                    NaN  -1.394155                0.551754  ...
# Ca006ONL2                   NaN        NaN                     NaN  ...
# Ca006ONNL                   NaN  -0.369233               -1.467845  ...
# Ca006ONNL2                  NaN   1.226184                0.620049  ...
#
#             g__Flavobacterium_ASV-25  g___ASV-434  g__Staphylococcus_ASV-33  \
# #sample-id
# Ca009STL                         NaN          NaN                       NaN
# 900221                           NaN          NaN                       NaN
# Ca010EBL                         NaN          NaN                       NaN
# 900460                           NaN          NaN                       NaN
# 900051                           NaN          NaN                       NaN
# ...                              ...          ...                       ...
# 9004032                          NaN          NaN                       NaN
# Ca006ONL                         NaN          NaN                       NaN
# Ca006ONL2                        NaN          NaN                       NaN
# Ca006ONNL                        NaN          NaN                       NaN
# Ca006ONNL2                       NaN          NaN                       NaN
#
#             g__Flavobacterium_ASV-8  g___ASV-489  g__Staphylococcus_ASV-34  \
# #sample-id
# Ca009STL                        NaN          NaN                       NaN
# 900221                          NaN          NaN                       NaN
# Ca010EBL                        NaN          NaN                       NaN
# 900460                          NaN          NaN                       NaN
# 900051                          NaN          NaN                       NaN
# ...                             ...          ...                       ...
# 9004032                         NaN          NaN                       NaN
# Ca006ONL                        NaN          NaN                       NaN
# Ca006ONL2                       NaN          NaN                       NaN
# Ca006ONNL                       NaN          NaN                       NaN
# Ca006ONNL2                      NaN          NaN                       NaN
#
#             g__Streptococcus_ASV-37      group  o_scorad        pid
# #sample-id
# Ca009STL                        NaN   skin-ADL      40.0  Ca-009-ST
# 900221                          NaN   skin-ADL      34.0  Ca-101-ID
# Ca010EBL                        NaN   skin-ADL      21.0  Ca-010-EB
# 900460                          NaN   skin-ADL      40.0  Ca-146-SM
# 900051                          NaN   skin-ADL      41.0  Ca-011-LQ
# ...                             ...        ...       ...        ...
# 9004032                         NaN   skin-ADL      78.0  Ca-126-KB
# Ca006ONL                        NaN   skin-ADL      34.0  Ca-006-ON
# Ca006ONL2                       NaN   skin-ADL      34.0  Ca-006-ON
# Ca006ONNL                       NaN  skin-ADNL      34.0  Ca-006-ON
# Ca006ONNL2                      NaN  skin-ADNL      34.0  Ca-006-ON
#
# [209 rows x 2264 columns]

# %%
fig, axes = plt.subplots(1, len(taxa_list), figsize=(len(taxa_list) * 2, 3.5), sharey=True)

for i, taxon in enumerate(taxa_list):
    ax = axes[i]
    
    # Drop missing values
    df = skin_samples[['o_scorad', taxon]].dropna()

    # Plot regression
    sns.regplot(
        data=df,
        x='o_scorad',
        y=taxon,
        scatter_kws={'alpha': 0.5, 's': 20},
        line_kws={'color': 'black'},
        ax=ax
    )

    # Compute Pearson correlation
    r, pval = pearsonr(df['o_scorad'], df[taxon])
    r_label = f"Pearson r = {r:.2f}\np = {pval:.1e}"
    ax.text(0.05, 0.95, r_label, transform=ax.transAxes,
            fontsize=10, va='top', ha='left', bbox=dict(facecolor='white', alpha=0.7, edgecolor='none'))

    # Format axes
    # ax.set_title(taxon.replace(' g__', '').split('_')[0], fontsize=12)
    ax.set_title(taxon.replace('g__', ''), fontsize=10)
    ax.set_xlabel("SCORAD Severity", fontsize=12)
    if i == 0:
        ax.set_ylabel("RCLR-transformed abundance", fontsize=12)
    else:
        ax.set_ylabel("")
        ax.set_yticklabels([])

    ax.set_ylim(-3, 7)

plt.tight_layout(rect=[0, 0, 1, 0.92])  # Leaves space for suptitle
plt.suptitle("Correlation Between Taxa on Skin and Atopic Dermatitis Severity", fontsize=14, y=0.98)
plt.savefig('../Plots/Analysis_figures/Severity_Correlations/rclr_abundance_vs_severity_ASV_skin.png', dpi=600)
