# %% [markdown]
# ## Scatter plot showing the relative abundances of shared ASVs (present in both skin and nares) across paired samples. Each point represents a single ASV, with its average relative abundance in skin samples on the x-axis and nares samples on the y-axis.

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd
import biom
from biom import load_table
import numpy as np
import scipy.stats as stats
from scipy.stats import mannwhitneyu
from statsmodels.stats.multitest import multipletests
import itertools
import matplotlib.patches
from scipy.stats import pearsonr

# %%
# Load the metadata
metadata_path = '../Data/Metadata/updated_clean_ant_skin_metadata_microbiome_type.tab'
metadata = pd.read_csv(metadata_path, sep='\t')

metadata['#sample-id'] = metadata['#sample-id'].str.replace('_', '')
# Set Sample-ID as the index for the metadata dataframe 
metadata = metadata.set_index('#sample-id')


# Create group column based on case_type to simplify group names
metadata['group'] = metadata['case_type'].map({
    'case-lesional skin': 'skin-ADL',
    'case-nonlesional skin': 'skin-ADNL', 
    'control-nonlesional skin': 'skin-H',
    'case-anterior nares': 'nares-AD',
    'control-anterior nares': 'nares-H'
})

metadata
# Out:
#             PlateNumber PlateLocation     i5 i5Sequence     i7 i7Sequence  \
# #sample-id
# Ca009STL              1            A1  SA501   ATCGTACG  SA701   CGAGAGTT
# 900221                1            B1  SA502   ACTATCTG  SA701   CGAGAGTT
# Ca010EBL              1            C1  SA503   TAGCGAGT  SA701   CGAGAGTT
# 900460                1            D1  SA504   CTGCGTGT  SA701   CGAGAGTT
# 900051                1            E1  SA505   TCATCGAG  SA701   CGAGAGTT
# ...                 ...           ...    ...        ...    ...        ...
# Ca006ONL2             6            H1  SA508   GACACCGT  SB701   CTCGACTT
# Ca006ONNL             6            F2  SA506   CGTGAGTG  SB702   CGAAGTAT
# Ca006ONNL2            6            H2  SA508   GACACCGT  SB702   CGAAGTAT
# Ca006ONPN             6            F3  SA506   CGTGAGTG  SB703   TAGCAGCT
# Ca006ONPN2            6            H3  SA508   GACACCGT  SB703   TAGCAGCT
#
#             identifier           Sequence      Plate ID Well location  ...  \
# #sample-id                                                             ...
# Ca009STL    SA701SA501  CGAGAGTT-ATCGTACG  1.010000e+21            A1  ...
# 900221      SA701SA502  CGAGAGTT-ACTATCTG  1.010000e+21            B1  ...
# Ca010EBL    SA701SA503  CGAGAGTT-TAGCGAGT  1.010000e+21            C1  ...
# 900460      SA701SA504  CGAGAGTT-CTGCGTGT  1.010000e+21            D1  ...
# 900051      SA701SA505  CGAGAGTT-TCATCGAG  1.010000e+21            E1  ...
# ...                ...                ...           ...           ...  ...
# Ca006ONL2   SB701SA508  CTCGACTT-GACACCGT  1.010000e+21            H1  ...
# Ca006ONNL   SB702SA506  CGAAGTAT-CGTGAGTG  1.010000e+21            F2  ...
# Ca006ONNL2  SB702SA508  CGAAGTAT-GACACCGT  1.010000e+21            H2  ...
# Ca006ONPN   SB703SA506  TAGCAGCT-CGTGAGTG  1.010000e+21            F3  ...
# Ca006ONPN2  SB703SA508  TAGCAGCT-GACACCGT  1.010000e+21            H3  ...
#
#             enrolment_date enrolment_season hiv_exposure hiv_status  \
# #sample-id
# Ca009STL         4/16/2015          Autumn     Unexposed   negative
# 900221           8/11/2015           Winter    Unexposed   negative
# Ca010EBL        11/20/2014           Spring    Unexposed   negative
# 900460           9/23/2015           Spring    Unexposed        NaN
# 900051           4/21/2015          Autumn     Unexposed   negative
# ...                    ...              ...          ...        ...
# Ca006ONL2        3/25/2015           Autumn    Unexposed   negative
# Ca006ONNL        3/25/2015           Autumn    Unexposed   negative
# Ca006ONNL2       3/25/2015           Autumn    Unexposed   negative
# Ca006ONPN        3/25/2015           Autumn    Unexposed   negative
# Ca006ONPN2       3/25/2015           Autumn    Unexposed   negative
#
#            household_size o_scorad  \
# #sample-id
# Ca009STL              4.0       40
# 900221                7.0       34
# Ca010EBL              7.0       21
# 900460                4.0       40
# 900051                7.0       41
# ...                   ...      ...
# Ca006ONL2             3.0       34
# Ca006ONNL             3.0       34
# Ca006ONNL2            3.0       34
# Ca006ONPN             3.0       34
# Ca006ONPN2            3.0       34
#
#                                                  FWD_filepath  \
# #sample-id
# Ca009STL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900221      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca010EBL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900460      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 900051      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# ...                                                       ...
# Ca006ONL2   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONNL   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONNL2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONPN   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# Ca006ONPN2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
#
#                                                  REV_filepath      group  \
# #sample-id
# Ca009STL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900221      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# Ca010EBL    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900460      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# 900051      /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# ...                                                       ...        ...
# Ca006ONL2   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   skin-ADL
# Ca006ONNL   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...  skin-ADNL
# Ca006ONNL2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...  skin-ADNL
# Ca006ONPN   /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   nares-AD
# Ca006ONPN2  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...   nares-AD
#
#            microbiome_type
# #sample-id
# Ca009STL              skin
# 900221                skin
# Ca010EBL              skin
# 900460                skin
# 900051                skin
# ...                    ...
# Ca006ONL2             skin
# Ca006ONNL             skin
# Ca006ONNL2            skin
# Ca006ONPN            nares
# Ca006ONPN2           nares
#
# [502 rows x 33 columns]

# %%
# Get participants with both skin and nares samples
skin_pids = metadata[metadata['microbiome_type'] == 'skin']['pid']
nares_pids = metadata[metadata['microbiome_type'] == 'nares']['pid']

# Find overlapping participants
shared_pids = set(skin_pids).intersection(set(nares_pids))

print(f"Number of participants with both skin and nares samples: {len(shared_pids)}")

# Display the participant IDs
print("\nParticipant IDs with both sample types:")
print(sorted(list(shared_pids)))
print(len(list(shared_pids)))
# Out:
# Number of participants with both skin and nares samples: 187
#
# Participant IDs with both sample types:
# ['Ca-006-ON', 'Ca-007-NK', 'Ca-008-HN', 'Ca-009-ST', 'Ca-009-ZN', 'Ca-010-EB', 'Ca-011-LQ', 'Ca-013-NN', 'Ca-014-LB', 'Ca-015-AM', 'Ca-016-YT', 'Ca-017-OM', 'Ca-018-AS', 'Ca-019-EC', 'Ca-020-AZ', 'Ca-021-IM', 'Ca-022-MS', 'Ca-023-EJ', 'Ca-024-ZM', 'Ca-025-AC', 'Ca-026-KM', 'Ca-027-IM', 'Ca-028-PN', 'Ca-029-TD', 'Ca-030-LM', 'Ca-031-AN', 'Ca-032-LN', 'Ca-033-UD', 'Ca-034-LS', 'Ca-035-AR', 'Ca-036-TK', 'Ca-037-HM', 'Ca-042-AM', 'Ca-043-SS', 'Ca-045-HN', 'Ca-046-MT', 'Ca-047-MD', 'Ca-049-LM', 'Ca-050-MM', 'Ca-051-AM', 'Ca-052-LM', 'Ca-053-NN', 'Ca-054-RN', 'Ca-055-LN', 'Ca-056-DH', 'Ca-101-ID', 'Ca-103-BT', 'Ca-104-SB', 'Ca-105-LX', 'Ca-106-NM', 'Ca-107-BM', 'Ca-108-EJ', 'Ca-110-LN', 'Ca-111-IN', 'Ca-112-AM', 'Ca-113-MN', 'Ca-114-QT', 'Ca-115-OM', 'Ca-116-AN', 'Ca-117-SM', 'Ca-118-AS', 'Ca-119-AM', 'Ca-120-ST', 'Ca-121-BT', 'Ca-122-UK', 'Ca-123-PG', 'Ca-124-AB', 'Ca-125-IM', 'Ca-126-KB', 'Ca-127-OM', 'Ca-128-SN', 'Ca-129-AJ', 'Ca-130-PM', 'Ca-131-PM', 'Ca-132-LD', 'Ca-133-LT', 'Ca-134-IT', 'Ca-135-NS', 'Ca-136-OM', 'Ca-137-TM', 'Ca-138-SM', 'Ca-139-OS', 'Ca-140-EM', 'Ca-141-TC', 'Ca-142-AM', 'Ca-143-ST', 'Ca-144-HN', 'Ca-145-LM', 'Ca-146-SM', 'Ca-147-LJ', 'Ca-148-AL', 'Ca-149-LM', 'Ca-150-ZS', 'Ca-151-QR', 'Ca-153-MN', 'Ca-154-OS', 'Ca-155-LS', 'Ca-156-MV', 'Ca-157-LM', 'Ca-158-LC', 'Ca-159-AS', 'Ca-160-LB', 'Ca-161-OM', 'Co-001-SM', 'Co-002-MP', 'Co-003-LT', 'Co-004-LN', 'Co-005-SN', 'Co-011-SF', 'Co-012-ON', 'Co-013-AY', 'Co-014-TN', 'Co-015-OJ', 'Co-016-CB', 'Co-026-LT', 'Co-027-IS', 'Co-028-UV', 'Co-029-YL', 'Co-030-AL', 'Co-031-LM', 'Co-032-AR', 'Co-033-LN', 'Co-034-AS', 'Co-036-OM', 'Co-037-LM', 'Co-038-AG', 'Co-039-KG', 'Co-040-ST', 'Co-041-LC', 'Co-042-LN', 'Co-043-ZS', 'Co-044-KM', 'Co-045-OM', 'Co-046-KL', 'Co-047-LV', 'Co-049-LJ', 'Co-050-AH', 'Co-101-AN', 'Co-102-LD', 'Co-103-MM', 'Co-104-IV', 'Co-105-IV', 'Co-106-AB', 'Co-107-TG', 'Co-108-OG', 'Co-109-AG', 'Co-110-SW', 'Co-111-AM', 'Co-112-SN', 'Co-113-MM', 'Co-114-IG', 'Co-115-SG', 'Co-116-MR', 'Co-117-TG', 'Co-118-MG', 'Co-119-MG', 'Co-120-MM', 'Co-121-MM', 'Co-122-IS', 'Co-123-LZ', 'Co-124-UM', 'Co-125-MM', 'Co-126-ID', 'Co-127-MB', 'Co-128-IV', 'Co-130-MM', 'Co-131-AM', 'Co-132-IM', 'Co-133-KT', 'Co-134-KK', 'Co-135-LT', 'Co-136-SM', 'Co-137-AM', 'Co-138-AT', 'Co-140-IM', 'Co-142-IP', 'Co-143-AN', 'Co-144-LM', 'Co-145-HN', 'Co-146-LK', 'Co-147-SV', 'Co-148-IM', 'Co-149-LM', 'Co-150-LN', 'Co-151-AN', 'Co-152-AF', 'Co-153-YM']
# 187

# %%
# Read in table at ASV level
# biom_path = '../Data/Tables/Absolute_Abundance_Tables/feature_table_with_tax_labels_Genus.biom'
biom_path = '../Data/Tables/Absolute_Abundance_Tables/209766_filtered_by_prevalence_1pct_rare_Genus-ASV-non-collapse.biom'
biom_tbl = load_table(biom_path)
df = pd.DataFrame(biom_tbl.to_dataframe().T)

# delete the prefix from the index
df.index = df.index.str.replace('15564.', '')

# Map the 'microbiome_type', 'group', 'o_scorad' columns from metadata to df based on matching index
df['group'] = metadata.loc[df.index, 'group']
df['microbiome_type'] = metadata.loc[df.index, 'microbiome_type']
df['o_scorad'] = metadata.loc[df.index, 'o_scorad']
df['pid'] = metadata.loc[df.index, 'pid']

df
# Out:
#          g__Streptococcus_ASV-1  g__Streptococcus_ASV-2  \
# 900344                    188.0                   115.0
# 900459                     20.0                    37.0
# 900221                        0                       0
# 900570                     18.0                       0
# 900092                    221.0                   116.0
# ...                         ...                     ...
# 9003972                    45.0                    20.0
# 900097                      3.0                       0
# 900498                      5.0                     4.0
# 900276                        0                       0
# 900406                        0                       0
#
#          g__Corynebacterium_ASV-1  g__Corynebacterium_ASV-3  g___ASV-3  \
# 900344                       23.0                      19.0        2.0
# 900459                          0                         0          0
# 900221                          0                         0          0
# 900570                          0                         0        1.0
# 900092                        3.0                       1.0          0
# ...                           ...                       ...        ...
# 9003972                       1.0                         0        1.0
# 900097                          0                         0          0
# 900498                          0                         0          0
# 900276                       13.0                         0          0
# 900406                          0                         0          0
#
#          g__Cutibacterium_ASV-1  g___ASV-18  g___ASV-28  g___ASV-26  \
# 900344                      2.0         1.0           0           0
# 900459                        0           0           0           0
# 900221                        0           0           0           0
# 900570                        0           0           0           0
# 900092                        0           0           0         1.0
# ...                         ...         ...         ...         ...
# 9003972                    21.0           0           0         1.0
# 900097                      6.0           0           0           0
# 900498                     11.0           0         6.0           0
# 900276                     63.0           0           0           0
# 900406                        0           0           0           0
#
#          g__Cutibacterium_ASV-2  ...  g__Leptotrichia_A_993758_ASV-14  \
# 900344                        0  ...                                0
# 900459                        0  ...                                0
# 900221                        0  ...                                0
# 900570                        0  ...                                0
# 900092                        0  ...                                0
# ...                         ...  ...                              ...
# 9003972                    18.0  ...                                0
# 900097                      1.0  ...                                0
# 900498                     13.0  ...                                0
# 900276                     51.0  ...                                0
# 900406                        0  ...                                0
#
#          g__Capnocytophaga_820688_ASV-7  g__UBA6175_ASV-2  \
# 900344                                0                 0
# 900459                                0                 0
# 900221                                0                 0
# 900570                                0                 0
# 900092                                0                 0
# ...                                 ...               ...
# 9003972                               0                 0
# 900097                                0                 0
# 900498                                0                 0
# 900276                                0                 0
# 900406                                0                 0
#
#          g__Comamonas_F_589250_ASV-4  g__Bosea_ASV-2  g___ASV-140      group  \
# 900344                             0               0            0     skin-H
# 900459                             0               0            0   nares-AD
# 900221                             0               0            0   skin-ADL
# 900570                             0               0            0  skin-ADNL
# 900092                             0               0            0   nares-AD
# ...                              ...             ...          ...        ...
# 9003972                            0               0          1.0   skin-ADL
# 900097                             0               0            0  skin-ADNL
# 900498                             0               0            0  skin-ADNL
# 900276                             0               0            0   skin-ADL
# 900406                             0               0            0  skin-ADNL
#
#          microbiome_type  o_scorad        pid
# 900344              skin       NaN  Co-130-MM
# 900459             nares        44  Ca-145-LM
# 900221              skin        34  Ca-101-ID
# 900570              skin        36  Ca-046-MT
# 900092             nares        53  Ca-023-EJ
# ...                  ...       ...        ...
# 9003972             skin        54  Ca-125-IM
# 900097              skin        44  Ca-025-AC
# 900498              skin       NaN  Ca-157-LM
# 900276              skin        52  Ca-111-IN
# 900406              skin        28  Ca-127-OM
#
# [502 rows x 802 columns]

# %%
# --- STEP 1: Prepare the data ---

# Separate features and metadata
features = df.drop(columns=['microbiome_type', 'group'])
metadata = df[['microbiome_type', 'group']]

# Coerce all to numeric and drop non-numeric columns
features_numeric = features.apply(pd.to_numeric, errors='coerce')
features_numeric = features_numeric.dropna(axis=1, how='all')

# Normalize to relative abundances
features_rel = features_numeric.div(features_numeric.sum(axis=1), axis=0)

# Add metadata back
features_rel['microbiome_type'] = metadata['microbiome_type']
features_rel['group'] = metadata['group']
# features_rel['pid'] = metadata['pid']
# features_rel['o_scorad'] = metadata['o_scorad']

# --- STEP 2: Define subsets ---

# AD group
skin_ADL = features_rel[features_rel['group'] == 'skin-ADL'].drop(columns=['microbiome_type', 'group'])
nares_AD = features_rel[features_rel['group'] == 'nares-AD'].drop(columns=['microbiome_type', 'group'])

# Healthy group
skin_H = features_rel[features_rel['group'] == 'skin-H'].drop(columns=['microbiome_type', 'group'])
nares_H = features_rel[features_rel['group'] == 'nares-H'].drop(columns=['microbiome_type', 'group'])

# --- STEP 3: Calculate mean relative abundances ---

mean_skin_ADL = skin_ADL.mean().astype(float)
mean_nares_AD = nares_AD.mean().astype(float)

mean_skin_H = skin_H.mean().astype(float)
mean_nares_H = nares_H.mean().astype(float)

# --- STEP 4: Make scatterplots ---

fig, axes = plt.subplots(1, 2, figsize=(10, 5))

# --- Scatterplot 1: Healthy group (left) ---

scatter_df_H = pd.DataFrame({
    'mean_skin': mean_skin_H,
    'mean_nares': mean_nares_H
}).replace(0, 1e-6)

# Filter out rows where either value is non-positive or NaN
valid_H = (scatter_df_H['mean_nares'] > 0) & (scatter_df_H['mean_skin'] > 0)
log_nares_H = np.log10(scatter_df_H.loc[valid_H, 'mean_nares'])
log_skin_H = np.log10(scatter_df_H.loc[valid_H, 'mean_skin'])

r_H, pval_H = stats.pearsonr(log_nares_H, log_skin_H)

axes[0].scatter(
    scatter_df_H['mean_nares'],
    scatter_df_H['mean_skin'],
    alpha=0.7,
    edgecolors='k',
    linewidths=0.5,
    color='#ADD8E6'
)

lims_H = [1e-6, scatter_df_H.max().max()]
axes[0].plot(lims_H, lims_H, 'k--', alpha=0.75)

axes[0].set_xscale('log')
axes[0].set_yscale('log')
axes[0].set_xlabel('Mean Relative Abundance in Nares-H', fontsize=12)
axes[0].set_ylabel('Mean Relative Abundance in Skin-H', fontsize=12)
n_H = metadata['group'].isin(['skin-H', 'nares-H']).sum() // 2
axes[0].set_title(f'Healthy Individuals (n={n_H})', fontsize=14)

axes[0].text(
    0.05, 0.95,
    f'Pearson r = {r_H:.2f}\n$p$ = {pval_H:.2e}',
    ha='left', va='top',
    transform=axes[0].transAxes,
    fontsize=12
)

axes[0].plot(0.05, 0.82, marker='o', markersize=6, color='#ADD8E6', transform=axes[0].transAxes, clip_on=False)
axes[0].text(0.07, 0.82, '16S ASV (n=798)', ha='left', va='center', transform=axes[0].transAxes, fontsize=11)

# --- Scatterplot 2: AD group (right) ---

scatter_df_AD = pd.DataFrame({
    'mean_skin': mean_skin_ADL,
    'mean_nares': mean_nares_AD
}).replace(0, 1e-6)

valid_AD = (scatter_df_AD['mean_nares'] > 0) & (scatter_df_AD['mean_skin'] > 0)
log_nares_AD = np.log10(scatter_df_AD.loc[valid_AD, 'mean_nares'])
log_skin_AD = np.log10(scatter_df_AD.loc[valid_AD, 'mean_skin'])

r_AD, pval_AD = stats.pearsonr(log_nares_AD, log_skin_AD)

axes[1].scatter(
    scatter_df_AD['mean_nares'],
    scatter_df_AD['mean_skin'],
    alpha=0.7,
    edgecolors='k',
    linewidths=0.5,
    color='#E31A1C'
)

lims_AD = [1e-6, scatter_df_AD.max().max()]
axes[1].plot(lims_AD, lims_AD, 'k--', alpha=0.75)

axes[1].set_xscale('log')
axes[1].set_yscale('log')
axes[1].set_xlabel('Mean Relative Abundance in Nares-AD', fontsize=14)
axes[1].set_ylabel('Mean Relative Abundance in Skin-ADL', fontsize=14)
n_AD = metadata['group'].isin(['skin-ADL', 'nares-AD']).sum() // 2
axes[1].set_title(f'AD Individuals (n={n_AD})', fontsize=14)

axes[1].text(
    0.05, 0.95,
    f'Pearson r = {r_AD:.2f}\n$p$ = {pval_AD:.2e}',
    ha='left', va='top',
    transform=axes[1].transAxes,
    fontsize=12
)

axes[1].plot(0.05, 0.82, marker='o', markersize=6, color='#E31A1C', transform=axes[1].transAxes, clip_on=False)
axes[1].text(0.07, 0.82, '16S ASV (n=798)', ha='left', va='center', transform=axes[1].transAxes, fontsize=11)

# --- Final layout ---
plt.suptitle('ASV Correlation between Skin and Nares by Disease Status', fontsize=16)
plt.tight_layout()
# plt.subplots_adjust(wspace=0.4)

plt.savefig('../Plots/Analysis_figures/Co-occurrence/ASV-correlation_scatterplots_AD_vs_H.png', dpi=600)
# Out:
# /Users/yangchen/miniforge3/envs/qiime2-metagenome-2024.10/lib/python3.10/site-packages/pandas/core/arrays/sparse/array.py:1556: RuntimeWarning: invalid value encountered in scalar divide
#   return sp_sum / ct
