# %%
import pandas as pd

# %%
md = pd.read_csv('../Data/Metadata/16S_AD_South-Africa_metadata.tsv', sep='\t')
md
# Out:
#        #sample-id  PlateNumber PlateLocation     i5 i5Sequence     i7  \
# 0       Ca009ST_L            1            A1  SA501   ATCGTACG  SA701
# 1          900221            1            B1  SA502   ACTATCTG  SA701
# 2       Ca010EB_L            1            C1  SA503   TAGCGAGT  SA701
# 3          900460            1            D1  SA504   CTGCGTGT  SA701
# 4          900051            1            E1  SA505   TCATCGAG  SA701
# ..            ...          ...           ...    ...        ...    ...
# 497   Ca006ON_L_2            6            H1  SA508   GACACCGT  SB701
# 498    Ca006ON_NL            6            F2  SA506   CGTGAGTG  SB702
# 499  Ca006ON_NL_2            6            H2  SA508   GACACCGT  SB702
# 500    Ca006ON_PN            6            F3  SA506   CGTGAGTG  SB703
# 501  Ca006ON_PN_2            6            H3  SA508   GACACCGT  SB703
#
#     i7Sequence  identifier           Sequence      Plate ID  ... age_months  \
# 0     CGAGAGTT  SA701SA501  CGAGAGTT-ATCGTACG  1.010000e+21  ...         24
# 1     CGAGAGTT  SA701SA502  CGAGAGTT-ACTATCTG  1.010000e+21  ...          9
# 2     CGAGAGTT  SA701SA503  CGAGAGTT-TAGCGAGT  1.010000e+21  ...         24
# 3     CGAGAGTT  SA701SA504  CGAGAGTT-CTGCGTGT  1.010000e+21  ...         18
# 4     CGAGAGTT  SA701SA505  CGAGAGTT-TCATCGAG  1.010000e+21  ...         31
# ..         ...         ...                ...           ...  ...        ...
# 497   CTCGACTT  SB701SA508  CTCGACTT-GACACCGT  1.010000e+21  ...         35
# 498   CGAAGTAT  SB702SA506  CGAAGTAT-CGTGAGTG  1.010000e+21  ...         35
# 499   CGAAGTAT  SB702SA508  CGAAGTAT-GACACCGT  1.010000e+21  ...         35
# 500   TAGCAGCT  SB703SA506  TAGCAGCT-CGTGAGTG  1.010000e+21  ...         35
# 501   TAGCAGCT  SB703SA508  TAGCAGCT-GACACCGT  1.010000e+21  ...         35
#
#         sex enrolment_date enrolment_season hiv_exposure hiv_status  \
# 0      male      4/16/2015          Autumn     Unexposed   negative
# 1    female      8/11/2015           Winter    Unexposed   negative
# 2    female     11/20/2014           Spring    Unexposed   negative
# 3    female      9/23/2015           Spring    Unexposed        NaN
# 4      male      4/21/2015          Autumn     Unexposed   negative
# ..      ...            ...              ...          ...        ...
# 497  female      3/25/2015           Autumn    Unexposed   negative
# 498  female      3/25/2015           Autumn    Unexposed   negative
# 499  female      3/25/2015           Autumn    Unexposed   negative
# 500  female      3/25/2015           Autumn    Unexposed   negative
# 501  female      3/25/2015           Autumn    Unexposed   negative
#
#     household_size o_scorad  \
# 0              4.0       40
# 1              7.0       34
# 2              7.0       21
# 3              4.0       40
# 4              7.0       41
# ..             ...      ...
# 497            3.0       34
# 498            3.0       34
# 499            3.0       34
# 500            3.0       34
# 501            3.0       34
#
#                                           FWD_filepath  \
# 0    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 1    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 2    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 3    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 4    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# ..                                                 ...
# 497  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 498  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 499  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 500  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 501  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
#
#                                           REV_filepath
# 0    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 1    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 2    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 3    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 4    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# ..                                                 ...
# 497  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 498  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 499  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 500  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 501  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
#
# [502 rows x 32 columns]

# %%
md_unique = md.drop_duplicates(subset=['pid', 'case_type'], keep='first')
md_unique
# Out:
#      #sample-id  PlateNumber PlateLocation     i5 i5Sequence     i7  \
# 0     Ca009ST_L            1            A1  SA501   ATCGTACG  SA701
# 1        900221            1            B1  SA502   ACTATCTG  SA701
# 2     Ca010EB_L            1            C1  SA503   TAGCGAGT  SA701
# 3        900460            1            D1  SA504   CTGCGTGT  SA701
# 4        900051            1            E1  SA505   TCATCGAG  SA701
# ..          ...          ...           ...    ...        ...    ...
# 492      900402            6            B4  SA502   ACTATCTG  SB704
# 494      900403            4            B1  SA502   ACTATCTG  SA701
# 496   Ca006ON_L            6            F1  SA506   CGTGAGTG  SB701
# 498  Ca006ON_NL            6            F2  SA506   CGTGAGTG  SB702
# 500  Ca006ON_PN            6            F3  SA506   CGTGAGTG  SB703
#
#     i7Sequence  identifier           Sequence      Plate ID  ... age_months  \
# 0     CGAGAGTT  SA701SA501  CGAGAGTT-ATCGTACG  1.010000e+21  ...         24
# 1     CGAGAGTT  SA701SA502  CGAGAGTT-ACTATCTG  1.010000e+21  ...          9
# 2     CGAGAGTT  SA701SA503  CGAGAGTT-TAGCGAGT  1.010000e+21  ...         24
# 3     CGAGAGTT  SA701SA504  CGAGAGTT-CTGCGTGT  1.010000e+21  ...         18
# 4     CGAGAGTT  SA701SA505  CGAGAGTT-TCATCGAG  1.010000e+21  ...         31
# ..         ...         ...                ...           ...  ...        ...
# 492   TCTCTATG  SB704SA502  TCTCTATG-ACTATCTG  1.010000e+21  ...         21
# 494   CGAGAGTT  SA701SA502  CGAGAGTT-ACTATCTG  1.010000e+21  ...         33
# 496   CTCGACTT  SB701SA506  CTCGACTT-CGTGAGTG  1.010000e+21  ...         35
# 498   CGAAGTAT  SB702SA506  CGAAGTAT-CGTGAGTG  1.010000e+21  ...         35
# 500   TAGCAGCT  SB703SA506  TAGCAGCT-CGTGAGTG  1.010000e+21  ...         35
#
#         sex enrolment_date enrolment_season hiv_exposure hiv_status  \
# 0      male      4/16/2015          Autumn     Unexposed   negative
# 1    female      8/11/2015           Winter    Unexposed   negative
# 2    female     11/20/2014           Spring    Unexposed   negative
# 3    female      9/23/2015           Spring    Unexposed        NaN
# 4      male      4/21/2015          Autumn     Unexposed   negative
# ..      ...            ...              ...          ...        ...
# 492     NaN            NaN              NaN          NaN        NaN
# 494    male      9/17/2015           Spring    Unexposed   negative
# 496  female      3/25/2015           Autumn    Unexposed   negative
# 498  female      3/25/2015           Autumn    Unexposed   negative
# 500  female      3/25/2015           Autumn    Unexposed   negative
#
#     household_size o_scorad  \
# 0              4.0       40
# 1              7.0       34
# 2              7.0       21
# 3              4.0       40
# 4              7.0       41
# ..             ...      ...
# 492            NaN      NaN
# 494            5.0       78
# 496            3.0       34
# 498            3.0       34
# 500            3.0       34
#
#                                           FWD_filepath  \
# 0    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 1    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 2    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 3    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 4    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# ..                                                 ...
# 492  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 494  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 496  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 498  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 500  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
#
#                                           REV_filepath
# 0    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 1    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 2    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 3    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 4    /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# ..                                                 ...
# 492  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 494  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 496  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 498  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
# 500  /Users/yac027/Gallo_lab/16S_AD_Dube_Dupont/ato...
#
# [483 rows x 32 columns]

# %%
print("Number of children by AD status:\n", md_unique.groupby('participant')['pid'].nunique())
# Out:
# Number of children by AD status:
#  participant
# case       110
# control     87
# Name: pid, dtype: int64

# %%
print("Number of children: ", md_unique['pid'].nunique())
# Out:
# Number of children:  197

# %%
md_unique = md_unique.copy()
md_unique['age_months'] = pd.to_numeric(md_unique['age_months'], errors='coerce')
print("Range of age_months:")
print("Min:", md_unique['age_months'].min())
print("Max:", md_unique['age_months'].max())
# Out:
# Range of age_months:
# Min: 9.0
# Max: 38.0

# %%
print("Age range (in months) by AD status:\n",
      md_unique.groupby('participant')['age_months'].agg(['min', 'max']))
# Out:
# Age range (in months) by AD status:
#                min   max
# participant
# case          9.0  38.0
# control      12.0  36.0

# %%
print("Number of skin and nasal samples: ", md_unique['specimen'].value_counts())
# Out:
# Number of skin and nasal samples:  specimen
# skin     294
# nasal    189
# Name: count, dtype: int64

# %%
print("Sample numbers by body site and case/control status: ", md_unique['case_type'].value_counts())
# Out:
# Sample numbers by body site and case/control status:  case_type
# case-nonlesional skin       106
# case-lesional skin          103
# case-anterior nares         103
# control-anterior nares       86
# control-nonlesional skin     85
# Name: count, dtype: int64

# %%
print("Total samples:", md_unique['case_type'].value_counts().sum())
# Out:
# Total samples: 483

# %%
print("Number of total of samples: ", md_unique.shape[0])
# Out:
# Number of total of samples:  483

# %%
# Loop through each unique case_type
for case in md_unique['case_type'].unique():
    subset = md_unique[md_unique['case_type'] == case]
    duplicates = subset[subset.duplicated('pid', keep=False)]

    if not duplicates.empty:
        print(f"Duplicate children found for case_type '{case}':")
        print(duplicates[['pid', '#sample-id']])
        print()  # blank line for readability
    else:
        print(f"No duplicate children found for case_type '{case}'.")
# Out:
# No duplicate children found for case_type 'case-lesional skin'.
# No duplicate children found for case_type 'case-nonlesional skin'.
# No duplicate children found for case_type 'case-anterior nares'.
# No duplicate children found for case_type 'control-nonlesional skin'.
# No duplicate children found for case_type 'control-anterior nares'.
